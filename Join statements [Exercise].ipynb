# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Join statements

# %% [markdown]
# In this exercise,  we will explore different SQL `JOIN` statements in order to cross-examine data contained in multiple tables in a dataset.

# %% [markdown]
# > ⚠️ In this exercise, we will query a sample SQLite database file called Chinook to gain some insight into the data. Ensure that you have downloaded the database file, `chinook.db`.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn how to:
# - Join multiple tables.
# - Find common information between tables.
# - Use a `LEFT JOIN` to check for missing information.
# - Use `CROSS JOIN` to find all the possible combinations of required table rows.

# %% [markdown]
# First, let's load our sample database:

# %%
# load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook
# %load_ext sql

# Load the Chinook database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/The%20chinook%20database%20ERD.jpeg"/>
# <br>
# <br>
#     <em>Figure 1: The Chinook database ERD</em>
# </div>

# %% [markdown]
# ## Overview
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Sometimes artists add a title track to their albums. This is a track that has the same title as the album. Write a query that returns albums that have a title track.
# Return rows in the AlbumId column from the albums table, Title from the albums table, and the Name from the tracks table, where the album table Title column matches the tracks table Name column.

# %%
# %%sql
#
# select alb.Title, trk.Name as Track_Name, alb.AlbumId
# from albums as alb
# inner join tracks as trk
# on alb.AlbumId = trk.AlbumId
# WHERE alb.Title = trk.Name
# limit 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Balls to the Wall', 'Balls to the Wall', 2),
#  ('Restless and Wild', 'Restless and Wild', 3),
#  ('Let There Be Rock', 'Let There Be Rock', 4),
#  ('Out Of Exile', 'Out Of Exile', 11),
#  ('Black Sabbath', 'Black Sabbath', 16),
#  ('Body Count', 'Body Count', 18),
#  ('Chemical Wedding', 'Chemical Wedding', 19),
#  ('Prenda Minha', 'Prenda Minha', 21),
#  ('Minha Historia', 'Minha Historia', 23),
#  ('Da Lama Ao Caos', 'Da Lama Ao Caos', 25)]

# %% [markdown]
# ### Exercise 2
#
# Suppose that in the previous exercise, we were additionally interested in knowing who the artists of the listed albums are. Write a query that can achieve this.

# %%
# %%sql
#
# select alb.Title, trk.Name as Track_Name, art.Name as Artist_Name, alb.AlbumId
# from albums as alb
# inner join tracks as trk
# on alb.AlbumId = trk.AlbumId
# inner join artists as art
# on alb.ArtistId = art.ArtistId
# WHERE alb.Title = trk.Name
# limit 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Balls to the Wall', 'Balls to the Wall', 'Accept', 2),
#  ('Restless and Wild', 'Restless and Wild', 'Accept', 3),
#  ('Let There Be Rock', 'Let There Be Rock', 'AC/DC', 4),
#  ('Out Of Exile', 'Out Of Exile', 'Audioslave', 11),
#  ('Black Sabbath', 'Black Sabbath', 'Black Sabbath', 16),
#  ('Body Count', 'Body Count', 'Body Count', 18),
#  ('Chemical Wedding', 'Chemical Wedding', 'Bruce Dickinson', 19),
#  ('Prenda Minha', 'Prenda Minha', 'Caetano Veloso', 21),
#  ('Minha Historia', 'Minha Historia', 'Chico Buarque', 23),
#  ('Da Lama Ao Caos', 'Da Lama Ao Caos', 'Chico Science & Nação Zumbi', 25)]

# %% [markdown]
# ### Exercise 3
#
# One use case for a `LEFT JOIN` is that it can be used to check for missing information. In this case, try to find out what media items have not been bought yet (i.e. are not an item in any invoice).

# %%
# %%sql
#
# select t.Name, t.TrackId, ii.InvoiceId
# from tracks as t
# left join invoice_items as ii
# on t.TrackId = ii.TrackId;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock (We Salute You)', 1, 108),
#  ('Balls to the Wall', 2, 1),
#  ('Balls to the Wall', 2, 214),
#  ('Fast As a Shark', 3, 319),
#  ('Restless and Wild', 4, 1),
#  ('Princess of the Dawn', 5, 108),
#  ('Put The Finger On You', 6, 2),
#  ("Let's Get It Up", 7, None),
#  ('Inject The Venom', 8, 2),
#  ('Inject The Venom', 8, 214),
#  ('Snowballed', 9, 108),
#  ('Snowballed', 9, 319),
#  ('Evil Walks', 10, 2),
#  ('C.O.D.', 11, None),
#  ('Breaking The Rules', 12, 2),
#  ('Night Of The Long Knives', 13, 108),
#  ('Spellbound', 14, 214),
#  ('Go Down', 15, 319),
#  ('Dog Eat Dog', 16, 3),
#  ('Let There Be Rock', 17, None),
#  ('Bad Boy Boogie', 18, None),
#  ('Problem Child', 19, 109),
#  ('Overdose', 20, 3),
#  ('Overdose', 20, 214),
#  ("Hell Ain't A Bad Place To Be", 21, 319),
#  ('Whole Lotta Rosie', 22, None),
#  ('Walk On Water', 23, None),
#  ('Love In An Elevator', 24, 3),
#  ('Rag Doll', 25, 109),
#  ('What It Takes', 26, 214),
#  ('Dude (Looks Like A Lady)', 27, None),
#  ("Janie's Got A Gun", 28, 3),
#  ("Cryin'", 29, None),
#  ('Amazing', 30, 320),
#  ('Blind Man', 31, 109),
#  ('Deuces Are Wild', 32, 3),
#  ('Deuces Are Wild', 32, 214),
#  ('The Other Side', 33, None),
#  ('Crazy', 34, None),
#  ('Eat The Rich', 35, None),
#  ('Angel', 36, 3),
#  ("Livin' On The Edge", 37, 109),
#  ('All I Really Want', 38, 214),
#  ('You Oughta Know', 39, 320),
#  ('Perfect', 40, None),
#  ('Hand In My Pocket', 41, None),
#  ('Right Through You', 42, 4),
#  ('Forgiven', 43, 109),
#  ('You Learn', 44, 214),
#  ('Head Over Feet', 45, None),
#  ('Mary Jane', 46, None),
#  ('Ironic', 47, None),
#  ('Not The Doctor', 48, 4),
#  ('Not The Doctor', 48, 320),
#  ('Wake Up', 49, 109),
#  ('You Oughta Know (Alternate)', 50, None),
#  ('We Die Young', 51, None),
#  ('Man In The Box', 52, None),
#  ('Sea Of Sorrow', 53, 215),
#  ('Bleed The Freak', 54, 4),
#  ("I Can't Remember", 55, 109),
#  ('Love, Hate, Love', 56, None),
#  ("It Ain't Like That", 57, 320),
#  ('Sunshine', 58, None),
#  ('Put You Down', 59, None),
#  ('Confusion', 60, 4),
#  ('I Know Somethin (Bout You)', 61, 109),
#  ('Real Thing', 62, 215),
#  ('Desafinado', 63, None),
#  ('Garota De Ipanema', 64, None),
#  ('Samba De Uma Nota Só (One Note Samba)', 65, None),
#  ('Por Causa De Você', 66, 4),
#  ('Por Causa De Você', 66, 320),
#  ('Ligia', 67, 109),
#  ('Fotografia', 68, None),
#  ('Dindi (Dindi)', 69, None),
#  ('Se Todos Fossem Iguais A Você (Instrumental)', 70, None),
#  ('Falando De Amor', 71, 215),
#  ('Angela', 72, 4),
#  ('Corcovado (Quiet Nights Of Quiet Stars)', 73, None),
#  ('Outra Vez', 74, None),
#  ('O Boto (Bôto)', 75, 320),
#  ('Canta, Canta Mais', 76, 110),
#  ('Enter Sandman', 77, None),
#  ('Master Of Puppets', 78, 4),
#  ('Harvester Of Sorrow', 79, None),
#  ('The Unforgiven', 80, 215),
#  ('Sad But True', 81, None),
#  ('Creeping Death', 82, None),
#  ('Wherever I May Roam', 83, None),
#  ('Welcome Home (Sanitarium)', 84, 4),
#  ('Welcome Home (Sanitarium)', 84, 320),
#  ('Cochise', 85, 110),
#  ('Show Me How to Live', 86, None),
#  ('Gasoline', 87, None),
#  ('What You Are', 88, None),
#  ('Like a Stone', 89, 215),
#  ('Set It Off', 90, 4),
#  ('Shadow on the Sun', 91, None),
#  ('I am the Highway', 92, None),
#  ('Exploder', 93, 320),
#  ('Hypnotize', 94, 110),
#  ("Bring'em Back Alive", 95, None),
#  ('Light My Way', 96, None),
#  ('Getaway Car', 97, None),
#  ('The Last Remaining Light', 98, 215),
#  ('Your Time Has Come', 99, 5),
#  ('Out Of Exile', 100, None),
#  ('Be Yourself', 101, None),
#  ("Doesn't Remind Me", 102, 320),
#  ('Drown Me Slowly', 103, 110),
#  ("Heaven's Dead", 104, None),
#  ('The Worm', 105, None),
#  ('Man Or Animal', 106, None),
#  ('Yesterday To Tomorrow', 107, 215),
#  ('Dandelion', 108, 5),
#  ('#1 Zero', 109, None),
#  ('The Curse', 110, None),
#  ('Money', 111, 320),
#  ('Long Tall Sally', 112, 110),
#  ('Bad Boy', 113, None),
#  ('Twist And Shout', 114, None),
#  ('Please Mr. Postman', 115, None),
#  ("C'Mon Everybody", 116, 215),
#  ("Rock 'N' Roll Music", 117, 5),
#  ('Slow Down', 118, None),
#  ('Roadrunner', 119, None),
#  ('Carol', 120, 320),
#  ('Good Golly Miss Molly', 121, 110),
#  ('20 Flight Rock', 122, None),
#  ('Quadrant', 123, None),
#  ("Snoopy's search-Red baron", 124, None),
#  ('Spanish moss-"A sound portrait"-Spanish moss', 125, 215),
#  ('Moon germs', 126, 5),
#  ('Stratus', 127, None),
#  ('The pleasant pheasant', 128, None),
#  ('Solo-Panhandler', 129, 320),
#  ('Do what cha wanna', 130, 110),
#  ('Intro/ Low Down', 131, None),
#  ('13 Years Of Grief', 132, None),
#  ('Stronger Than Death', 133, None),
#  ('All For You', 134, 215),
#  ('Super Terrorizer', 135, 5),
#  ('Phoney Smile Fake Hellos', 136, None),
#  ('Lost My Better Half', 137, None),
#  ('Bored To Tears', 138, 320),
#  ('A.N.D.R.O.T.A.Z.', 139, 110),
#  ('Born To Booze', 140, None),
#  ('World Of Trouble', 141, None),
#  ('No More Tears', 142, None),
#  ('The Begining... At Last', 143, 215),
#  ('Heart Of Gold', 144, 5),
#  ('Snowblind', 145, None),
#  ('Like A Bird', 146, None),
#  ('Blood In The Wall', 147, 320),
#  ('The Beginning...At Last', 148, 110),
#  ('Black Sabbath', 149, None),
#  ('The Wizard', 150, None),
#  ('Behind The Wall Of Sleep', 151, None),
#  ('N.I.B.', 152, 215),
#  ('Evil Woman', 153, 5),
#  ('Sleeping Village', 154, None),
#  ('Warning', 155, None),
#  ('Wheels Of Confusion / The Straightener', 156, None),
#  ("Tomorrow's Dream", 157, 110),
#  ('Changes', 158, None),
#  ('FX', 159, None),
#  ('Supernaut', 160, None),
#  ('Snowblind', 161, 215),
#  ('Snowblind', 161, 321),
#  ('Cornucopia', 162, 5),
#  ('Cornucopia', 162, 322),
#  ('Laguna Sunrise', 163, 322),
#  ('St. Vitus Dance', 164, None),
#  ('Under The Sun/Every Day Comes and Goes', 165, 323),
#  ('Smoked Pork', 166, 110),
#  ("Body Count's In The House", 167, 323),
#  ('Now Sports', 168, None),
#  ('Body Count', 169, 324),
#  ('A Statistic', 170, 215),
#  ('Bowels Of The Devil', 171, 5),
#  ('Bowels Of The Devil', 171, 324),
#  ('The Real Problem', 172, None),
#  ('KKK Bitch', 173, 324),
#  ('D Note', 174, None),
#  ('Voodoo', 175, 110),
#  ('Voodoo', 175, 324),
#  ('The Winner Loses', 176, None),
#  ('There Goes The Neighborhood', 177, None),
#  ('Oprah', 178, None),
#  ('Evil Dick', 179, 325),
#  ('Body Count Anthem', 180, 5),
#  ("Momma's Gotta Die Tonight", 181, None),
#  ('Freedom Of Speech', 182, None),
#  ('King In Crimson', 183, 325),
#  ('Chemical Wedding', 184, 110),
#  ('Chemical Wedding', 184, 216),
#  ('The Tower', 185, 217),
#  ('Killing Floor', 186, 217),
#  ('Book Of Thel', 187, 325),
#  ('Gates Of Urizen', 188, 218),
#  ('Jerusalem', 189, 5),
#  ('Trupets Of Jericho', 190, 218),
#  ('Machine Men', 191, 325),
#  ('The Alchemist', 192, 219),
#  ('Realword', 193, 110),
#  ('First Time I Met The Blues', 194, 219),
#  ('Let Me Love You Baby', 195, 325),
#  ('Stone Crazy', 196, 219),
#  ('Pretty Baby', 197, None),
#  ('When My Left Eye Jumps', 198, 5),
#  ('When My Left Eye Jumps', 198, 219),
#  ('Leave My Girl Alone', 199, 325),
#  ('She Suits Me To A Tee', 200, None),
#  ('Keep It To Myself (Aka Keep It To Yourself)', 201, None),
#  ('My Time After Awhile', 202, 220),
#  ('Too Many Ways (Alternate)', 203, None),
#  ("Talkin' 'Bout Women Obviously", 204, None),
#  ('Jorge Da Capadócia', 205, 326),
#  ('Prenda Minha', 206, 220),
#  ('Meditação', 207, 5),
#  ('Meditação', 207, 111),
#  ('Terra', 208, 112),
#  ('Eclipse Oculto', 209, 112),
#  ('Texto "Verdade Tropical"', 210, 220),
#  ('Bem Devagar', 211, 113),
#  ('Bem Devagar', 211, 326),
#  ('Drão', 212, None),
#  ('Saudosismo', 213, 113),
#  ('Carolina', 214, 220),
#  ('Sozinho', 215, 114),
#  ('Esse Cara', 216, 5),
#  ('Mel', 217, 114),
#  ('Mel', 217, 326),
#  ('Linha Do Equador', 218, 220),
#  ('Odara', 219, 114),
#  ('A Luz De Tieta', 220, None),
#  ('Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', 221, 114),
#  ('Vida Boa', 222, 220),
#  ('Sozinho (Hitmakers Classic Mix)', 223, 326),
#  ('Sozinho (Hitmakers Classic Radio Edit)', 224, None),
#  ("Sozinho (Caêdrum 'n' Bass)", 225, 115),
#  ('Carolina', 226, None),
#  ('Essa Moça Ta Diferente', 227, None),
#  ('Vai Passar', 228, 221),
#  ('Samba De Orly', 229, 115),
#  ('Samba De Orly', 229, 326),
#  ('Bye, Bye Brasil', 230, 6),
#  ('Atras Da Porta', 231, 7),
#  ('Tatuagem', 232, 7),
#  ('O Que Será (À Flor Da Terra)', 233, 115),
#  ('Morena De Angola', 234, 8),
#  ('Morena De Angola', 234, 221),
#  ('Apesar De Você', 235, 326),
#  ('A Banda', 236, 8),
#  ('Minha Historia', 237, 115),
#  ('Com Açúcar E Com Afeto', 238, 9),
#  ('Brejo Da Cruz', 239, None),
#  ('Meu Caro Amigo', 240, 9),
#  ('Meu Caro Amigo', 240, 221),
#  ('Geni E O Zepelim', 241, 115),
#  ('Geni E O Zepelim', 241, 326),
#  ('Trocando Em Miúdos', 242, 9),
#  ('Vai Trabalhar Vagabundo', 243, None),
#  ("Gota D'água", 244, 9),
#  ('Construção / Deus Lhe Pague', 245, 115),
#  ('Mateus Enter', 246, 221),
#  ('O Cidadão Do Mundo', 247, 326),
#  ('Etnia', 248, 10),
#  ('Quilombo Groove [Instrumental]', 249, None),
#  ('Macô', 250, None),
#  ('Um Passeio No Mundo Livre', 251, 116),
#  ('Samba Do Lado', 252, 10),
#  ('Samba Do Lado', 252, 221),
#  ('Maracatu Atômico', 253, 326),
#  ('O Encontro De Isaac Asimov Com Santos Dumont No Céu', 254, None),
#  ('Corpo De Lama', 255, None),
#  ('Sobremesa', 256, 10),
#  ('Manguetown', 257, 116),
#  ('Um Satélite Na Cabeça', 258, 221),
#  ('Baião Ambiental [Instrumental]', 259, None),
#  ('Sangue De Bairro', 260, 10),
#  ('Enquanto O Mundo Explode', 261, None),
#  ('Interlude Zumbi', 262, 327),
#  ('Criança De Domingo', 263, 116),
#  ('Amor De Muito', 264, 10),
#  ('Amor De Muito', 264, 221),
#  ('Samidarish [Instrumental]', 265, None),
#  ('Maracatu Atômico [Atomic Version]', 266, None),
#  ('Maracatu Atômico [Ragga Mix]', 267, None),
#  ('Maracatu Atômico [Trip Hop]', 268, 10),
#  ('Banditismo Por Uma Questa', 269, 116),
#  ('Banditismo Por Uma Questa', 270, 221),
#  ('Rios Pontes & Overdrives', 271, 327),
#  ('Cidade', 272, None),
#  ('Praiera', 273, None),
#  ('Samba Makossa', 274, 11),
#  ('Da Lama Ao Caos', 275, 116),
#  ('Maracatu De Tiro Certeiro', 276, 221),
#  ('Salustiano Song', 277, None),
#  ('Antene Se', 278, None),
#  ('Risoflora', 279, None),
#  ('Lixo Do Mangue', 280, 11),
#  ('Lixo Do Mangue', 280, 327),
#  ('Computadores Fazem Arte', 281, 116),
#  ('Girassol', 282, None),
#  ('A Sombra Da Maldade', 283, None),
#  ('Johnny B. Goode', 284, None),
#  ('Soldado Da Paz', 285, 222),
#  ('Firmamento', 286, 11),
#  ('Extra', 287, 116),
#  ('O Erê', 288, None),
#  ('Podes Crer', 289, 327),
#  ('A Estrada', 290, None),
#  ('Berlim', 291, None),
#  ('Já Foi', 292, 11),
#  ('Onde Você Mora?', 293, 116),
#  ('Pensamento', 294, 222),
#  ('Conciliação', 295, None),
#  ('Realidade Virtual', 296, None),
#  ('Mensagem', 297, None),
#  ('A Cor Do Sol', 298, 11),
#  ('A Cor Do Sol', 298, 327),
#  ('Onde Você Mora?', 299, 116),
#  ('O Erê', 300, None),
#  ('A Sombra Da Maldade', 301, None),
#  ('A Estrada', 302, None),
#  ('Falar A Verdade', 303, 222),
#  ('Firmamento', 304, 11),
#  ('Pensamento', 305, None),
#  ('Realidade Virtual', 306, None),
#  ('Doutor', 307, 327),
#  ('Na Frente Da TV', 308, 117),
#  ('Downtown', 309, None),
#  ('Sábado A Noite', 310, 11),
#  ('A Cor Do Sol', 311, None),
#  ('Eu Também Quero Beijar', 312, 222),
#  ('Noite Do Prazer', 313, None),
#  ('À Francesa', 314, None),
#  ('Cada Um Cada Um (A Namoradeira)', 315, None),
#  ('Linha Do Equador', 316, 11),
#  ('Linha Do Equador', 316, 327),
#  ('Amor Demais', 317, 117),
#  ('Férias', 318, None),
#  ('Gostava Tanto De Você', 319, None),
#  ('Flor Do Futuro', 320, None),
#  ('Felicidade Urgente', 321, 222),
#  ('Livre Pra Viver', 322, 11),
#  ('Dig-Dig, Lambe-Lambe (Ao Vivo)', 323, None),
#  ('Pererê', 324, None),
#  ('TriboTchan', 325, 327),
#  ('Tapa Aqui, Descobre Ali', 326, 117),
#  ('Daniela', 327, None),
#  ('Bate Lata', 328, None),
#  ('Garotas do Brasil', 329, None),
#  ('Levada do Amor (Ailoviu)', 330, 222),
#  ('Lavadeira', 331, 12),
#  ('Reboladeira', 332, None),
#  ('É que Nessa Encarnação Eu Nasci Manga', 333, None),
#  ('Reggae Tchan', 334, 327),
#  ('My Love', 335, 117),
#  ('Latinha de Cerveja', 336, None),
#  ('You Shook Me', 337, None),
#  ("I Can't Quit You Baby", 338, None),
#  ('Communication Breakdown', 339, 222),
#  ('Dazed and Confused', 340, 12),
#  ('The Girl I Love She Got Long Black Wavy Hair', 341, None),
#  ('What is and Should Never Be', 342, None),
#  ('Communication Breakdown(2)', 343, 327),
#  ('Travelling Riverside Blues', 344, 117),
#  ('Whole Lotta Love', 345, None),
#  ("Somethin' Else", 346, None),
#  ('Communication Breakdown(3)', 347, None),
#  ("I Can't Quit You Baby(2)", 348, 222),
#  ('You Shook Me(2)', 349, 12),
#  ('How Many More Times', 350, None),
#  ('Debra Kadabra', 351, None),
#  ('Carolina Hard-Core Ecstasy', 352, 327),
#  ('Sam With The Showing Scalp Flat Top', 353, 117),
#  ("Poofter's Froth Wyoming Plans Ahead", 354, None),
#  ('200 Years Old', 355, None),
#  ('Cucamonga', 356, None),
#  ('Advance Romance', 357, 222),
#  ('Man With The Woman Head', 358, 12),
#  ('Muffin Man', 359, None),
#  ('Vai-Vai 2001', 360, None),
#  ('X-9 2001', 361, 327),
#  ('Gavioes 2001', 362, 117),
#  ('Nene 2001', 363, None),
#  ('Rosas De Ouro 2001', 364, None),
#  ('Mocidade Alegre 2001', 365, None),
#  ('Camisa Verde 2001', 366, 222),
#  ('Leandro De Itaquera 2001', 367, 12),
#  ('Tucuruvi 2001', 368, None),
#  ('Aguia De Ouro 2001', 369, None),
#  ('Ipiranga 2001', 370, 327),
#  ('Morro Da Casa Verde 2001', 371, 117),
#  ('Perola Negra 2001', 372, None),
#  ('Sao Lucas 2001', 373, None),
#  ('Guanabara', 374, None),
#  ('Mas Que Nada', 375, 222),
#  ('Vôo Sobre o Horizonte', 376, 12),
#  ('A Paz', 377, None),
#  ('Wave (Vou te Contar)', 378, None),
#  ('Água de Beber', 379, 327),
#  ('Samba da Bençaco', 380, 117),
#  ('Pode Parar', 381, None),
#  ('Menino do Rio', 382, None),
#  ('Ando Meio Desligado', 383, None),
#  ('Mistério da Raça', 384, 222),
#  ('All Star', 385, 12),
#  ('Menina Bonita', 386, None),
#  ('Pescador de Ilusões', 387, None),
#  ('À Vontade (Live Mix)', 388, None),
#  ('Maria Fumaça', 389, 117),
#  ('Sambassim (dj patife remix)', 390, None),
#  ('Garota De Ipanema', 391, None),
#  ('Tim Tim Por Tim Tim', 392, None),
#  ('Tarde Em Itapoã', 393, 222),
#  ('Tarde Em Itapoã', 393, 328),
#  ('Tanto Tempo', 394, 12),
#  ('Tanto Tempo', 394, 329),
#  ('Eu Vim Da Bahia - Live', 395, 329),
#  ('Alô Alô Marciano', 396, None),
#  ('Linha Do Horizonte', 397, 330),
#  ('Only A Dream In Rio', 398, 117),
#  ('Abrir A Porta', 399, 330),
#  ('Alice', 400, None),
#  ('Momentos Que Marcam', 401, 331),
#  ('Um Jantar Pra Dois', 402, 222),
#  ('Bumbo Da Mangueira', 403, 12),
#  ('Bumbo Da Mangueira', 403, 331),
#  ('Mr Funk Samba', 404, None),
#  ('Santo Antonio', 405, 331),
#  ('Por Você', 406, None),
#  ('Só Tinha De Ser Com Você', 407, 117),
#  ('Só Tinha De Ser Com Você', 407, 331),
#  ('Free Speech For The Dumb', 408, None),
#  ("It's Electric", 409, None),
#  ('Sabbra Cadabra', 410, None),
#  ('Turn The Page', 411, 332),
#  ('Die Die My Darling', 412, 12),
#  ('Loverman', 413, None),
#  ('Mercyful Fate', 414, None),
#  ('Astronomy', 415, 332),
#  ('Whiskey In The Jar', 416, 117),
#  ('Whiskey In The Jar', 416, 223),
#  ("Tuesday's Gone", 417, 224),
#  ('The More I See', 418, 224),
#  ('A Kind Of Magic', 419, 332),
#  ('Under Pressure', 420, 225),
#  ('Radio GA GA', 421, 12),
#  ('I Want It All', 422, 225),
#  ('I Want To Break Free', 423, 332),
#  ('Innuendo', 424, 226),
#  ("It's A Hard Life", 425, 117),
#  ('Breakthru', 426, 226),
#  ('Who Wants To Live Forever', 427, 332),
#  ('Headlong', 428, 226),
#  ('The Miracle', 429, None),
#  ("I'm Going Slightly Mad", 430, 12),
#  ("I'm Going Slightly Mad", 430, 226),
#  ('The Invisible Man', 431, 332),
#  ('Hammer To Fall', 432, None),
#  ('Friends Will Be Friends', 433, None),
#  ('The Show Must Go On', 434, 227),
#  ('One Vision', 435, None),
#  ('Detroit Rock City', 436, None),
#  ('Black Diamond', 437, 333),
#  ('Hard Luck Woman', 438, 227),
#  ('Sure Know Something', 439, 12),
#  ('Sure Know Something', 439, 118),
#  ('Love Gun', 440, 119),
#  ('Deuce', 441, 119),
#  ("Goin' Blind", 442, 227),
#  ('Shock Me', 443, 120),
#  ('Shock Me', 443, 333),
#  ('Do You Love Me', 444, None),
#  ('She', 445, 120),
#  ('I Was Made For Loving You', 446, 227),
#  ('Shout It Out Loud', 447, 121),
#  ('God Of Thunder', 448, 12),
#  ('Calling Dr. Love', 449, 121),
#  ('Calling Dr. Love', 449, 333),
#  ('Beth', 450, 227),
#  ('Strutter', 451, 121),
#  ('Rock And Roll All Nite', 452, None),
#  ('Cold Gin', 453, 121),
#  ('Plaster Caster', 454, 227),
#  ("God Gave Rock 'n' Roll To You", 455, 333),
#  ('Heart of the Night', 456, None),
#  ('De La Luz', 457, 122),
#  ('Westwood Moon', 458, None),
#  ('Midnight', 459, None),
#  ('Playtime', 460, 228),
#  ('Surrender', 461, 122),
#  ('Surrender', 461, 333),
#  ("Valentino's", 462, 13),
#  ('Believe', 463, 14),
#  ('As We Sleep', 464, 14),
#  ('When Evening Falls', 465, 122),
#  ('J Squared', 466, 15),
#  ('J Squared', 466, 228),
#  ('Best Thing', 467, 333),
#  ('Maria', 468, 15),
#  ('Poprocks And Coke', 469, 122),
#  ('Longview', 470, 16),
#  ('Welcome To Paradise', 471, None),
#  ('Basket Case', 472, 16),
#  ('Basket Case', 472, 228),
#  ('When I Come Around', 473, 122),
#  ('When I Come Around', 473, 333),
#  ('She', 474, 16),
#  ('J.A.R. (Jason Andrew Relva)', 475, None),
#  ('Geek Stink Breath', 476, 16),
#  ('Brain Stew', 477, 122),
#  ('Jaded', 478, 228),
#  ('Walking Contradiction', 479, 333),
#  ('Stuck With Me', 480, 17),
#  ("Hitchin' A Ride", 481, None),
#  ('Good Riddance (Time Of Your Life)', 482, None),
#  ('Redundant', 483, 123),
#  ('Nice Guys Finish Last', 484, 17),
#  ('Nice Guys Finish Last', 484, 228),
#  ('Minority', 485, 333),
#  ('Warning', 486, None),
#  ('Waiting', 487, None),
#  ("Macy's Day Parade", 488, 17),
#  ('Into The Light', 489, 123),
#  ('River Song', 490, 228),
#  ('She Give Me ...', 491, None),
#  ("Don't You Cry", 492, 17),
#  ('Love Is Blind', 493, None),
#  ('Slave', 494, 334),
#  ('Cry For Love', 495, 123),
#  ('Living On Love', 496, 17),
#  ('Living On Love', 496, 228),
#  ('Midnight Blue', 497, None),
#  ('Too Many Tears', 498, None),
#  ("Don't Lie To Me", 499, None),
#  ('Wherever You May Go', 500, 17),
#  ('Grito De Alerta', 501, 123),
#  ('Não Dá Mais Pra Segurar (Explode Coração)', 502, 228),
#  ('Começaria Tudo Outra Vez', 503, 334),
#  ('O Que É O Que É ?', 504, None),
#  ('Sangrando', 505, None),
#  ('Diga Lá, Coração', 506, 18),
#  ('Lindo Lago Do Amor', 507, 123),
#  ('Eu Apenas Queria Que Voçê Soubesse', 508, 228),
#  ('Com A Perna No Mundo', 509, None),
#  ('E Vamos À Luta', 510, None),
#  ('Um Homem Também Chora (Guerreiro Menino)', 511, None),
#  ('Comportamento Geral', 512, 18),
#  ('Comportamento Geral', 512, 334),
#  ('Ponto De Interrogação', 513, 123),
#  ('Espere Por Mim, Morena', 514, None),
#  ('Meia-Lua Inteira', 515, None),
#  ('Voce e Linda', 516, None),
#  ('Um Indio', 517, 229),
#  ('Podres Poderes', 518, 18),
#  ('Voce Nao Entende Nada - Cotidiano', 519, 123),
#  ('O Estrangeiro', 520, None),
#  ('Menino Do Rio', 521, 334),
#  ('Qualquer Coisa', 522, None),
#  ('Sampa', 523, None),
#  ('Queixa', 524, 18),
#  ('O Leaozinho', 525, 123),
#  ('Fora Da Ordem', 526, 229),
#  ('Terra', 527, None),
#  ('Alegria, Alegria', 528, None),
#  ('Balada Do Louco', 529, None),
#  ('Ando Meio Desligado', 530, 18),
#  ('Ando Meio Desligado', 530, 334),
#  ('Top Top', 531, 123),
#  ('Baby', 532, None),
#  ('A E O Z', 533, None),
#  ('Panis Et Circenses', 534, None),
#  ('Chão De Estrelas', 535, 229),
#  ('Vida De Cachorro', 536, 18),
#  ('Bat Macumba', 537, None),
#  ('Desculpe Babe', 538, None),
#  ('Rita Lee', 539, 334),
#  ('Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll', 540, 124),
#  ('Banho De Lua', 541, None),
#  ('Meu Refrigerador Não Funciona', 542, 18),
#  ('Burn', 543, None),
#  ('Stormbringer', 544, 229),
#  ('Gypsy', 545, None),
#  ('Lady Double Dealer', 546, None),
#  ('Mistreated', 547, None),
#  ('Smoke On The Water', 548, 18),
#  ('Smoke On The Water', 548, 334),
#  ('You Fool No One', 549, 124),
#  ('Custard Pie', 550, None),
#  ('The Rover', 551, None),
#  ('In My Time Of Dying', 552, None),
#  ('Houses Of The Holy', 553, 229),
#  ('Trampled Under Foot', 554, 18),
#  ('Kashmir', 555, None),
#  ('Imperatriz', 556, None),
#  ('Beija-Flor', 557, 334),
#  ('Viradouro', 558, 124),
#  ('Mocidade', 559, None),
#  ('Unidos Da Tijuca', 560, None),
#  ('Salgueiro', 561, None),
#  ('Mangueira', 562, 229),
#  ('União Da Ilha', 563, 19),
#  ('Grande Rio', 564, None),
#  ('Portela', 565, None),
#  ('Caprichosos', 566, 334),
#  ('Tradição', 567, 124),
#  ('Império Serrano', 568, None),
#  ('Tuiuti', 569, None),
#  ('(Da Le) Yaleo', 570, None),
#  ('Love Of My Life', 571, 229),
#  ('Put Your Lights On', 572, 19),
#  ('Africa Bamba', 573, None),
#  ('Smooth', 574, None),
#  ('Do You Like The Way', 575, 334),
#  ('Maria Maria', 576, 124),
#  ('Migra', 577, None),
#  ('Corazon Espinado', 578, None),
#  ('Wishing It Was', 579, None),
#  ('El Farol', 580, 229),
#  ('Primavera', 581, 19),
#  ('The Calling', 582, None),
#  ('Solução', 583, None),
#  ('Manuel', 584, 334),
#  ('Entre E Ouça', 585, 124),
#  ('Um Contrato Com Deus', 586, None),
#  ('Um Jantar Pra Dois', 587, None),
#  ('Vamos Dançar', 588, None),
#  ('Um Love', 589, 229),
#  ('Seis Da Tarde', 590, 19),
#  ('Baixo Rio', 591, None),
#  ('Sombras Do Meu Destino', 592, None),
#  ('Do You Have Other Loves?', 593, 334),
#  ('Agora Que O Dia Acordou', 594, 124),
#  ('Já!!!', 595, None),
#  ('A Rua', 596, None),
#  ("Now's The Time", 597, None),
#  ('Jeru', 598, 229),
#  ('Compulsion', 599, 19),
#  ('Tempus Fugit', 600, None),
#  ("Walkin'", 601, None),
#  ("'Round Midnight", 602, 334),
#  ('Bye Bye Blackbird', 603, 124),
#  ('New Rhumba', 604, None),
#  ('Generique', 605, None),
#  ('Summertime', 606, None),
#  ('So What', 607, 229),
#  ('The Pan Piper', 608, 19),
#  ('Someday My Prince Will Come', 609, None),
#  ('My Funny Valentine (Live)', 610, None),
#  ('E.S.P.', 611, 334),
#  ('Nefertiti', 612, 124),
#  ('Petits Machins (Little Stuff)', 613, None),
#  ('Miles Runs The Voodoo Down', 614, None),
#  ('Little Church (Live)', 615, None),
#  ('Black Satin', 616, 229),
#  ('Jean Pierre (Live)', 617, 19),
#  ('Time After Time', 618, None),
#  ('Portia', 619, None),
#  ("Space Truckin'", 620, None),
#  ('Going Down / Highway Star', 621, 124),
#  ('Mistreated (Alternate Version)', 622, None),
#  ('You Fool No One (Alternate Version)', 623, None),
#  ('Jeepers Creepers', 624, None),
#  ('Blue Rythm Fantasy', 625, 229),
#  ('Blue Rythm Fantasy', 625, 335),
#  ('Drum Boogie', 626, 19),
#  ('Drum Boogie', 626, 336),
#  ('Let Me Off Uptown', 627, 336),
#  ('Leave Us Leap', 628, None),
#  ('Opus No.1', 629, 337),
#  ('Boogie Blues', 630, 124),
#  ('How High The Moon', 631, 337),
#  ('Disc Jockey Jump', 632, None),
#  ("Up An' Atom", 633, 338),
#  ('Bop Boogie', 634, 229),
#  ('Lemon Drop', 635, 19),
#  ('Lemon Drop', 635, 338),
#  ('Coronation Drop', 636, None),
#  ('Overtime', 637, 338),
#  ('Imagination', 638, None),
#  ("Don't Take Your Love From Me", 639, 124),
#  ("Don't Take Your Love From Me", 639, 338),
#  ('Midget', 640, None),
#  ("I'm Coming Virginia", 641, None),
#  ("Payin' Them Dues Blues", 642, None),
#  ('Jungle Drums', 643, 339),
#  ('Showcase', 644, 19),
#  ('Swedish Schnapps', 645, None),
#  ('Samba Da Bênção', 646, None),
#  ('Pot-Pourri N.º 4', 647, 339),
#  ('Onde Anda Você', 648, 124),
#  ('Onde Anda Você', 648, 230),
#  ('Samba Da Volta', 649, 231),
#  ('Canto De Ossanha', 650, 231),
#  ('Pot-Pourri N.º 5', 651, 339),
#  ('Formosa', 652, 232),
#  ('Como É Duro Trabalhar', 653, 19),
#  ('Minha Namorada', 654, 232),
#  ('Por Que Será', 655, 339),
#  ('Berimbau', 656, 233),
#  ('Deixa', 657, 124),
#  ('Pot-Pourri N.º 2', 658, 233),
#  ('Samba Em Prelúdio', 659, 339),
#  ('Carta Ao Tom 74', 660, 233),
#  ('Linha de Passe (João Bosco)', 661, None),
#  ('Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)', 662, 19),
#  ('Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)', 662, 233),
#  ('Chão de Giz (Elba Ramalho)', 663, 339),
#  ('Marina (Dorival Caymmi)', 664, None),
#  ('Aquarela (Toquinho)', 665, None),
#  ('Coração do Agreste (Fafá de Belém)', 666, 234),
#  ('Dona (Roupa Nova)', 667, None),
#  ('Começaria Tudo Outra Vez (Maria Creuza)', 668, None),
#  ('Caçador de Mim (Sá & Guarabyra)', 669, 340),
#  ('Romaria (Renato Teixeira)', 670, 234),
#  ('As Rosas Não Falam (Beth Carvalho)', 671, 19),
#  ('As Rosas Não Falam (Beth Carvalho)', 671, 125),
#  ('Wave (Os Cariocas)', 672, 126),
#  ('Garota de Ipanema (Dick Farney)', 673, 126),
#  ('Preciso Apender a Viver Só (Maysa)', 674, 234),
#  ('Susie Q', 675, 127),
#  ('Susie Q', 675, 340),
#  ('I Put A Spell On You', 676, None),
#  ('Proud Mary', 677, 127),
#  ('Bad Moon Rising', 678, 234),
#  ('Lodi', 679, 128),
#  ('Green River', 680, 19),
#  ('Commotion', 681, 128),
#  ('Commotion', 681, 340),
#  ('Down On The Corner', 682, 234),
#  ('Fortunate Son', 683, 128),
#  ("Travelin' Band", 684, None),
#  ("Who'll Stop The Rain", 685, 128),
#  ('Up Around The Bend', 686, 234),
#  ('Run Through The Jungle', 687, 340),
#  ("Lookin' Out My Back Door", 688, None),
#  ('Long As I Can See The Light', 689, 129),
#  ('I Heard It Through The Grapevine', 690, None),
#  ('Have You Ever Seen The Rain?', 691, None),
#  ('Hey Tonight', 692, 235),
#  ('Sweet Hitch-Hiker', 693, 129),
#  ('Sweet Hitch-Hiker', 693, 340),
#  ('Someday Never Comes', 694, 20),
#  ('Walking On The Water', 695, 21),
#  ('Suzie-Q, Pt. 2', 696, 21),
#  ('Born On The Bayou', 697, 129),
#  ('Good Golly Miss Molly', 698, 22),
#  ('Good Golly Miss Molly', 698, 235),
#  ('Tombstone Shadow', 699, 340),
#  ('Wrote A Song For Everyone', 700, 22),
#  ('Night Time Is The Right Time', 701, 129),
#  ('Cotton Fields', 702, 23),
#  ('It Came Out Of The Sky', 703, None),
#  ("Don't Look Now", 704, 23),
#  ("Don't Look Now", 704, 235),
#  ('The Midnight Special', 705, 129),
#  ('The Midnight Special', 705, 340),
#  ('Before You Accuse Me', 706, 23),
#  ('My Baby Left Me', 707, None),
#  ('Pagan Baby', 708, 23),
#  ('(Wish I Could) Hideaway', 709, 129),
#  ("It's Just A Thought", 710, 235),
#  ('Molina', 711, 340),
#  ('Born To Move', 712, 24),
#  ("Lookin' For A Reason", 713, None),
#  ('Hello Mary Lou', 714, None),
#  ('Gatas Extraordinárias', 715, 130),
#  ('Brasil', 716, 24),
#  ('Brasil', 716, 235),
#  ('Eu Sou Neguinha (Ao Vivo)', 717, 340),
#  ('Geração Coca-Cola (Ao Vivo)', 718, None),
#  ('Lanterna Dos Afogados', 719, None),
#  ('Coroné Antonio Bento', 720, 24),
#  ('Você Passa, Eu Acho Graça (Ao Vivo)', 721, 130),
#  ('Meu Mundo Fica Completo (Com Você)', 722, 235),
#  ('1° De Julho', 723, None),
#  ('Música Urbana 2', 724, 24),
#  ('Vida Bandida (Ao Vivo)', 725, None),
#  ('Palavras Ao Vento', 726, 341),
#  ('Não Sei O Que Eu Quero Da Vida', 727, 130),
#  ('Woman Is The Nigger Of The World (Ao Vivo)', 728, 24),
#  ('Woman Is The Nigger Of The World (Ao Vivo)', 728, 235),
#  ('Juventude Transviada (Ao Vivo)', 729, None),
#  ('Malandragem', 730, None),
#  ('O Segundo Sol', 731, None),
#  ('Smells Like Teen Spirit (Ao Vivo)', 732, 24),
#  ('E.C.T.', 733, 130),
#  ('Todo Amor Que Houver Nesta Vida', 734, 235),
#  ('Metrô. Linha 743', 735, 341),
#  ('Nós (Ao Vivo)', 736, None),
#  ('Na Cadência Do Samba', 737, None),
#  ('Admirável Gado Novo', 738, 25),
#  ('Eleanor Rigby', 739, 130),
#  ('Socorro', 740, 235),
#  ('Blues Da Piedade', 741, None),
#  ('Rubens', 742, None),
#  ('Não Deixe O Samba Morrer - Cassia Eller e Alcione', 743, None),
#  ('Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', 744, 25),
#  ('Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', 744, 341),
#  ("Comin' Home", 745, 130),
#  ('Lady Luck', 746, None),
#  ("Gettin' Tighter", 747, None),
#  ('Dealer', 748, None),
#  ('I Need Love', 749, 236),
#  ('Drifter', 750, 25),
#  ('Love Child', 751, 130),
#  ("This Time Around / Owed to 'G' [Instrumental]", 752, None),
#  ('You Keep On Moving', 753, 341),
#  ('Speed King', 754, None),
#  ('Bloodsucker', 755, None),
#  ('Child In Time', 756, 25),
#  ('Flight Of The Rat', 757, 130),
#  ('Into The Fire', 758, 236),
#  ('Living Wreck', 759, None),
#  ("Hard Lovin' Man", 760, None),
#  ('Fireball', 761, None),
#  ('No No No', 762, 25),
#  ('No No No', 762, 341),
#  ('Strange Kind Of Woman', 763, 130),
#  ("Anyone's Daughter", 764, None),
#  ('The Mule', 765, None),
#  ('Fools', 766, None),
#  ('No One Came', 767, 236),
#  ('Knocking At Your Back Door', 768, 25),
#  ('Bad Attitude', 769, None),
#  ('Child In Time (Son Of Aleric - Instrumental)', 770, None),
#  ("Nobody's Home", 771, 341),
#  ('Black Night', 772, 131),
#  ('Perfect Strangers', 773, None),
#  ('The Unwritten Law', 774, 25),
#  ('Call Of The Wild', 775, None),
#  ('Hush', 776, 236),
#  ('Smoke On The Water', 777, None),
#  ('Space Trucking', 778, None),
#  ('Highway Star', 779, None),
#  ("Maybe I'm A Leo", 780, 25),
#  ("Maybe I'm A Leo", 780, 341),
#  ('Pictures Of Home', 781, 131),
#  ('Never Before', 782, None),
#  ('Smoke On The Water', 783, None),
#  ('Lazy', 784, None),
#  ("Space Truckin'", 785, 236),
#  ('Vavoom : Ted The Mechanic', 786, 25),
#  ('Loosen My Strings', 787, None),
#  ('Soon Forgotten', 788, None),
#  ('Sometimes I Feel Like Screaming', 789, 341),
#  ("Cascades : I'm Not Your Lover", 790, 131),
#  ('The Aviator', 791, None),
#  ("Rosa's Cantina", 792, None),
#  ('A Castle Full Of Rascals', 793, None),
#  ('A Touch Away', 794, 236),
#  ('Hey Cisco', 795, 26),
#  ('Somebody Stole My Guitar', 796, None),
#  ('The Purpendicular Waltz', 797, None),
#  ('King Of Dreams', 798, 341),
#  ('The Cut Runs Deep', 799, 131),
#  ('Fire In The Basement', 800, None),
#  ('Truth Hurts', 801, None),
#  ('Breakfast In Bed', 802, None),
#  ('Love Conquers All', 803, 236),
#  ('Fortuneteller', 804, 26),
#  ('Too Much Is Not Enough', 805, None),
#  ('Wicked Ways', 806, None),
#  ('Stormbringer', 807, 341),
#  ("Love Don't Mean a Thing", 808, 131),
#  ('Holy Man', 809, None),
#  ('Hold On', 810, None),
#  ('Lady Double Dealer', 811, None),
#  ("You Can't Do it Right (With the One You Love)", 812, 236),
#  ('High Ball Shooter', 813, 26),
#  ('The Gypsy', 814, None),
#  ('Soldier Of Fortune', 815, None),
#  ('The Battle Rages On', 816, 341),
#  ('Lick It Up', 817, 131),
#  ('Anya', 818, None),
#  ('Talk About Love', 819, None),
#  ('Time To Kill', 820, None),
#  ('Ramshackle Man', 821, 236),
#  ('A Twist In The Tail', 822, 26),
#  ('Nasty Piece Of Work', 823, None),
#  ('Solitaire', 824, None),
#  ("One Man's Meat", 825, 341),
#  ('Pour Some Sugar On Me', 826, 131),
#  ('Photograph', 827, None),
#  ('Love Bites', 828, None),
#  ("Let's Get Rocked", 829, None),
#  ('Two Steps Behind [Acoustic Version]', 830, 236),
#  ('Animal', 831, 26),
#  ('Heaven Is', 832, None),
#  ('Rocket', 833, None),
#  ('When Love & Hate Collide', 834, 341),
#  ('Action', 835, 131),
#  ('Make Love Like A Man', 836, None),
#  ('Armageddon It', 837, None),
#  ('Have You Ever Needed Someone So Bad', 838, None),
#  ('Rock Of Ages', 839, 236),
#  ('Hysteria', 840, 26),
#  ("Bringin' On The Heartbreak", 841, None),
#  ('Roll Call', 842, None),
#  ('Otay', 843, 341),
#  ('Groovus Interruptus', 844, 131),
#  ('Paris On Mine', 845, None),
#  ('In Time', 846, None),
#  ('Plan B', 847, None),
#  ('Outbreak', 848, 236),
#  ('Baltimore, DC', 849, 26),
#  ('Talkin Loud and Saying Nothin', 850, None),
#  ('Pétala', 851, None),
#  ('Meu Bem-Querer', 852, None),
#  ('Cigano', 853, 131),
#  ('Boa Noite', 854, None),
#  ('Fato Consumado', 855, None),
#  ('Faltando Um Pedaço', 856, None),
#  ('Álibi', 857, 236),
#  ('Álibi', 857, 342),
#  ('Esquinas', 858, 26),
#  ('Esquinas', 858, 343),
#  ('Se...', 859, 343),
#  ('Eu Te Devoro', 860, None),
#  ('Lilás', 861, 344),
#  ('Acelerou', 862, 131),
#  ('Um Amor Puro', 863, 344),
#  ('Samurai', 864, None),
#  ('Nem Um Dia', 865, 345),
#  ('Oceano', 866, 236),
#  ('Açai', 867, 26),
#  ('Açai', 867, 345),
#  ('Serrado', 868, None),
#  ('Flor De Lis', 869, 345),
#  ('Amar É Tudo', 870, None),
#  ('Azul', 871, 131),
#  ('Azul', 871, 345),
#  ('Seduzir', 872, None),
#  ('A Carta', 873, None),
#  ('Sina', 874, None),
#  ('Acelerou', 875, 346),
#  ('Um Amor Puro', 876, 26),
#  ('O Bêbado e a Equilibrista', 877, None),
#  ('O Mestre-Sala dos Mares', 878, None),
#  ('Atrás da Porta', 879, 346),
#  ('Dois Pra Lá, Dois Pra Cá', 880, 131),
#  ('Dois Pra Lá, Dois Pra Cá', 880, 237),
#  ('Casa no Campo', 881, 238),
#  ('Romaria', 882, 238),
#  ('Alô, Alô, Marciano', 883, 346),
#  ('Me Deixas Louca', 884, 239),
#  ('Fascinação', 885, 26),
#  ('Saudosa Maloca', 886, 239),
#  ('As Aparências Enganam', 887, 346),
#  ('Madalena', 888, 240),
#  ('Maria Rosa', 889, 131),
#  ('Aprendendo A Jogar', 890, 240),
#  ('Layla', 891, 346),
#  ('Badge', 892, 240),
#  ('I Feel Free', 893, None),
#  ('Sunshine Of Your Love', 894, 26),
#  ('Sunshine Of Your Love', 894, 240),
#  ('Crossroads', 895, 346),
#  ('Strange Brew', 896, None),
#  ('White Room', 897, None),
#  ('Bell Bottom Blues', 898, 241),
#  ('Cocaine', 899, None),
#  ('I Shot The Sheriff', 900, None),
#  ('After Midnight', 901, 347),
#  ('Swing Low Sweet Chariot', 902, 241),
#  ('Lay Down Sally', 903, 26),
#  ('Lay Down Sally', 903, 132),
#  ('Knockin On Heavens Door', 904, 133),
#  ('Wonderful Tonight', 905, 133),
#  ('Let It Grow', 906, 241),
#  ('Promises', 907, 134),
#  ('Promises', 907, 347),
#  ("I Can't Stand It", 908, None),
#  ('Signe', 909, 134),
#  ('Before You Accuse Me', 910, 241),
#  ('Hey Hey', 911, 135),
#  ('Tears In Heaven', 912, 26),
#  ('Lonely Stranger', 913, 135),
#  ('Lonely Stranger', 913, 347),
#  ("Nobody Knows You When You're Down & Out", 914, 241),
#  ('Layla', 915, 135),
#  ('Running On Faith', 916, None),
#  ("Walkin' Blues", 917, 135),
#  ('Alberta', 918, 241),
#  ('San Francisco Bay Blues', 919, 347),
#  ('Malted Milk', 920, None),
#  ('Old Love', 921, 136),
#  ("Rollin' And Tumblin'", 922, None),
#  ('Collision', 923, None),
#  ('Stripsearch', 924, 242),
#  ('Last Cup Of Sorrow', 925, 136),
#  ('Last Cup Of Sorrow', 925, 347),
#  ('Naked In Front Of The Computer', 926, 27),
#  ('Helpless', 927, 28),
#  ('Mouth To Mouth', 928, 28),
#  ...]

# %% [markdown]
# ### Exercise 4
#
# In the results, the tracks that have a value of `None` (i.e. `NULL`) for `InvoiceId` are the ones that have not been purchased yet. Add a `WHERE` clause to only focus on these 'unpopular' tracks.

# %%
# %%sql
#
# select t.Name, t.TrackId, ii.InvoiceId
# from tracks as t
# left join invoice_items as ii
# on t.TrackId = ii.TrackId
# where ii.InvoiceId is NULL
# Out:
#  * sqlite:///chinook.db
# Done.
# [("Let's Get It Up", 7, None),
#  ('C.O.D.', 11, None),
#  ('Let There Be Rock', 17, None),
#  ('Bad Boy Boogie', 18, None),
#  ('Whole Lotta Rosie', 22, None),
#  ('Walk On Water', 23, None),
#  ('Dude (Looks Like A Lady)', 27, None),
#  ("Cryin'", 29, None),
#  ('The Other Side', 33, None),
#  ('Crazy', 34, None),
#  ('Eat The Rich', 35, None),
#  ('Perfect', 40, None),
#  ('Hand In My Pocket', 41, None),
#  ('Head Over Feet', 45, None),
#  ('Mary Jane', 46, None),
#  ('Ironic', 47, None),
#  ('You Oughta Know (Alternate)', 50, None),
#  ('We Die Young', 51, None),
#  ('Man In The Box', 52, None),
#  ('Love, Hate, Love', 56, None),
#  ('Sunshine', 58, None),
#  ('Put You Down', 59, None),
#  ('Desafinado', 63, None),
#  ('Garota De Ipanema', 64, None),
#  ('Samba De Uma Nota Só (One Note Samba)', 65, None),
#  ('Fotografia', 68, None),
#  ('Dindi (Dindi)', 69, None),
#  ('Se Todos Fossem Iguais A Você (Instrumental)', 70, None),
#  ('Corcovado (Quiet Nights Of Quiet Stars)', 73, None),
#  ('Outra Vez', 74, None),
#  ('Enter Sandman', 77, None),
#  ('Harvester Of Sorrow', 79, None),
#  ('Sad But True', 81, None),
#  ('Creeping Death', 82, None),
#  ('Wherever I May Roam', 83, None),
#  ('Show Me How to Live', 86, None),
#  ('Gasoline', 87, None),
#  ('What You Are', 88, None),
#  ('Shadow on the Sun', 91, None),
#  ('I am the Highway', 92, None),
#  ("Bring'em Back Alive", 95, None),
#  ('Light My Way', 96, None),
#  ('Getaway Car', 97, None),
#  ('Out Of Exile', 100, None),
#  ('Be Yourself', 101, None),
#  ("Heaven's Dead", 104, None),
#  ('The Worm', 105, None),
#  ('Man Or Animal', 106, None),
#  ('#1 Zero', 109, None),
#  ('The Curse', 110, None),
#  ('Bad Boy', 113, None),
#  ('Twist And Shout', 114, None),
#  ('Please Mr. Postman', 115, None),
#  ('Slow Down', 118, None),
#  ('Roadrunner', 119, None),
#  ('20 Flight Rock', 122, None),
#  ('Quadrant', 123, None),
#  ("Snoopy's search-Red baron", 124, None),
#  ('Stratus', 127, None),
#  ('The pleasant pheasant', 128, None),
#  ('Intro/ Low Down', 131, None),
#  ('13 Years Of Grief', 132, None),
#  ('Stronger Than Death', 133, None),
#  ('Phoney Smile Fake Hellos', 136, None),
#  ('Lost My Better Half', 137, None),
#  ('Born To Booze', 140, None),
#  ('World Of Trouble', 141, None),
#  ('No More Tears', 142, None),
#  ('Snowblind', 145, None),
#  ('Like A Bird', 146, None),
#  ('Black Sabbath', 149, None),
#  ('The Wizard', 150, None),
#  ('Behind The Wall Of Sleep', 151, None),
#  ('Sleeping Village', 154, None),
#  ('Warning', 155, None),
#  ('Wheels Of Confusion / The Straightener', 156, None),
#  ('Changes', 158, None),
#  ('FX', 159, None),
#  ('Supernaut', 160, None),
#  ('St. Vitus Dance', 164, None),
#  ('Now Sports', 168, None),
#  ('The Real Problem', 172, None),
#  ('D Note', 174, None),
#  ('The Winner Loses', 176, None),
#  ('There Goes The Neighborhood', 177, None),
#  ('Oprah', 178, None),
#  ("Momma's Gotta Die Tonight", 181, None),
#  ('Freedom Of Speech', 182, None),
#  ('Pretty Baby', 197, None),
#  ('She Suits Me To A Tee', 200, None),
#  ('Keep It To Myself (Aka Keep It To Yourself)', 201, None),
#  ('Too Many Ways (Alternate)', 203, None),
#  ("Talkin' 'Bout Women Obviously", 204, None),
#  ('Drão', 212, None),
#  ('A Luz De Tieta', 220, None),
#  ('Sozinho (Hitmakers Classic Radio Edit)', 224, None),
#  ('Carolina', 226, None),
#  ('Essa Moça Ta Diferente', 227, None),
#  ('Brejo Da Cruz', 239, None),
#  ('Vai Trabalhar Vagabundo', 243, None),
#  ('Quilombo Groove [Instrumental]', 249, None),
#  ('Macô', 250, None),
#  ('O Encontro De Isaac Asimov Com Santos Dumont No Céu', 254, None),
#  ('Corpo De Lama', 255, None),
#  ('Baião Ambiental [Instrumental]', 259, None),
#  ('Enquanto O Mundo Explode', 261, None),
#  ('Samidarish [Instrumental]', 265, None),
#  ('Maracatu Atômico [Atomic Version]', 266, None),
#  ('Maracatu Atômico [Ragga Mix]', 267, None),
#  ('Cidade', 272, None),
#  ('Praiera', 273, None),
#  ('Salustiano Song', 277, None),
#  ('Antene Se', 278, None),
#  ('Risoflora', 279, None),
#  ('Girassol', 282, None),
#  ('A Sombra Da Maldade', 283, None),
#  ('Johnny B. Goode', 284, None),
#  ('O Erê', 288, None),
#  ('A Estrada', 290, None),
#  ('Berlim', 291, None),
#  ('Conciliação', 295, None),
#  ('Realidade Virtual', 296, None),
#  ('Mensagem', 297, None),
#  ('O Erê', 300, None),
#  ('A Sombra Da Maldade', 301, None),
#  ('A Estrada', 302, None),
#  ('Pensamento', 305, None),
#  ('Realidade Virtual', 306, None),
#  ('Downtown', 309, None),
#  ('A Cor Do Sol', 311, None),
#  ('Noite Do Prazer', 313, None),
#  ('À Francesa', 314, None),
#  ('Cada Um Cada Um (A Namoradeira)', 315, None),
#  ('Férias', 318, None),
#  ('Gostava Tanto De Você', 319, None),
#  ('Flor Do Futuro', 320, None),
#  ('Dig-Dig, Lambe-Lambe (Ao Vivo)', 323, None),
#  ('Pererê', 324, None),
#  ('Daniela', 327, None),
#  ('Bate Lata', 328, None),
#  ('Garotas do Brasil', 329, None),
#  ('Reboladeira', 332, None),
#  ('É que Nessa Encarnação Eu Nasci Manga', 333, None),
#  ('Latinha de Cerveja', 336, None),
#  ('You Shook Me', 337, None),
#  ("I Can't Quit You Baby", 338, None),
#  ('The Girl I Love She Got Long Black Wavy Hair', 341, None),
#  ('What is and Should Never Be', 342, None),
#  ('Whole Lotta Love', 345, None),
#  ("Somethin' Else", 346, None),
#  ('Communication Breakdown(3)', 347, None),
#  ('How Many More Times', 350, None),
#  ('Debra Kadabra', 351, None),
#  ("Poofter's Froth Wyoming Plans Ahead", 354, None),
#  ('200 Years Old', 355, None),
#  ('Cucamonga', 356, None),
#  ('Muffin Man', 359, None),
#  ('Vai-Vai 2001', 360, None),
#  ('Nene 2001', 363, None),
#  ('Rosas De Ouro 2001', 364, None),
#  ('Mocidade Alegre 2001', 365, None),
#  ('Tucuruvi 2001', 368, None),
#  ('Aguia De Ouro 2001', 369, None),
#  ('Perola Negra 2001', 372, None),
#  ('Sao Lucas 2001', 373, None),
#  ('Guanabara', 374, None),
#  ('A Paz', 377, None),
#  ('Wave (Vou te Contar)', 378, None),
#  ('Pode Parar', 381, None),
#  ('Menino do Rio', 382, None),
#  ('Ando Meio Desligado', 383, None),
#  ('Menina Bonita', 386, None),
#  ('Pescador de Ilusões', 387, None),
#  ('À Vontade (Live Mix)', 388, None),
#  ('Sambassim (dj patife remix)', 390, None),
#  ('Garota De Ipanema', 391, None),
#  ('Tim Tim Por Tim Tim', 392, None),
#  ('Alô Alô Marciano', 396, None),
#  ('Alice', 400, None),
#  ('Mr Funk Samba', 404, None),
#  ('Por Você', 406, None),
#  ('Free Speech For The Dumb', 408, None),
#  ("It's Electric", 409, None),
#  ('Sabbra Cadabra', 410, None),
#  ('Loverman', 413, None),
#  ('Mercyful Fate', 414, None),
#  ('The Miracle', 429, None),
#  ('Hammer To Fall', 432, None),
#  ('Friends Will Be Friends', 433, None),
#  ('One Vision', 435, None),
#  ('Detroit Rock City', 436, None),
#  ('Do You Love Me', 444, None),
#  ('Rock And Roll All Nite', 452, None),
#  ('Heart of the Night', 456, None),
#  ('Westwood Moon', 458, None),
#  ('Midnight', 459, None),
#  ('Welcome To Paradise', 471, None),
#  ('J.A.R. (Jason Andrew Relva)', 475, None),
#  ("Hitchin' A Ride", 481, None),
#  ('Good Riddance (Time Of Your Life)', 482, None),
#  ('Warning', 486, None),
#  ('Waiting', 487, None),
#  ('She Give Me ...', 491, None),
#  ('Love Is Blind', 493, None),
#  ('Midnight Blue', 497, None),
#  ('Too Many Tears', 498, None),
#  ("Don't Lie To Me", 499, None),
#  ('O Que É O Que É ?', 504, None),
#  ('Sangrando', 505, None),
#  ('Com A Perna No Mundo', 509, None),
#  ('E Vamos À Luta', 510, None),
#  ('Um Homem Também Chora (Guerreiro Menino)', 511, None),
#  ('Espere Por Mim, Morena', 514, None),
#  ('Meia-Lua Inteira', 515, None),
#  ('Voce e Linda', 516, None),
#  ('O Estrangeiro', 520, None),
#  ('Qualquer Coisa', 522, None),
#  ('Sampa', 523, None),
#  ('Terra', 527, None),
#  ('Alegria, Alegria', 528, None),
#  ('Balada Do Louco', 529, None),
#  ('Baby', 532, None),
#  ('A E O Z', 533, None),
#  ('Panis Et Circenses', 534, None),
#  ('Bat Macumba', 537, None),
#  ('Desculpe Babe', 538, None),
#  ('Banho De Lua', 541, None),
#  ('Burn', 543, None),
#  ('Gypsy', 545, None),
#  ('Lady Double Dealer', 546, None),
#  ('Mistreated', 547, None),
#  ('Custard Pie', 550, None),
#  ('The Rover', 551, None),
#  ('In My Time Of Dying', 552, None),
#  ('Kashmir', 555, None),
#  ('Imperatriz', 556, None),
#  ('Mocidade', 559, None),
#  ('Unidos Da Tijuca', 560, None),
#  ('Salgueiro', 561, None),
#  ('Grande Rio', 564, None),
#  ('Portela', 565, None),
#  ('Império Serrano', 568, None),
#  ('Tuiuti', 569, None),
#  ('(Da Le) Yaleo', 570, None),
#  ('Africa Bamba', 573, None),
#  ('Smooth', 574, None),
#  ('Migra', 577, None),
#  ('Corazon Espinado', 578, None),
#  ('Wishing It Was', 579, None),
#  ('The Calling', 582, None),
#  ('Solução', 583, None),
#  ('Um Contrato Com Deus', 586, None),
#  ('Um Jantar Pra Dois', 587, None),
#  ('Vamos Dançar', 588, None),
#  ('Baixo Rio', 591, None),
#  ('Sombras Do Meu Destino', 592, None),
#  ('Já!!!', 595, None),
#  ('A Rua', 596, None),
#  ("Now's The Time", 597, None),
#  ('Tempus Fugit', 600, None),
#  ("Walkin'", 601, None),
#  ('New Rhumba', 604, None),
#  ('Generique', 605, None),
#  ('Summertime', 606, None),
#  ('Someday My Prince Will Come', 609, None),
#  ('My Funny Valentine (Live)', 610, None),
#  ('Petits Machins (Little Stuff)', 613, None),
#  ('Miles Runs The Voodoo Down', 614, None),
#  ('Little Church (Live)', 615, None),
#  ('Time After Time', 618, None),
#  ('Portia', 619, None),
#  ("Space Truckin'", 620, None),
#  ('Mistreated (Alternate Version)', 622, None),
#  ('You Fool No One (Alternate Version)', 623, None),
#  ('Jeepers Creepers', 624, None),
#  ('Leave Us Leap', 628, None),
#  ('Disc Jockey Jump', 632, None),
#  ('Coronation Drop', 636, None),
#  ('Imagination', 638, None),
#  ('Midget', 640, None),
#  ("I'm Coming Virginia", 641, None),
#  ("Payin' Them Dues Blues", 642, None),
#  ('Swedish Schnapps', 645, None),
#  ('Samba Da Bênção', 646, None),
#  ('Linha de Passe (João Bosco)', 661, None),
#  ('Marina (Dorival Caymmi)', 664, None),
#  ('Aquarela (Toquinho)', 665, None),
#  ('Dona (Roupa Nova)', 667, None),
#  ('Começaria Tudo Outra Vez (Maria Creuza)', 668, None),
#  ('I Put A Spell On You', 676, None),
#  ("Travelin' Band", 684, None),
#  ("Lookin' Out My Back Door", 688, None),
#  ('I Heard It Through The Grapevine', 690, None),
#  ('Have You Ever Seen The Rain?', 691, None),
#  ('It Came Out Of The Sky', 703, None),
#  ('My Baby Left Me', 707, None),
#  ("Lookin' For A Reason", 713, None),
#  ('Hello Mary Lou', 714, None),
#  ('Geração Coca-Cola (Ao Vivo)', 718, None),
#  ('Lanterna Dos Afogados', 719, None),
#  ('1° De Julho', 723, None),
#  ('Vida Bandida (Ao Vivo)', 725, None),
#  ('Juventude Transviada (Ao Vivo)', 729, None),
#  ('Malandragem', 730, None),
#  ('O Segundo Sol', 731, None),
#  ('Nós (Ao Vivo)', 736, None),
#  ('Na Cadência Do Samba', 737, None),
#  ('Blues Da Piedade', 741, None),
#  ('Rubens', 742, None),
#  ('Não Deixe O Samba Morrer - Cassia Eller e Alcione', 743, None),
#  ('Lady Luck', 746, None),
#  ("Gettin' Tighter", 747, None),
#  ('Dealer', 748, None),
#  ("This Time Around / Owed to 'G' [Instrumental]", 752, None),
#  ('Speed King', 754, None),
#  ('Bloodsucker', 755, None),
#  ('Living Wreck', 759, None),
#  ("Hard Lovin' Man", 760, None),
#  ('Fireball', 761, None),
#  ("Anyone's Daughter", 764, None),
#  ('The Mule', 765, None),
#  ('Fools', 766, None),
#  ('Bad Attitude', 769, None),
#  ('Child In Time (Son Of Aleric - Instrumental)', 770, None),
#  ('Perfect Strangers', 773, None),
#  ('Call Of The Wild', 775, None),
#  ('Smoke On The Water', 777, None),
#  ('Space Trucking', 778, None),
#  ('Highway Star', 779, None),
#  ('Never Before', 782, None),
#  ('Smoke On The Water', 783, None),
#  ('Lazy', 784, None),
#  ('Loosen My Strings', 787, None),
#  ('Soon Forgotten', 788, None),
#  ('The Aviator', 791, None),
#  ("Rosa's Cantina", 792, None),
#  ('A Castle Full Of Rascals', 793, None),
#  ('Somebody Stole My Guitar', 796, None),
#  ('The Purpendicular Waltz', 797, None),
#  ('Fire In The Basement', 800, None),
#  ('Truth Hurts', 801, None),
#  ('Breakfast In Bed', 802, None),
#  ('Too Much Is Not Enough', 805, None),
#  ('Wicked Ways', 806, None),
#  ('Holy Man', 809, None),
#  ('Hold On', 810, None),
#  ('Lady Double Dealer', 811, None),
#  ('The Gypsy', 814, None),
#  ('Soldier Of Fortune', 815, None),
#  ('Anya', 818, None),
#  ('Talk About Love', 819, None),
#  ('Time To Kill', 820, None),
#  ('Nasty Piece Of Work', 823, None),
#  ('Solitaire', 824, None),
#  ('Photograph', 827, None),
#  ('Love Bites', 828, None),
#  ("Let's Get Rocked", 829, None),
#  ('Heaven Is', 832, None),
#  ('Rocket', 833, None),
#  ('Make Love Like A Man', 836, None),
#  ('Armageddon It', 837, None),
#  ('Have You Ever Needed Someone So Bad', 838, None),
#  ("Bringin' On The Heartbreak", 841, None),
#  ('Roll Call', 842, None),
#  ('Paris On Mine', 845, None),
#  ('In Time', 846, None),
#  ('Plan B', 847, None),
#  ('Talkin Loud and Saying Nothin', 850, None),
#  ('Pétala', 851, None),
#  ('Meu Bem-Querer', 852, None),
#  ('Boa Noite', 854, None),
#  ('Fato Consumado', 855, None),
#  ('Faltando Um Pedaço', 856, None),
#  ('Eu Te Devoro', 860, None),
#  ('Samurai', 864, None),
#  ('Serrado', 868, None),
#  ('Amar É Tudo', 870, None),
#  ('Seduzir', 872, None),
#  ('A Carta', 873, None),
#  ('Sina', 874, None),
#  ('O Bêbado e a Equilibrista', 877, None),
#  ('O Mestre-Sala dos Mares', 878, None),
#  ('I Feel Free', 893, None),
#  ('Strange Brew', 896, None),
#  ('White Room', 897, None),
#  ('Cocaine', 899, None),
#  ('I Shot The Sheriff', 900, None),
#  ("I Can't Stand It", 908, None),
#  ('Running On Faith', 916, None),
#  ('Malted Milk', 920, None),
#  ("Rollin' And Tumblin'", 922, None),
#  ('Collision', 923, None),
#  ('Land Of Sunshine', 935, None),
#  ('Smaller And Smaller', 939, None),
#  ('Crack Hitler', 945, None),
#  ('Jizzlobber', 946, None),
#  ('Ricochet', 950, None),
#  ('Evidence', 951, None),
#  ('Caralho Voador', 955, None),
#  ('Digging The Grave', 957, None),
#  ('The Last To Know', 961, None),
#  ('Just A Man', 962, None),
#  ('Absolute Zero', 963, None),
#  ('Zombie Eaters', 968, None),
#  ('The Real Thing', 969, None),
#  ('War Pigs', 973, None),
#  ('Edge Of The World', 974, None),
#  ('Deixa Entrar', 975, None),
#  ('Rindo À Toa', 978, None),
#  ('Confidência', 979, None),
#  ('Forró De Tóquio', 980, None),
#  ('Asas', 984, None),
#  ('Oração', 986, None),
#  ('Minha Gata', 987, None),
#  ('Best Of You', 991, None),
#  ('DOA', 992, None),
#  ('Hell', 993, None),
#  ('Resolve', 996, None),
#  ('The Deepest Blues Are Black', 997, None),
#  ('End Over End', 998, None),
#  ('Miracle', 1001, None),
#  ('Another Round', 1002, None),
#  ('On The Mend', 1005, None),
#  ('Cold Day In The Sun', 1007, None),
#  ('All My Life', 1009, None),
#  ('Low', 1010, None),
#  ('Have It All', 1011, None),
#  ('Tired Of You', 1014, None),
#  ('Halo', 1015, None),
#  ('Lonely As You', 1016, None),
#  ('Come Back', 1019, None),
#  ('Doll', 1020, None),
#  ('My Poor Brain', 1023, None),
#  ('Wind Up', 1024, None),
#  ('Up In Arms', 1025, None),
#  ('Enough Space', 1028, None),
#  ('February Stars', 1029, None),
#  ('New Way Home', 1032, None),
#  ('My Way', 1033, None),
#  ('Strangers In The Night', 1034, None),
#  ('Something Stupid', 1037, None),
#  ('Moon River', 1038, None),
#  ('For Once In My Life', 1041, None),
#  ('Love And Marriage', 1042, None),
#  ("They Can't Take That Away From Me", 1043, None),
#  ("I've Got You Under My Skin", 1046, None),
#  ('The Best Is Yet To Come', 1047, None),
#  ("That's Life", 1050, None),
#  ('The Girl From Ipanema', 1051, None),
#  ('The Lady Is A Tramp', 1052, None),
#  ('Loves Been Good To Me', 1055, None),
#  ('L.A. Is My Lady', 1056, None),
#  ('Funk De Bamba (Com Fernanda Abreu)', 1059, None),
#  ('Call Me At Cleo´s', 1060, None),
#  ('Olhos Coloridos (Com Sandra De Sá)', 1061, None),
#  ('Forty Days (Com DJ Hum)', 1064, None),
#  ('Balada Da Paula', 1065, None),
#  ('Motéis', 1068, None),
#  ('Whistle Stop', 1069, None),
#  ('16 Toneladas', 1070, None),
#  ('Óia Eu Aqui De Novo', 1073, None),
#  ('Baião Da Penha', 1074, None),
#  ('Último Pau-De-Arara', 1077, None),
#  ('Asa Branca', 1078, None),
#  ('Qui Nem Jiló', 1079, None),
#  ('A Volta Da Asa Branca', 1082, None),
#  ('O Amor Daqui De Casa', 1083, None),
#  ('As Pegadas Do Amor', 1084, None),
#  ('Casinha Feliz', 1086, None),
#  ('Introdução (Live)', 1087, None),
#  ('Palco (Live)', 1088, None),
#  ('Vendedor De Caranguejo (Live)', 1092, None),
#  ('Cérebro Eletrônico (Live)', 1096, None),
#  ('Ghandi (Live)', 1100, None),
#  ('Doce De Carnaval (Candy All)', 1102, None),
#  ('Pretinha', 1104, None),
#  ('A Novidade', 1105, None),
#  ('Tenho Sede', 1106, None),
#  ('Esotérico', 1109, None),
#  ('Drão', 1110, None),
#  ('I Stand Alone', 1125, None),
#  ('Releasing The Demons', 1128, None),
#  ('Dead And Broken', 1129, None),
#  ('The Awakening', 1131, None),
#  ('Serenity', 1132, None),
#  ("She's A Rebel", 1140, None),
#  ('Nightrain', 1148, None),
#  ('My Michelle', 1152, None),
#  ("Sweet Child O' Mine", 1154, None),
#  ("You're Crazy", 1155, None),
#  ('November Rain', 1167, None),
#  ('Bad Apples', 1171, None),
#  ("Knockin' On Heaven's Door", 1177, None),
#  ('Get In The Ring', 1178, None),
#  ('Locomotive', 1182, None),
#  ('So Fine', 1183, None),
#  ('My World', 1187, None),
#  ('Love Is The Colour', 1189, None),
#  ('Gypsy', 1193, None),
#  ('Journey Into Sunlight', 1194, None),
#  ('Sunchild', 1195, None),
#  ('Dark Side Of The Cog', 1200, None),
#  ('Different World', 1201, None),
#  ('The Longest Day', 1205, None),
#  ('Out of the Shadows', 1206, None),
#  ('The Reincarnation of Benjamin Breeg', 1207, None),
#  ('The Legacy', 1210, None),
#  ('Hallowed Be Thy Name (Live) [Non Album Bonus Track]', 1211, None),
#  ('The Number Of The Beast', 1212, None),
#  ('Remember Tomorrow', 1216, None),
#  ('Sanctuary', 1218, None),
#  ('Running Free', 1219, None),
#  ('Hallowed Be Thy Name', 1223, None),
#  ('Be Quick Or Be Dead', 1224, None),
#  ('From Here To Eternity', 1225, None),
#  ('Tailgunner', 1228, None),
#  ('The Evil That Men Do', 1229, None),
#  ('Afraid To Shoot Strangers', 1230, None),
#  ('The Clairvoyant', 1233, None),
#  ('Fear Of The Dark', 1234, None),
#  ('Brave New World', 1237, None),
#  ('The Mercenary', 1239, None),
#  ('The Fallen Angel', 1241, None),
#  ('The Nomad', 1242, None),
#  ('Out Of The Silent Planet', 1243, None),
#  ('Rainmaker', 1246, None),
#  ('No More Lies', 1247, None),
#  ('Montsegur', 1248, None),
#  ('New Frontier', 1251, None),
#  ('Paschendale', 1252, None),
#  ('Journeyman', 1255, None),
#  ('Be Quick Or Be Dead', 1256, None),
#  ('From Here To Eternity', 1257, None),
#  ("Childhood's End", 1260, None),
#  ('Wasting Love', 1261, None),
#  ('The Apparition', 1264, None),
#  ('Judas Be My Guide', 1265, None),
#  ('Weekend Warrior', 1266, None),
#  ('02 - Sanctuary', 1269, None),
#  ('03 - Remember Tomorrow', 1270, None),
#  ('06 - Transylvania', 1273, None),
#  ('07 - Strange World', 1274, None),
#  ('08 - Charlotte the Harlot', 1275, None),
#  ('Wrathchild', 1278, None),
#  ('Murders In The Rue Morgue', 1279, None),
#  ('Innocent Exile', 1282, None),
#  ('Killers', 1283, None),
#  ('Prodigal Son', 1284, None),
#  ('Intro- Churchill S Speech', 1287, None),
#  ('Aces High', 1288, None),
#  ('Revelations', 1291, None),
#  ('Flight Of Icarus', 1292, None),
#  ('Rime Of The Ancient Mariner', 1293, None),
#  ('Hallowed Be Thy Name', 1296, None),
#  ('Iron Maiden', 1297, None),
#  ('Wrathchild', 1300, None),
#  ('Acacia Avenue', 1301, None),
#  ('Children Of The Damned', 1302, None),
#  ('Be Quick Or Be Dead', 1305, None),
#  ('The Number Of The Beast', 1306, None),
#  ('Can I Play With Madness', 1309, None),
#  ('Wasting Love', 1310, None),
#  ('Tailgunner', 1311, None),
#  ('Fear Of The Dark', 1314, None),
#  ('Bring Your Daughter... To The Slaughter...', 1315, None),
#  ('The Clairvoyant', 1316, None),
#  ('Run To The Hills', 1318, None),
#  ('2 Minutes To Midnight', 1319, None),
#  ('Iron Maiden', 1320, None),
#  ('Running Free', 1324, None),
#  ('Public Enema Number One', 1328, None),
#  ('Hooks In You', 1332, None),
#  ('Mother Russia', 1334, None),
#  ('Revelations', 1336, None),
#  ('Flight Of The Icarus', 1337, None),
#  ('Die With Your Boots On', 1338, None),
#  ('Quest For Fire', 1341, None),
#  ('Sun And Steel', 1342, None),
#  ('2 Minutes To Midnight', 1357, None),
#  ('The Mercenary', 1360, None),
#  ('The Trooper', 1361, None),
#  ('The Clansman', 1363, None),
#  ('The Evil That Men Do', 1364, None),
#  ('Infinite Dreams', 1372, None),
#  ('Wasted Years', 1380, None),
#  ('Alexander the Great', 1384, None),
#  ('The Loneliness of the Long Dis', 1386, None),
#  ('22 Acacia Avenue', 1387, None),
#  ('Look For The Truth', 1399, None),
#  ('The Edge Of Darkness', 1403, None),
#  ('The Clansman', 1409, None),
#  ('When Two Worlds Collide', 1410, None),
#  ('Please Please Please', 1414, None),
#  ('Think', 1415, None),
#  ('I Got You (I Feel Good)', 1419, None),
#  ('Cold Sweat', 1421, None),
#  ('Make It Funky Pt.1', 1425, None),
#  ("I'm A Greedy Man Pt.1", 1426, None),
#  ('Get On The Good Foot', 1427, None),
#  ('Hot Pants Pt.1', 1432, None),
#  ('Soul Power (Live)', 1433, None),
#  ('If I Like It, I Do It', 1437, None),
#  ('Music Of The Wind', 1438, None),
#  ('Emergency On Planet Earth', 1439, None),
#  ('Revolution 1993', 1442, None),
#  ("Didgin' Out", 1443, None),
#  ('Canned Heat', 1444, None),
#  ('Failling', 1448, None),
#  ('Supersonic', 1450, None),
#  ('Butterfly', 1451, None),
#  ('Just Another Story', 1455, None),
#  ('Stillness In Time', 1456, None),
#  ('Half The Man', 1457, None),
#  ('The Kids', 1460, None),
#  ('Mr. Moon', 1461, None),
#  ('Scam', 1462, None),
#  ('Space Cowboy', 1465, None),
#  ('Last Chance', 1466, None),
#  ("Look What You've Done", 1469, None),
#  ('Move On', 1471, None),
#  ('Get Me Outta Here', 1473, None),
#  ('Cold Hard Bitch', 1474, None),
#  ('Come Around Again', 1475, None),
#  ('Timothy', 1478, None),
#  ('Foxy Lady', 1479, None),
#  ('Manic Depression', 1480, None),
#  ('Love Or Confusion', 1483, None),
#  ("I Don't Live Today", 1484, None),
#  ('Third Stone From The Sun', 1487, None),
#  ('Remember', 1488, None),
#  ('Are You Experienced?', 1489, None),
#  ('Purple Haze', 1492, None),
#  ('51st Anniversary', 1493, None),
#  ('Surfing with the Alien', 1496, None),
#  ('Ice 9', 1497, None),
#  ('Crushing Day', 1498, None),
#  ('Hill of the Skull', 1501, None),
#  ('Circles', 1502, None),
#  ('Echo', 1505, None),
#  ('Engenho De Dentro', 1506, None),
#  ('Alcohol', 1507, None),
#  ('W/Brasil (Chama O Síndico)', 1510, None),
#  ('País Tropical', 1511, None),
#  ('Selassiê', 1514, None),
#  ('Menina Sarará', 1515, None),
#  ('Que Maravilha', 1516, None),
#  ('Taj Mahal', 1519, None),
#  ('Rapidamente', 1520, None),
#  ('My Brother', 1523, None),
#  ('Há Quanto Tempo', 1524, None),
#  ('Vício', 1525, None),
#  ('A Tarde', 1528, None),
#  ('Always Be All Right', 1529, None),
#  ('Pura Elegancia', 1532, None),
#  ('Choramingando', 1533, None),
#  ('Por Merecer', 1534, None),
#  ('Cuando A Noite Vai Chegando', 1537, None),
#  ('Naquele Dia', 1538, None),
#  ('Cuando Eu For Pro Ceu', 1541, None),
#  ('Do Nosso Amor', 1542, None),
#  ('Borogodo', 1543, None),
#  ('The Green Manalishi', 1546, None),
#  ('Living After Midnight', 1547, None),
#  ('Breaking The Law (Live)', 1548, None),
#  ('Heading Out To The Highway (Live)', 1550, None),
#  ('The Hellion', 1551, None),
#  ('Electric Eye', 1552, None),
#  ('Some Heads Are Gonna Roll', 1556, None),
#  ('Victim Of Change (Live)', 1560, None),
#  ("Goin' Blind", 1564, None),
#  ('Domino', 1566, None),
#  ('A World Without Heroes', 1568, None),
#  ('Rock Bottom', 1569, None),
#  ('See You Tonight', 1570, None),
#  ('2,000 Man', 1573, None),
#  ('Beth', 1574, None),
#  ("I Can't Quit You Baby", 1589, None),
#  ('Darlene', 1592, None),
#  ("Bonzo's Montreux", 1593, None),
#  ('The Song Remains The Same', 1595, None),
#  ('The Rain Song', 1596, None),
#  ('South Bound Saurez', 1604, None),
#  ('The Battle Of Evermore', 1612, None),
#  ('Going To California', 1616, None),
#  ('Good Times Bad Times', 1618, None),
#  ("Babe I'm Gonna Leave You", 1619, None),
#  ('Heartbreaker', 1631, None),
#  ('Bring It On Home', 1635, None),
#  ('Gallows Pole', 1641, None),
#  ('Tangerine', 1642, None),
#  ('In The Light', 1646, None),
#  ('Bron-Yr-Aur', 1647, None),
#  ('The Wanton Song', 1651, None),
#  ('Black Country Woman', 1653, None),
#  ('Royal Orleans', 1657, None),
#  ("Nobody's Fault But Mine", 1658, None),
#  ('Candy Store Rock', 1659, None),
#  ('The Song Remains The Same', 1664, None),
#  ('Rain Song', 1665, None),
#  ('Moby Dick', 1669, None),
#  ('Whole Lotta Love', 1670, None),
#  ('Natália', 1671, None),
#  ('Longe Do Meu Lado', 1674, None),
#  ('A Via Láctea', 1675, None),
#  ('Música Ambiente', 1676, None),
#  ('Mil Pedaços', 1680, None),
#  ('1º De Julho', 1682, None),
#  ('Esperando Por Mim', 1683, None),
#  ('Ainda É Cedo', 1687, None),
#  ('Geração Coca-Cola', 1688, None),
#  ('Eduardo E Mônica', 1689, None),
#  ('Que País É Este', 1692, None),
#  ('Faroeste Caboclo', 1693, None),
#  ('Há Tempos', 1694, None),
#  ('Vento No Litoral', 1697, None),
#  ('Perfeição', 1698, None),
#  ('Antes Das Seis', 1701, None),
#  ('Fly Away', 1703, None),
#  ('Again', 1705, None),
#  ("It Ain't Over 'Til It's Over", 1706, None),
#  ("Can't Get You Off My Mind", 1707, None),
#  ('Stand By My Woman', 1710, None),
#  ('Always On The Run', 1711, None),
#  ('Heaven Help', 1712, None),
#  ('Let Love Rule', 1715, None),
#  ('Black Velveteen', 1716, None),
#  ('Dancin´Days', 1719, None),
#  ('Um Pro Outro', 1720, None),
#  ('Aviso Aos Navegantes', 1721, None),
#  ('Hyperconectividade', 1724, None),
#  ('O Descobridor Dos Sete Mares', 1725, None),
#  ('Um Certo Alguém', 1728, None),
#  ('Fullgás', 1729, None),
#  ('Sábado À Noite', 1730, None),
#  ('Atrás Do Trio Elétrico', 1733, None),
#  ('Senta A Pua', 1734, None),
#  ('Toda Forma De Amor', 1737, None),
#  ('Tudo Igual', 1738, None),
#  ('Fogo De Palha', 1739, None),
#  ('Se Você Pensa', 1742, None),
#  ('Lá Vem O Sol (Here Comes The Sun)', 1743, None),
#  ('Kayleigh', 1746, None),
#  ('Lavender', 1747, None),
#  ('Bitter Suite: Brief Encounter / Lost Weekend / Blue Angel', 1748, None),
#  ('Lords Of The Backstage', 1751, None),
#  ('Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold', 1752, None),
#  ('Arrepio', 1755, None),
#  ('Magamalabares', 1756, None),
#  ('Chuva No Brejo', 1757, None),
#  ('Maraçá', 1760, None),
#  ('Blanco', 1761, None),
#  ('Beija Eu', 1764, None),
#  ('Give Me Love', 1765, None),
#  ('Ainda Lembro', 1766, None),
#  ('Ao Meu Redor', 1769, None),
#  ('Bem Leve', 1770, None),
#  ('Wherever I Lay My Hat', 1773, None),
#  ("Get My Hands On Some Lovin'", 1774, None),
#  ('No Good Without You', 1775, None),
#  ("You're What's Happening (In The World Today)", 1778, None),
#  ('Loving You Is Sweeter Than Ever', 1779, None),
#  ("It's A Bitter Pill To Swallow", 1780, None),
#  ("Gonna Keep On Tryin' Till I Win Your Love", 1782, None),
#  ("Gonna Give Her All The Love I've Got", 1783, None),
#  ('I Wish It Would Rain', 1784, None),
#  ('Ego Tripping Out', 1788, None),
#  ('Overkill', 1792, None),
#  ('Who Can It Be Now?', 1796, None),
#  ('Dr. Heckyll & Mr. Jive', 1798, None),
#  ('No Sign of Yesterday', 1800, None),
#  ('Enter Sandman', 1801, None),
#  ('Sad But True', 1802, None),
#  ('Wherever I May Roam', 1805, None),
#  ("Don't Tread On Me", 1806, None),
#  ('The Prince', 1821, None),
#  ('Killing Time', 1824, None),
#  ('Overkill', 1825, None),
#  ('Stone Dead Forever', 1827, None),
#  ('Too Late Too Late', 1828, None),
#  ('No Remorse', 1836, None),
#  ('Hero Of The Day', 1844, None),
#  ('Wasted My Hate', 1848, None),
#  ('Thorn Within', 1850, None),
#  ('Ronnie', 1851, None),
#  ("Devil's Dance", 1863, None),
#  ('Carpe Diem Baby', 1867, None),
#  ('Fixxxer', 1873, None),
#  ('Fight Fire With Fire', 1874, None),
#  ('Trapped Under Ice', 1878, None),
#  ('Escape', 1879, None),
#  ('St. Anger', 1883, None),
#  ('Dirty Window', 1885, None),
#  ('Sweet Amber', 1889, None),
#  ('The Unnamed Feeling', 1890, None),
#  ('Purify', 1891, None),
#  ('One', 1896, None),
#  ('The Shortest Straw', 1897, None),
#  ('Dyers Eve', 1901, None),
#  ('Springsville', 1902, None),
#  ('The Maids Of Cadiz', 1903, None),
#  ('Miles Ahead', 1906, None),
#  ('Blues For Pablo', 1907, None),
#  ('New Rhumba', 1908, None),
#  ('Springsville (Alternate Take)', 1912, None),
#  ('The Meaning Of The Blues/Lament (Alternate Take)', 1914, None),
#  ("I Don't Wanna Be Kissed (By Anyone But You) (Alternate Take)", 1915, None),
#  ('Cuitelinho', 1919, None),
#  ('Caxangá', 1920, None),
#  ('Nos Bailes Da Vida', 1921, None),
#  ('Canção Do Novo Mundo', 1924, None),
#  ('Um Gosto De Sol', 1925, None),
#  ('Solar', 1926, None),
#  ('Minas', 1929, None),
#  ('Fé Cega, Faca Amolada', 1930, None),
#  ('Gran Circo', 1933, None),
#  ('Trastevere', 1935, None),
#  ('Leila (Venha Ser Feliz)', 1937, None),
#  ('Paula E Bebeto', 1938, None),
#  ('Simples', 1939, None),
#  ('Ace Of Spades', 1942, None),
#  ('Love Me Like A Reptile', 1943, None),
#  ('Shoot You In The Back', 1944, None),
#  ('(We Are) The Road Crew', 1947, None),
#  ('Fire Fire', 1948, None),
#  ('Bite The Bullet', 1951, None),
#  ('The Chase Is Better Than The Catch', 1952, None),
#  ('The Hammer', 1953, None),
#  ('Emergency', 1956, None),
#  ('Kir Royal', 1957, None),
#  ('Dois Índios', 1960, None),
#  ('Noite Negra', 1961, None),
#  ('Beijo do Olhar', 1962, None),
#  ('Só Se For Pelo Cabelo', 1965, None),
#  ('No Clima', 1966, None),
#  ('Bitter Pill', 1969, None),
#  ('Enslaved', 1970, None),
#  ('Girls, Girls, Girls', 1971, None),
#  ('Glitter', 1974, None),
#  ('Dr. Feelgood', 1975, None),
#  ('Afraid', 1978, None),
#  ("Don't Go Away Mad (Just Go Away)", 1979, None),
#  ('Without You', 1980, None),
#  ('Too Fast For Love', 1983, None),
#  ('Looks That Kill', 1984, None),
#  ('School', 1987, None),
#  ('Drain You', 1988, None),
#  ('Aneurysm', 1989, None),
#  ('Lithium', 1992, None),
#  ('Sliver', 1993, None),
#  ('Heart-Shaped Box', 1996, None),
#  ('Milk It', 1997, None),
#  ('Negative Creep', 1998, None),
#  ("Tourette's", 2001, None),
#  ('Blew', 2002, None),
#  ('Come As You Are', 2005, None),
#  ('Breed', 2006, None),
#  ('Lithium', 2007, None),
#  ('Drain You', 2010, None),
#  ('Lounge Act', 2011, None),
#  ('Stay Away', 2012, None),
#  ('Something In The Way', 2014, None),
#  ('Time', 2015, None),
#  ('P.S.Apareça', 2016, None),
#  ('Mágica', 2020, None),
#  ('Deus', 2024, None),
#  ('Prazer E Fé', 2028, None),
#  ('Requebra', 2030, None),
#  ('Olodum - Alegria Geral', 2032, None),
#  ('Madagáscar Olodum', 2033, None),
#  ('Faraó Divindade Do Egito', 2034, None),
#  ('Olodum, A Banda Do Pelô', 2037, None),
#  ('Cartao Postal', 2038, None),
#  ('Meu Erro', 2053, None),
#  ('Tendo A Lua', 2056, None),
#  ('Que País É Este', 2057, None),
#  ('Feira Moderna', 2059, None),
#  ('Tequila - Lourinha Bombril (Parate Y Mira)', 2060, None),
#  ('Lourinha Bombril', 2068, None),
#  ('Aonde Quer Que Eu Va', 2076, None),
#  ('Alagados', 2080, None),
#  ('Melô Do Marinheiro', 2082, None),
#  ('Vital E Sua Moto', 2083, None),
#  ('Crazy Train', 2095, None),
#  ("I Don't Know", 2099, None),
#  ('Steal Away (The Night)', 2105, None),
#  ('Suicide Solution (With Guitar Solo)', 2106, None),
#  ('Goodbye To Romance', 2110, None),
#  ('No Bone Movies', 2111, None),
#  ('Upon A Golden Horse', 2115, None),
#  ('Please Read The Letter', 2117, None),
#  ('Burning Up', 2121, None),
#  ('When I Was A Child', 2122, None),
#  ('House Of Love', 2123, None),
#  ('Always Forever Now', 2128, None),
#  ('A Different Kind Of Blue', 2129, None),
#  ('One Minute Warning', 2133, None),
#  ('Corpse (These Chains Are Way Too Long)', 2134, None),
#  ('Elvis Ate America', 2135, None),
#  ("Theme From Let's Go Native", 2138, None),
#  ('Wrathchild', 2139, None),
#  ('Killers', 2140, None),
#  ('Remember Tomorrow', 2144, None),
#  ('Running Free', 2146, None),
#  ('Phantom Of The Opera', 2147, None),
#  ('Hail, Hail', 2151, None),
#  ('Daughter', 2152, None),
#  ('Elderly Woman Behind The Counter In A Small Town', 2153, None),
#  ('Go', 2156, None),
#  ('Red Mosquito', 2157, None),
#  ('Even Flow', 2158, None),
#  ('Do The Evolution', 2161, None),
#  ('Better Man', 2162, None),
#  ('Life Wasted', 2165, None),
#  ('Comatose', 2167, None),
#  ('Marker In The Sand', 2169, None),
#  ('Parachutes', 2170, None),
#  ('Unemployable', 2171, None),
#  ('Wasted Reprise', 2174, None),
#  ('Army Reserve', 2175, None),
#  ('Come Back', 2176, None),
#  ('Save You', 2179, None),
#  ('Love Boat Captain', 2180, None),
#  ('I Am Mine', 2183, None),
#  ('Thumbing My Way', 2184, None),
#  ('You Are', 2185, None),
#  ('Help Help', 2188, None),
#  ('Bushleager', 2189, None),
#  ('All or None', 2192, None),
#  ('Once', 2193, None),
#  ('Evenflow', 2194, None),
#  ('Black', 2197, None),
#  ('Jeremy', 2198, None),
#  ('Garden', 2201, None),
#  ('Deep', 2202, None),
#  ('Release', 2203, None),
#  ('Daughter', 2206, None),
#  ('Glorified G', 2207, None),
#  ('Blood', 2210, None),
#  ('Rearviewmirror', 2211, None),
#  ('Rats', 2212, None),
#  ('Indifference', 2215, None),
#  ('Johnny B. Goode', 2216, None),
#  ("I'm The Toughest", 2219, None),
#  ('Nothing But Love', 2220, None),
#  ('Buk-In-Hamm Palace', 2221, None),
#  ('Mystic Man', 2224, None),
#  ('Coming In Hot', 2225, None),
#  ('Equal Rights Downpresser Man', 2228, None),
#  ('Speak To Me/Breathe', 2229, None),
#  ('On The Run', 2230, None),
#  ('Money', 2233, None),
#  ('Us And Them', 2234, None),
#  ('Eclipse', 2237, None),
#  ('ZeroVinteUm', 2238, None),
#  ('Queimando Tudo', 2239, None),
#  ('100% HardCore', 2242, None),
#  ('Biruta', 2243, None),
#  ('Mão Na Cabeça', 2244, None),
#  ('Adoled (Ocean)', 2246, None),
#  ('Seus Amigos', 2247, None),
#  ('Paga Pau', 2248, None),
#  ('Quem Me Cobrou?', 2252, None),
#  ('Killer Queen', 2256, None),
#  ("Don't Stop Me Now", 2260, None),
#  ('Crazy Little Thing Called Love', 2262, None),
#  ("Now I'm Here", 2264, None),
#  ('Good Old-Fashioned Lover Boy', 2265, None),
#  ('Play The Game', 2266, None),
#  ('We Will Rock You', 2269, None),
#  ('We Are The Champions', 2270, None),
#  ('Pop Song 89', 2285, None),
#  ('Stand', 2288, None),
#  ('World Leader Pretend', 2289, None),
#  ('Orange Crush', 2291, None),
#  ('Turn You Inside-Out', 2292, None),
#  ('E-Bow The Letter', 2300, None),
#  ('Low Desert', 2308, None),
#  ('Near Wild Heaven', 2312, None),
#  ('Belong', 2314, None),
#  ('Half A World Away', 2315, None),
#  ('Driver 8', 2327, None),
#  ('The One I Love', 2331, None),
#  ('Merry Christmas', 2337, None),
#  ('Bodies', 2338, None),
#  ('Cajueiro', 2342, None),
#  ('Palhas Do Coqueiro', 2343, None),
#  ('O Segredo Do Universo', 2347, None),
#  ('Mata Virgem', 2349, None),
#  ('Diamante De Mendigo', 2353, None),
#  ('Negócio É', 2354, None),
#  ('Muita Estrela, Pouca Constelação', 2355, None),
#  ('Breaking The Girl', 2360, None),
#  ('Funky Monks', 2361, None),
#  ('The Righteous & The Wicked', 2365, None),
#  ('Give It Away', 2366, None),
#  ('Blood Sugar Sex Magik', 2367, None),
#  ('Apache Rose Peacock', 2370, None),
#  ('The Greeting Song', 2371, None),
#  ('My Lovely Man', 2372, None),
#  ('Universally Speaking', 2376, None),
#  ...]

# %% [markdown]
# ### Exercise 5
#
# Let's suppose that, as part of a new business strategy, Chinook wants to develop new product categories for their media items that are based on genre and media type. Write a query that will list all possible product categories (i.e. all possible genre and media type combinations).

# %%
# %%sql
#
# select g.Name as Genre_type, m.Name as Media_type
# from genres as g
# cross join media_types as m
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Rock', 'MPEG audio file'),
#  ('Rock', 'Protected AAC audio file'),
#  ('Rock', 'Protected MPEG-4 video file'),
#  ('Rock', 'Purchased AAC audio file'),
#  ('Rock', 'AAC audio file'),
#  ('Jazz', 'MPEG audio file'),
#  ('Jazz', 'Protected AAC audio file'),
#  ('Jazz', 'Protected MPEG-4 video file'),
#  ('Jazz', 'Purchased AAC audio file'),
#  ('Jazz', 'AAC audio file'),
#  ('Metal', 'MPEG audio file'),
#  ('Metal', 'Protected AAC audio file'),
#  ('Metal', 'Protected MPEG-4 video file'),
#  ('Metal', 'Purchased AAC audio file'),
#  ('Metal', 'AAC audio file'),
#  ('Alternative & Punk', 'MPEG audio file'),
#  ('Alternative & Punk', 'Protected AAC audio file'),
#  ('Alternative & Punk', 'Protected MPEG-4 video file'),
#  ('Alternative & Punk', 'Purchased AAC audio file'),
#  ('Alternative & Punk', 'AAC audio file'),
#  ('Rock And Roll', 'MPEG audio file'),
#  ('Rock And Roll', 'Protected AAC audio file'),
#  ('Rock And Roll', 'Protected MPEG-4 video file'),
#  ('Rock And Roll', 'Purchased AAC audio file'),
#  ('Rock And Roll', 'AAC audio file'),
#  ('Blues', 'MPEG audio file'),
#  ('Blues', 'Protected AAC audio file'),
#  ('Blues', 'Protected MPEG-4 video file'),
#  ('Blues', 'Purchased AAC audio file'),
#  ('Blues', 'AAC audio file'),
#  ('Latin', 'MPEG audio file'),
#  ('Latin', 'Protected AAC audio file'),
#  ('Latin', 'Protected MPEG-4 video file'),
#  ('Latin', 'Purchased AAC audio file'),
#  ('Latin', 'AAC audio file'),
#  ('Reggae', 'MPEG audio file'),
#  ('Reggae', 'Protected AAC audio file'),
#  ('Reggae', 'Protected MPEG-4 video file'),
#  ('Reggae', 'Purchased AAC audio file'),
#  ('Reggae', 'AAC audio file'),
#  ('Pop', 'MPEG audio file'),
#  ('Pop', 'Protected AAC audio file'),
#  ('Pop', 'Protected MPEG-4 video file'),
#  ('Pop', 'Purchased AAC audio file'),
#  ('Pop', 'AAC audio file'),
#  ('Soundtrack', 'MPEG audio file'),
#  ('Soundtrack', 'Protected AAC audio file'),
#  ('Soundtrack', 'Protected MPEG-4 video file'),
#  ('Soundtrack', 'Purchased AAC audio file'),
#  ('Soundtrack', 'AAC audio file'),
#  ('Bossa Nova', 'MPEG audio file'),
#  ('Bossa Nova', 'Protected AAC audio file'),
#  ('Bossa Nova', 'Protected MPEG-4 video file'),
#  ('Bossa Nova', 'Purchased AAC audio file'),
#  ('Bossa Nova', 'AAC audio file'),
#  ('Easy Listening', 'MPEG audio file'),
#  ('Easy Listening', 'Protected AAC audio file'),
#  ('Easy Listening', 'Protected MPEG-4 video file'),
#  ('Easy Listening', 'Purchased AAC audio file'),
#  ('Easy Listening', 'AAC audio file'),
#  ('Heavy Metal', 'MPEG audio file'),
#  ('Heavy Metal', 'Protected AAC audio file'),
#  ('Heavy Metal', 'Protected MPEG-4 video file'),
#  ('Heavy Metal', 'Purchased AAC audio file'),
#  ('Heavy Metal', 'AAC audio file'),
#  ('R&B/Soul', 'MPEG audio file'),
#  ('R&B/Soul', 'Protected AAC audio file'),
#  ('R&B/Soul', 'Protected MPEG-4 video file'),
#  ('R&B/Soul', 'Purchased AAC audio file'),
#  ('R&B/Soul', 'AAC audio file'),
#  ('Electronica/Dance', 'MPEG audio file'),
#  ('Electronica/Dance', 'Protected AAC audio file'),
#  ('Electronica/Dance', 'Protected MPEG-4 video file'),
#  ('Electronica/Dance', 'Purchased AAC audio file'),
#  ('Electronica/Dance', 'AAC audio file'),
#  ('World', 'MPEG audio file'),
#  ('World', 'Protected AAC audio file'),
#  ('World', 'Protected MPEG-4 video file'),
#  ('World', 'Purchased AAC audio file'),
#  ('World', 'AAC audio file'),
#  ('Hip Hop/Rap', 'MPEG audio file'),
#  ('Hip Hop/Rap', 'Protected AAC audio file'),
#  ('Hip Hop/Rap', 'Protected MPEG-4 video file'),
#  ('Hip Hop/Rap', 'Purchased AAC audio file'),
#  ('Hip Hop/Rap', 'AAC audio file'),
#  ('Science Fiction', 'MPEG audio file'),
#  ('Science Fiction', 'Protected AAC audio file'),
#  ('Science Fiction', 'Protected MPEG-4 video file'),
#  ('Science Fiction', 'Purchased AAC audio file'),
#  ('Science Fiction', 'AAC audio file'),
#  ('TV Shows', 'MPEG audio file'),
#  ('TV Shows', 'Protected AAC audio file'),
#  ('TV Shows', 'Protected MPEG-4 video file'),
#  ('TV Shows', 'Purchased AAC audio file'),
#  ('TV Shows', 'AAC audio file'),
#  ('Sci Fi & Fantasy', 'MPEG audio file'),
#  ('Sci Fi & Fantasy', 'Protected AAC audio file'),
#  ('Sci Fi & Fantasy', 'Protected MPEG-4 video file'),
#  ('Sci Fi & Fantasy', 'Purchased AAC audio file'),
#  ('Sci Fi & Fantasy', 'AAC audio file'),
#  ('Drama', 'MPEG audio file'),
#  ('Drama', 'Protected AAC audio file'),
#  ('Drama', 'Protected MPEG-4 video file'),
#  ('Drama', 'Purchased AAC audio file'),
#  ('Drama', 'AAC audio file'),
#  ('Comedy', 'MPEG audio file'),
#  ('Comedy', 'Protected AAC audio file'),
#  ('Comedy', 'Protected MPEG-4 video file'),
#  ('Comedy', 'Purchased AAC audio file'),
#  ('Comedy', 'AAC audio file'),
#  ('Alternative', 'MPEG audio file'),
#  ('Alternative', 'Protected AAC audio file'),
#  ('Alternative', 'Protected MPEG-4 video file'),
#  ('Alternative', 'Purchased AAC audio file'),
#  ('Alternative', 'AAC audio file'),
#  ('Classical', 'MPEG audio file'),
#  ('Classical', 'Protected AAC audio file'),
#  ('Classical', 'Protected MPEG-4 video file'),
#  ('Classical', 'Purchased AAC audio file'),
#  ('Classical', 'AAC audio file'),
#  ('Opera', 'MPEG audio file'),
#  ('Opera', 'Protected AAC audio file'),
#  ('Opera', 'Protected MPEG-4 video file'),
#  ('Opera', 'Purchased AAC audio file'),
#  ('Opera', 'AAC audio file')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name"
# FROM
#     albums a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# SELECT
#     a.AlbumId,
#     a.Title AS "Album Title",
#     t.Name AS "Track Name",
#     ar.Name AS "Artist Name"
# FROM
#     albums AS a
# INNER JOIN
#     tracks AS t
#     ON a.Title = t.Name
# INNER JOIN
#     artists AS ar
#     ON ar.ArtistId = a.ArtistId
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# Return rows in the `AlbumId` from the `albums` table, `Title` from the `albums` table, the `Name` from the `tracks` table, and the `Name` from the `artists` table, where the `albums` table `Title` column matches the `tracks` table `Name` column, and the `artists` table `Name` column where the `artists` table `ArtistId` is equal to the `albums` table `ArtistId`.

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# SELECT
#     t.TrackId,
#     ii.InvoiceId
# FROM
#     tracks t
# LEFT JOIN
#     invoice_items ii
#     ON t.TrackId = ii.TrackId
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# SELECT
#     t.TrackId,
#     ii.InvoiceId
# FROM
#     tracks AS t
# LEFT JOIN
#     invoice_items AS ii
#     ON t.TrackId = ii.TrackId
# WHERE ii.InvoiceId IS NULL
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# ### Exercise 5

# %%
# %%sql
#
# SELECT
#     g.Name AS "Genre",
#     m.Name AS "Media Type"
# FROM
#     genres AS g
# CROSS JOIN
#     media_types AS m
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
