# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in the SELECT clause

# %% [markdown]
# In this notebook, we will look at subqueries, which are powerful tools to enable more in-depth analysis in SQL. They are essentially intermediate results sets that we access with another query, so **a query inside another query**. We can use subqueries in various places in a query, and those subquery results also have various forms. Here, we look at the **use of a subquery in the `SELECT` clause.**

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use **subqueries** instead of static values to make calculations dynamic.
# - How to turn a normal subquery into a **correlated subquery** to perform calculations based on specific criteria.

# %% [markdown]
# ## Overview
#
# Imagine we want to calculate the percentage of land area a specific country in a sub-region occupies, as a percentage of the total land area in that sub-region. That is a challenging question because we need to divide each country's land area with the sum of all countries in that sub-region.
# To do it, we can use a subquery. For example, let's just look at one sub-region for now, `Middle Africa`, and use the `Geographic_location` table to **find out the percentage of land each country has as a percentage of the total for 'Middle Africa'.**

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Geographic_location` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:password@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Calculate the total land area of the 'Middle Africa' sub-region
#
# Write a query that will find the `Land_area` sum for the `Middle Africa` sub-region. Call this column `total_land_area`.

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('access_to_basic_services',),
#  ('basic_services',),
#  ('countrynames',),
#  ('economic_indicators',),
#  ('geographic_location',)]

# %%
# %%sql
#
# select *
# from geographic_location;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17')),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00')),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00')),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50')),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.00')),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.00')),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.00')),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.00')),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.00')),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.00')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.00')),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.00')),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.00')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.00')),
#  ('Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('240.00')),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.00')),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.00')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.00')),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424701.90')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.00')),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.00')),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None),
#  ('Cook Islands', 'Polynesia', 'Oceania', None),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.00')),
#  ("Côte d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.00')),
#  ('Curaçao', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.00')),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.00')),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', Decimal('750.00')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.00')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.00')),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.00')),
#  ('Equatorial Guinea', 'Middle Africa', 'Sub-Saharan Africa', Decimal('28050.00')),
#  ('Eritrea', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('121083.12')),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.00')),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.04')),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.00')),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None),
#  ('French Polynesia', 'Polynesia', 'Oceania', Decimal('3471.00')),
#  ('Gabon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('257670.00')),
#  ('Gambia', 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Georgia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('69490.00')),
#  ('Ghana', 'Western Africa', 'Sub-Saharan Africa', Decimal('227538.83')),
#  ('Greenland', 'Northern America', 'Europe and Northern America', Decimal('410450.00')),
#  ('Grenada', 'Caribbean', 'Latin America and the Caribbean', Decimal('340.00')),
#  ('Guadeloupe', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Guam', 'Micronesia', 'Oceania', Decimal('540.00')),
#  ('Guatemala', 'Central America', 'Latin America and the Caribbean', Decimal('107160.00')),
#  ('Guinea', 'Western Africa', 'Sub-Saharan Africa', Decimal('245720.00')),
#  ('Guinea-Bissau', 'Western Africa', 'Sub-Saharan Africa', Decimal('28120.00')),
#  ('Guyana', 'South America', 'Latin America and the Caribbean', Decimal('196850.00')),
#  ('Haiti', 'Caribbean', 'Latin America and the Caribbean', Decimal('27560.00')),
#  ('Honduras', 'Central America', 'Latin America and the Caribbean', Decimal('111890.00')),
#  ('India', 'Southern Asia', 'Central and Southern Asia', Decimal('2973190.00')),
#  ('Indonesia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('1877519.00')),
#  ('Iran (Islamic Republic of)', 'Southern Asia', 'Central and Southern Asia', None),
#  ('Iraq', 'Western Asia', 'Northern Africa and Western Asia', Decimal('434128.00')),
#  ('Israel', 'Western Asia', 'Northern Africa and Western Asia', Decimal('21640.00')),
#  ('Jamaica', 'Caribbean', 'Latin America and the Caribbean', Decimal('10830.00')),
#  ('Japan', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('364500.00')),
#  ('Jordan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('88784.67')),
#  ('Kazakhstan', 'Central Asia', 'Central and Southern Asia', Decimal('2699700.00')),
#  ('Kenya', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('569140.00')),
#  ('Kiribati', 'Micronesia', 'Oceania', Decimal('810.00')),
#  ('Kuwait', 'Western Asia', 'Northern Africa and Western Asia', Decimal('17820.00')),
#  ('Kyrgyzstan', 'Central Asia', 'Central and Southern Asia', None),
#  ("Lao People's Democratic Republic", 'South-Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Lebanon', 'Western Asia', 'Northern Africa and Western Asia', Decimal('10230.00')),
#  ('Lesotho', 'Southern Africa', 'Sub-Saharan Africa', Decimal('30360.00')),
#  ('Liberia', 'Western Africa', 'Sub-Saharan Africa', Decimal('96320.00')),
#  ('Libya', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('1759540.00')),
#  ('Madagascar', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('581800.00')),
#  ('Malawi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('94280.00')),
#  ('Malaysia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('328550.00')),
#  ('Maldives', 'Southern Asia', 'Central and Southern Asia', Decimal('300.00')),
#  ('Mali', 'Western Africa', 'Sub-Saharan Africa', Decimal('1220190.00')),
#  ('Marshall Islands', 'Micronesia', 'Oceania', Decimal('180.00')),
#  ('Martinique', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Mauritania', 'Western Africa', 'Sub-Saharan Africa', Decimal('1030700.00')),
#  ('Mauritius', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('2030.00')),
#  ('Mayotte', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Mexico', 'Central America', 'Latin America and the Caribbean', Decimal('1943950.00')),
#  ('Micronesia (Federated States of)', 'Micronesia', 'Oceania', None),
#  ('Mongolia', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('1557297.67')),
#  ('Montserrat', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Morocco', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('446300.00')),
#  ('Mozambique', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('786380.00')),
#  ('Myanmar', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('652780.00')),
#  ('Namibia', 'Southern Africa', 'Sub-Saharan Africa', Decimal('823290.00')),
#  ('Nauru', 'Micronesia', 'Oceania', Decimal('20.00')),
#  ('Nepal', 'Southern Asia', 'Central and Southern Asia', Decimal('143350.00')),
#  ('New Caledonia', 'Melanesia', 'Oceania', Decimal('18280.00')),
#  ('New Zealand', 'Australia and New Zealand', 'Oceania', Decimal('263310.00')),
#  ('Nicaragua', 'Central America', 'Latin America and the Caribbean', Decimal('120340.00')),
#  ('Niger', 'Western Africa', 'Sub-Saharan Africa', Decimal('1266700.00')),
#  ('Nigeria', 'Western Africa', 'Sub-Saharan Africa', Decimal('910770.00')),
#  ('Niue', 'Polynesia', 'Oceania', None),
#  ('Northern Mariana Islands', 'Micronesia', 'Oceania', Decimal('460.00')),
#  ('Oman', 'Western Asia', 'Northern Africa and Western Asia', Decimal('309500.00')),
#  ('Pakistan', 'Southern Asia', 'Central and Southern Asia', Decimal('770880.00')),
#  ('Palau', 'Micronesia', 'Oceania', Decimal('460.00')),
#  ('Panama', 'Central America', 'Latin America and the Caribbean', Decimal('74150.00')),
#  ('Papua New Guinea', 'Melanesia', 'Oceania', Decimal('452860.00')),
#  ('Paraguay', 'South America', 'Latin America and the Caribbean', Decimal('397300.00')),
#  ('Peru', 'South America', 'Latin America and the Caribbean', Decimal('1280000.00')),
#  ('Philippines', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('298170.00')),
#  ('Puerto Rico', 'Caribbean', 'Latin America and the Caribbean', Decimal('8870.00')),
#  ('Qatar', 'Western Asia', 'Northern Africa and Western Asia', Decimal('11490.00')),
#  ('Republic of Korea', 'Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Réunion', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Rwanda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('24670.00')),
#  ('Saint Barthélemy', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Helena', 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Saint Kitts and Nevis', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Lucia', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Martin (French Part)', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Pierre and Miquelon', 'Northern America', 'Europe and Northern America', None),
#  ('Saint Vincent and the Grenadines', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Samoa', 'Polynesia', 'Oceania', Decimal('2796.67')),
#  ('Sao Tome and Principe', 'Middle Africa', 'Sub-Saharan Africa', Decimal('960.00')),
#  ('Saudi Arabia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('2149690.00')),
#  ('Senegal', 'Western Africa', 'Sub-Saharan Africa', Decimal('192530.00')),
#  ('Seychelles', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('460.00')),
#  ('Sierra Leone', 'Western Africa', 'Sub-Saharan Africa', Decimal('72180.00')),
#  ('Singapore', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('713.00')),
#  ('Sint Maarten (Dutch part)', 'Caribbean', 'Latin America and the Caribbean', Decimal('34.00')),
#  ('Solomon Islands', 'Melanesia', 'Oceania', Decimal('27990.00')),
#  ('Somalia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('627340.00')),
#  ('South Africa', 'Southern Africa', 'Sub-Saharan Africa', Decimal('1213090.00')),
#  ('South Sudan', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('631930.00')),
#  ('Sri Lanka', 'Southern Asia', 'Central and Southern Asia', Decimal('61877.91')),
#  ('State of Palestine', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Sudan', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('1868000.00')),
#  ('Suriname', 'South America', 'Latin America and the Caribbean', Decimal('156000.00')),
#  ('Syrian Arab Republic', 'Western Asia', 'Northern Africa and Western Asia', Decimal('183630.00')),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.00')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.00')),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.00')),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.00')),
#  ('Tokelau', 'Polynesia', 'Oceania', None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.00')),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.00')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.00')),
#  ('Türkiye', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.00')),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('950.00')),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.00')),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.00')),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.00')),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.00')),
#  ('Uzbekistan', 'Central Asia', 'Central and Southern Asia', Decimal('440595.17')),
#  ('Vanuatu', 'Melanesia', 'Oceania', Decimal('12190.00')),
#  ('Venezuela (Bolivarian Republic of)', 'South America', 'Latin America and the Caribbean', None),
#  ('Viet Nam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Wallis and Futuna Islands', 'Polynesia', 'Oceania', None),
#  ('Yemen', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Zambia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('743390.00')),
#  ('Zimbabwe', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('386850.00'))]

# %%
# %%sql
#
# select sum(Land_area) as total_land_area
# from geographic_location
# where Sub_region = 'Middle Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('3888270.00'),)]

# %% [markdown]
# ### 2. Calculate land area percentages for the Middle African countries using a static value
#
# Recall that, to find the percentage of land area each country in the `Middle Africa` sub-region occupies, we need to **divide each country’s land area with the `total_land_area`**, which we have calculated above. Copy and paste this land area value into a new query and calculate the percentages. Call this calculated column `pct_regional_land`.

# %%
# %%sql
# # Add your code here
# select Country_name, ROUND(Land_area/3888270.00 * 100) as pct_regional_land
# from geographic_location
# where sub_region = 'Middle Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32')),
#  ('Cameroon', Decimal('12')),
#  ('Central African Republic', Decimal('16')),
#  ('Chad', Decimal('32')),
#  ('Congo', None),
#  ('Democratic Republic of the Congo', None),
#  ('Equatorial Guinea', Decimal('1')),
#  ('Gabon', Decimal('7')),
#  ('Sao Tome and Principe', Decimal('0'))]

# %% [markdown]
# ### 3. Calculate land area percentages for the Middle African countries using a subquery
#
# Instead of using the static value above, let's improve our query by using a subquery to achieve the same result.
#
# Hint: The subquery in this case will be the query we created to find the total land area in Exercise 1.

# %%
# %%sql
# # Add your code here
# select Country_name, ROUND(Land_area/(
# select sum(Land_area) as total_land_area
# from geographic_location
# where Sub_region = 'Middle Africa'
# ) * 100) as pct_regional_land
# from geographic_location
# where sub_region = 'Middle Africa'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', Decimal('32')),
#  ('Cameroon', Decimal('12')),
#  ('Central African Republic', Decimal('16')),
#  ('Chad', Decimal('32')),
#  ('Congo', None),
#  ('Democratic Republic of the Congo', None),
#  ('Equatorial Guinea', Decimal('1')),
#  ('Gabon', Decimal('7')),
#  ('Sao Tome and Principe', Decimal('0'))]

# %% [markdown]
# ### Correlated subqueries
#
# With a normal nested subquery (uncorrelated), **it runs first and executes once**, returning value(s) to be used by the outer query. This is what we have above where our subquery calculates the land area sum for the `Middle Africa` sub-region, and this is the value that is returned to the outer query to calculate land area percentages.
#
# If we want to calculate the land area percentages for all the regions, we would need to manually edit the search string in the `WHERE` clause, which is not very practical.
#
# Instead, we can use a **correlated subquery**. This is a type of subquery that is **executed once for every row processed by the outer query**. It is often used when you need to perform a calculation based on values in the current row of the outer query. In our case, we want the subquery to calculate the land area sum based on the sub-region value of the current row being processed by the outer query.
#
# Below is a general syntax template where a correlated subquery has been used:

# %% [markdown]
# ```
# SELECT
#     outer_column1,
#     outer_column2
# FROM
#     outer_table AS outer_alias
# WHERE
#     expression operator (
#                         SELECT
#                             aggregate_function(inner_column)
#                         FROM
#                             inner_table AS inner_alias
#                         WHERE
#                             inner_column = outer_alias.outer_column2
#                         )
# ;
# ```

# %% [markdown]
# ### 4. Calculate country land area percentages for all the regions using a correlated subquery
#
# Transform the subquery in Exercise 2 into a correlated subquery that will calculate land area percentages for all the regions.
#
# Hint: Use the general syntax above to help you figure out how to achieve this.

# %%
# %%sql
# # Add your code here
# select Country_name, ROUND(Land_area/(
# select sum(Land_area) as total_land_area
# from geographic_location
# where Sub_region = g.Sub_region
# ) * 100, 2) as pct_regional_land
# from geographic_location as g
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('13.67')),
#  ('Algeria', Decimal('36.03')),
#  ('American Samoa', Decimal('2.77')),
#  ('Angola', Decimal('32.06')),
#  ('Anguilla', None),
#  ('Antigua and Barbuda', Decimal('0.21')),
#  ('Argentina', Decimal('17.77')),
#  ('Armenia', Decimal('0.82')),
#  ('Aruba', Decimal('0.09')),
#  ('Australia', Decimal('96.69')),
#  ('Azerbaijan', Decimal('2.37')),
#  ('Bahamas', None),
#  ('Bahrain', Decimal('0.02')),
#  ('Bangladesh', Decimal('2.73')),
#  ('Barbados', Decimal('0.21')),
#  ('Belize', Decimal('0.93')),
#  ('Benin', Decimal('1.97')),
#  ('Bermuda', Decimal('0.00')),
#  ('Bhutan', Decimal('0.80')),
#  ('Bolivia (Plurinational State of)', None),
#  ('Botswana', Decimal('21.38')),
#  ('Brazil', Decimal('54.27')),
#  ('British Virgin Islands', Decimal('0.07')),
#  ('Brunei Darussalam', Decimal('0.14')),
#  ('Burkina Faso', Decimal('4.77')),
#  ('Burundi', Decimal('0.43')),
#  ('Cabo Verde', Decimal('0.07')),
#  ('Cambodia', Decimal('4.57')),
#  ('Cameroon', Decimal('12.16')),
#  ('Canada', Decimal('95.62')),
#  ('Cayman Islands', Decimal('0.12')),
#  ('Central African Republic', Decimal('16.02')),
#  ('Chad', Decimal('32.38')),
#  ('Chile', Decimal('4.83')),
#  ('China', Decimal('83.06')),
#  ('Colombia', Decimal('7.20')),
#  ('Comoros', Decimal('0.03')),
#  ('Congo', None),
#  ('Cook Islands', None),
#  ('Costa Rica', Decimal('2.08')),
#  ("Côte d'Ivoire", None),
#  ('Cuba', Decimal('49.92')),
#  ('Curaçao', None),
#  ('Cyprus', Decimal('0.26')),
#  ("Democratic People's Republic of Korea", None),
#  ('Democratic Republic of the Congo', None),
#  ('Djibouti', Decimal('0.39')),
#  ('Dominica', Decimal('0.36')),
#  ('Dominican Republic', Decimal('23.21')),
#  ('Ecuador', Decimal('1.61')),
#  ('Egypt', None),
#  ('El Salvador', Decimal('0.84')),
#  ('Equatorial Guinea', Decimal('0.72')),
#  ('Eritrea', Decimal('2.04')),
#  ('Eswatini', Decimal('0.65')),
#  ('Ethiopia', Decimal('18.97')),
#  ('Falkland Islands (Malvinas)', None),
#  ('Fiji', Decimal('3.45')),
#  ('French Guiana', None),
#  ('French Polynesia', Decimal('48.09')),
#  ('Gabon', Decimal('6.63')),
#  ('Gambia', None),
#  ('Georgia', Decimal('1.99')),
#  ('Ghana', Decimal('3.97')),
#  ('Greenland', Decimal('4.38')),
#  ('Grenada', Decimal('0.16')),
#  ('Guadeloupe', None),
#  ('Guam', Decimal('21.86')),
#  ('Guatemala', Decimal('4.37')),
#  ('Guinea', Decimal('4.28')),
#  ('Guinea-Bissau', Decimal('0.49')),
#  ('Guyana', Decimal('1.28')),
#  ('Haiti', Decimal('13.24')),
#  ('Honduras', Decimal('4.56')),
#  ('India', Decimal('62.33')),
#  ('Indonesia', Decimal('48.57')),
#  ('Iran (Islamic Republic of)', None),
#  ('Iraq', Decimal('12.44')),
#  ('Israel', Decimal('0.62')),
#  ('Jamaica', Decimal('5.20')),
#  ('Japan', Decimal('3.21')),
#  ('Jordan', Decimal('2.55')),
#  ('Kazakhstan', Decimal('72.01')),
#  ('Kenya', Decimal('9.57')),
#  ('Kiribati', Decimal('32.79')),
#  ('Kuwait', Decimal('0.51')),
#  ('Kyrgyzstan', None),
#  ("Lao People's Democratic Republic", None),
#  ('Lebanon', Decimal('0.29')),
#  ('Lesotho', Decimal('1.15')),
#  ('Liberia', Decimal('1.68')),
#  ('Libya', Decimal('26.62')),
#  ('Madagascar', Decimal('9.78')),
#  ('Malawi', Decimal('1.58')),
#  ('Malaysia', Decimal('8.50')),
#  ('Maldives', Decimal('0.01')),
#  ('Mali', Decimal('21.27')),
#  ('Marshall Islands', Decimal('7.29')),
#  ('Martinique', None),
#  ('Mauritania', Decimal('17.97')),
#  ('Mauritius', Decimal('0.03')),
#  ('Mayotte', None),
#  ('Mexico', Decimal('79.28')),
#  ('Micronesia (Federated States of)', None),
#  ('Mongolia', Decimal('13.72')),
#  ('Montserrat', None),
#  ('Morocco', Decimal('6.75')),
#  ('Mozambique', Decimal('13.22')),
#  ('Myanmar', Decimal('16.89')),
#  ('Namibia', Decimal('31.06')),
#  ('Nauru', Decimal('0.81')),
#  ('Nepal', Decimal('3.01')),
#  ('New Caledonia', Decimal('3.45')),
#  ('New Zealand', Decimal('3.31')),
#  ('Nicaragua', Decimal('4.91')),
#  ('Niger', Decimal('22.09')),
#  ('Nigeria', Decimal('15.88')),
#  ('Niue', None),
#  ('Northern Mariana Islands', Decimal('18.62')),
#  ('Oman', Decimal('8.87')),
#  ('Pakistan', Decimal('16.16')),
#  ('Palau', Decimal('18.62')),
#  ('Panama', Decimal('3.02')),
#  ('Papua New Guinea', Decimal('85.51')),
#  ('Paraguay', Decimal('2.58')),
#  ('Peru', Decimal('8.31')),
#  ('Philippines', Decimal('7.71')),
#  ('Puerto Rico', Decimal('4.26')),
#  ('Qatar', Decimal('0.33')),
#  ('Republic of Korea', None),
#  ('Réunion', None),
#  ('Rwanda', Decimal('0.41')),
#  ('Saint Barthélemy', None),
#  ('Saint Helena', None),
#  ('Saint Kitts and Nevis', None),
#  ('Saint Lucia', None),
#  ('Saint Martin (French Part)', None),
#  ('Saint Pierre and Miquelon', None),
#  ('Saint Vincent and the Grenadines', None),
#  ('Samoa', Decimal('38.75')),
#  ('Sao Tome and Principe', Decimal('0.02')),
#  ('Saudi Arabia', Decimal('61.62')),
#  ('Senegal', Decimal('3.36')),
#  ('Seychelles', Decimal('0.01')),
#  ('Sierra Leone', Decimal('1.26')),
#  ('Singapore', Decimal('0.02')),
#  ('Sint Maarten (Dutch part)', Decimal('0.02')),
#  ('Solomon Islands', Decimal('5.29')),
#  ('Somalia', Decimal('10.55')),
#  ('South Africa', Decimal('45.77')),
#  ('South Sudan', Decimal('10.62')),
#  ('Sri Lanka', Decimal('1.30')),
#  ('State of Palestine', None),
#  ('Sudan', Decimal('28.26')),
#  ('Suriname', Decimal('1.01')),
#  ('Syrian Arab Republic', Decimal('5.26')),
#  ('Tajikistan', Decimal('3.70')),
#  ('Thailand', Decimal('13.22')),
#  ('Timor-Leste', Decimal('0.38')),
#  ('Togo', Decimal('0.95')),
#  ('Tokelau', None),
#  ('Tonga', Decimal('9.98')),
#  ('Trinidad and Tobago', Decimal('2.47')),
#  ('Tunisia', Decimal('2.35')),
#  ('Türkiye', None),
#  ('Turkmenistan', Decimal('12.53')),
#  ('Turks and Caicos Islands', Decimal('0.46')),
#  ('Tuvalu', Decimal('0.42')),
#  ('Uganda', Decimal('3.37')),
#  ('United Arab Emirates', Decimal('2.04')),
#  ('United Republic of Tanzania', None),
#  ('United States of America', None),
#  ('United States Virgin Islands', None),
#  ('Uruguay', Decimal('1.14')),
#  ('Uzbekistan', Decimal('11.75')),
#  ('Vanuatu', Decimal('2.30')),
#  ('Venezuela (Bolivarian Republic of)', None),
#  ('Viet Nam', None),
#  ('Wallis and Futuna Islands', None),
#  ('Yemen', None),
#  ('Zambia', Decimal('12.50')),
#  ('Zimbabwe', Decimal('6.50'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Calculate the total land area of the 'Middle Africa' sub-region

# %%
# %%sql
#
# SELECT
#     SUM(Land_area) as total_land_area
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';

# %% [markdown]
# This query will return a single value which is the sum of all of the `Land_area` for the `Middle Africa` sub-region.

# %% [markdown]
# ### 2. Calculate land area percentages for the Middle African countries using a static value
#
# To calculate the percentages, we select the country names and the land area for each country, which we then divide by the total area for Middle Africa multiplied by 100 (to get the percentage), and then round the result off.
#
# **Note:** In the above query, we calculated a `total_land_area` of **"3888270.00"** which we'll use in the query below to calculate percentages for each country.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area/3888270.00*100) AS  pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';

# %% [markdown]
# ### 3. Calculate land area percentages for the Middle African countries using a subquery
#
# We replace the static value above with the query that generated that result (the query in Exercise 1).

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = g.Sub_region) * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location as g
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('13.67')),
#  ('Algeria', Decimal('36.03')),
#  ('American Samoa', Decimal('2.77')),
#  ('Angola', Decimal('32.06')),
#  ('Anguilla', None),
#  ('Antigua and Barbuda', Decimal('0.21')),
#  ('Argentina', Decimal('17.77')),
#  ('Armenia', Decimal('0.82')),
#  ('Aruba', Decimal('0.09')),
#  ('Australia', Decimal('96.69')),
#  ('Azerbaijan', Decimal('2.37')),
#  ('Bahamas', None),
#  ('Bahrain', Decimal('0.02')),
#  ('Bangladesh', Decimal('2.73')),
#  ('Barbados', Decimal('0.21')),
#  ('Belize', Decimal('0.93')),
#  ('Benin', Decimal('1.97')),
#  ('Bermuda', Decimal('0.00')),
#  ('Bhutan', Decimal('0.80')),
#  ('Bolivia (Plurinational State of)', None),
#  ('Botswana', Decimal('21.38')),
#  ('Brazil', Decimal('54.27')),
#  ('British Virgin Islands', Decimal('0.07')),
#  ('Brunei Darussalam', Decimal('0.14')),
#  ('Burkina Faso', Decimal('4.77')),
#  ('Burundi', Decimal('0.43')),
#  ('Cabo Verde', Decimal('0.07')),
#  ('Cambodia', Decimal('4.57')),
#  ('Cameroon', Decimal('12.16')),
#  ('Canada', Decimal('95.62')),
#  ('Cayman Islands', Decimal('0.12')),
#  ('Central African Republic', Decimal('16.02')),
#  ('Chad', Decimal('32.38')),
#  ('Chile', Decimal('4.83')),
#  ('China', Decimal('83.06')),
#  ('Colombia', Decimal('7.20')),
#  ('Comoros', Decimal('0.03')),
#  ('Congo', None),
#  ('Cook Islands', None),
#  ('Costa Rica', Decimal('2.08')),
#  ("Côte d'Ivoire", None),
#  ('Cuba', Decimal('49.92')),
#  ('Curaçao', None),
#  ('Cyprus', Decimal('0.26')),
#  ("Democratic People's Republic of Korea", None),
#  ('Democratic Republic of the Congo', None),
#  ('Djibouti', Decimal('0.39')),
#  ('Dominica', Decimal('0.36')),
#  ('Dominican Republic', Decimal('23.21')),
#  ('Ecuador', Decimal('1.61')),
#  ('Egypt', None),
#  ('El Salvador', Decimal('0.84')),
#  ('Equatorial Guinea', Decimal('0.72')),
#  ('Eritrea', Decimal('2.04')),
#  ('Eswatini', Decimal('0.65')),
#  ('Ethiopia', Decimal('18.97')),
#  ('Falkland Islands (Malvinas)', None),
#  ('Fiji', Decimal('3.45')),
#  ('French Guiana', None),
#  ('French Polynesia', Decimal('48.09')),
#  ('Gabon', Decimal('6.63')),
#  ('Gambia', None),
#  ('Georgia', Decimal('1.99')),
#  ('Ghana', Decimal('3.97')),
#  ('Greenland', Decimal('4.38')),
#  ('Grenada', Decimal('0.16')),
#  ('Guadeloupe', None),
#  ('Guam', Decimal('21.86')),
#  ('Guatemala', Decimal('4.37')),
#  ('Guinea', Decimal('4.28')),
#  ('Guinea-Bissau', Decimal('0.49')),
#  ('Guyana', Decimal('1.28')),
#  ('Haiti', Decimal('13.24')),
#  ('Honduras', Decimal('4.56')),
#  ('India', Decimal('62.33')),
#  ('Indonesia', Decimal('48.57')),
#  ('Iran (Islamic Republic of)', None),
#  ('Iraq', Decimal('12.44')),
#  ('Israel', Decimal('0.62')),
#  ('Jamaica', Decimal('5.20')),
#  ('Japan', Decimal('3.21')),
#  ('Jordan', Decimal('2.55')),
#  ('Kazakhstan', Decimal('72.01')),
#  ('Kenya', Decimal('9.57')),
#  ('Kiribati', Decimal('32.79')),
#  ('Kuwait', Decimal('0.51')),
#  ('Kyrgyzstan', None),
#  ("Lao People's Democratic Republic", None),
#  ('Lebanon', Decimal('0.29')),
#  ('Lesotho', Decimal('1.15')),
#  ('Liberia', Decimal('1.68')),
#  ('Libya', Decimal('26.62')),
#  ('Madagascar', Decimal('9.78')),
#  ('Malawi', Decimal('1.58')),
#  ('Malaysia', Decimal('8.50')),
#  ('Maldives', Decimal('0.01')),
#  ('Mali', Decimal('21.27')),
#  ('Marshall Islands', Decimal('7.29')),
#  ('Martinique', None),
#  ('Mauritania', Decimal('17.97')),
#  ('Mauritius', Decimal('0.03')),
#  ('Mayotte', None),
#  ('Mexico', Decimal('79.28')),
#  ('Micronesia (Federated States of)', None),
#  ('Mongolia', Decimal('13.72')),
#  ('Montserrat', None),
#  ('Morocco', Decimal('6.75')),
#  ('Mozambique', Decimal('13.22')),
#  ('Myanmar', Decimal('16.89')),
#  ('Namibia', Decimal('31.06')),
#  ('Nauru', Decimal('0.81')),
#  ('Nepal', Decimal('3.01')),
#  ('New Caledonia', Decimal('3.45')),
#  ('New Zealand', Decimal('3.31')),
#  ('Nicaragua', Decimal('4.91')),
#  ('Niger', Decimal('22.09')),
#  ('Nigeria', Decimal('15.88')),
#  ('Niue', None),
#  ('Northern Mariana Islands', Decimal('18.62')),
#  ('Oman', Decimal('8.87')),
#  ('Pakistan', Decimal('16.16')),
#  ('Palau', Decimal('18.62')),
#  ('Panama', Decimal('3.02')),
#  ('Papua New Guinea', Decimal('85.51')),
#  ('Paraguay', Decimal('2.58')),
#  ('Peru', Decimal('8.31')),
#  ('Philippines', Decimal('7.71')),
#  ('Puerto Rico', Decimal('4.26')),
#  ('Qatar', Decimal('0.33')),
#  ('Republic of Korea', None),
#  ('Réunion', None),
#  ('Rwanda', Decimal('0.41')),
#  ('Saint Barthélemy', None),
#  ('Saint Helena', None),
#  ('Saint Kitts and Nevis', None),
#  ('Saint Lucia', None),
#  ('Saint Martin (French Part)', None),
#  ('Saint Pierre and Miquelon', None),
#  ('Saint Vincent and the Grenadines', None),
#  ('Samoa', Decimal('38.75')),
#  ('Sao Tome and Principe', Decimal('0.02')),
#  ('Saudi Arabia', Decimal('61.62')),
#  ('Senegal', Decimal('3.36')),
#  ('Seychelles', Decimal('0.01')),
#  ('Sierra Leone', Decimal('1.26')),
#  ('Singapore', Decimal('0.02')),
#  ('Sint Maarten (Dutch part)', Decimal('0.02')),
#  ('Solomon Islands', Decimal('5.29')),
#  ('Somalia', Decimal('10.55')),
#  ('South Africa', Decimal('45.77')),
#  ('South Sudan', Decimal('10.62')),
#  ('Sri Lanka', Decimal('1.30')),
#  ('State of Palestine', None),
#  ('Sudan', Decimal('28.26')),
#  ('Suriname', Decimal('1.01')),
#  ('Syrian Arab Republic', Decimal('5.26')),
#  ('Tajikistan', Decimal('3.70')),
#  ('Thailand', Decimal('13.22')),
#  ('Timor-Leste', Decimal('0.38')),
#  ('Togo', Decimal('0.95')),
#  ('Tokelau', None),
#  ('Tonga', Decimal('9.98')),
#  ('Trinidad and Tobago', Decimal('2.47')),
#  ('Tunisia', Decimal('2.35')),
#  ('Türkiye', None),
#  ('Turkmenistan', Decimal('12.53')),
#  ('Turks and Caicos Islands', Decimal('0.46')),
#  ('Tuvalu', Decimal('0.42')),
#  ('Uganda', Decimal('3.37')),
#  ('United Arab Emirates', Decimal('2.04')),
#  ('United Republic of Tanzania', None),
#  ('United States of America', None),
#  ('United States Virgin Islands', None),
#  ('Uruguay', Decimal('1.14')),
#  ('Uzbekistan', Decimal('11.75')),
#  ('Vanuatu', Decimal('2.30')),
#  ('Venezuela (Bolivarian Republic of)', None),
#  ('Viet Nam', None),
#  ('Wallis and Futuna Islands', None),
#  ('Yemen', None),
#  ('Zambia', Decimal('12.50')),
#  ('Zimbabwe', Decimal('6.50'))]

# %% [markdown]
# When we execute this, the inner query runs first and calculates the sum value, then “passes” that to the outer query to get the percentages. A subquery that passes a single value to the outer query is known as a **scalar subquery.**
#
# The benefit of using the subquery instead of the actual value is that if we want to do the same for another sub-region, we can just change the search string, “Middle Africa”, for example, to "Polynesia". It will process the same calculation using the Polynesian data. These types of calculations are known as **dynamic**. By changing some of the filters, we automatically calculate the corresponding sum.

# %% [markdown]
# ### 4. Calculate land area percentages for all the regions using a correlated subquery
#
# We replace **“Middle Africa”** with a reference to the field that will change for each row, that is, the `Sub_region`. In order for this to work, we have to give the table in our main query an alias, **`g`**, so that when we refer to it in the subquery, SQL knows we are talking about the outer query’s table.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = g.Sub_region) * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location AS g;

# %% [markdown]
# As SQL looks at the first row in **`g`**, the sub-region of the first row is **`g.sub-Region`**.
#
# So for the first row, the sub-region will be `Central and Southern Asia`. The inner query will then execute, filtering out the Central and Southern Asia data, and calculate the sum of the land area in Central and Southern Asia. The main query then uses that value to calculate the percentage. SQL then moves to the second row. This time, the sub-region is `Northern Africa and Western Asia`, which the subquery uses again, and passes back to the main query, and so on.

# %% [markdown]
# The downside of using correlated subqueries is that they can be quite inefficient. This is because the subquery may be evaluated once for each row processed by the outer query. For example, once we have calculated the total area for Middle Africa, the same calculation will be repeated for another row.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
