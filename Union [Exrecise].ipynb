# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Union

# %% [markdown]
# In this exercise, we will explore different SQL union statements in order to cross-examine data contained in multiple tables in a dataset.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn to:
# - Use unions to stack the rows of similar tables.

# %% [markdown]
# First, let's load our database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# Establish a connection to a SQLite database file.
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/The%20chinook%20database%20ERD.jpeg"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: The Chinook database ERD</em>
# </div>
#
#  <em> <a href="https://www.sqlitetutorial.net/sqlite-sample-database/">Image source</a></em>

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# Use the `UNION` operator to combine information from the tracks and albums tables into a single list.

# %%
# %%sql
#
# select t.Name as Track_name, t.AlbumId
# from tracks as t
# union
# select a.Title as Album_title, a.AlbumId
# from albums as a;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('"40"', 239),
#  ('"?"', 231),
#  ('"Eine Kleine Nachtmusik" Serenade In G, K. 525: I. Allegro', 281),
#  ('#1 Zero', 11),
#  ('#9 Dream', 255),
#  ("'Round Midnight", 48),
#  ('(Anesthesia) Pulling Teeth', 150),
#  ('(Da Le) Yaleo', 46),
#  ("(I Can't Help) Falling In Love With You", 241),
#  ('(Oh) Pretty Woman', 242),
#  ('(There Is) No Greater Love (Teo Licks)', 322),
#  ('(We Are) The Road Crew', 160),
#  ('(White Man) In Hammersmith Palais', 211),
#  ('(Wish I Could) Hideaway', 55),
#  ('...And Found', 231),
#  ('...And Justice For All', 156),
#  ('...In Translation', 230),
#  ('.07%', 228),
#  ('01 - Prowler', 100),
#  ('02 - Sanctuary', 100),
#  ('03 - Remember Tomorrow', 100),
#  ('04 - Running Free', 100),
#  ('05 - Phantom of the Opera', 100),
#  ('06 - Transylvania', 100),
#  ('07 - Strange World', 100),
#  ('08 - Charlotte the Harlot', 100),
#  ('09 - Iron Maiden', 100),
#  ('1/2 Full', 180),
#  ('100% HardCore', 184),
#  ('13 Years Of Grief', 14),
#  ('14 Years', 92),
#  ('16 Toneladas', 84),
#  ('1979', 202),
#  ('19th Nervous Breakdown', 216),
#  ('1° De Julho', 56),
#  ('1º De Julho', 139),
#  ('2 A.M.', 113),
#  ('2 Minutes To Midnight', 95),
#  ('2 Minutes To Midnight', 102),
#  ('2 Minutes To Midnight', 104),
#  ('2 Minutes To Midnight', 107),
#  ('2 Minutes To Midnight', 108),
#  ('2 X 4', 151),
#  ('2,000 Man', 126),
#  ('20 Flight Rock', 12),
#  ('200 Years Old', 31),
#  ('20th Century Masters - The Millennium Collection: The Best of Scorpions', 257),
#  ('2112 Overture', 196),
#  ('22 Acacia Avenue', 112),
#  ('24 Caprices, Op. 1, No. 24, for Solo Violin, in A Minor', 339),
#  ('3 Gymnopédies: No.1 - Lent Et Grave, No.3 - Lent Et Douloureux', 332),
#  ('32 Dentes', 224),
#  ('5.15', 221),
#  ('51st Anniversary', 120),
#  ('A Banda', 23),
#  ('A Bencao E Outros', 247),
#  ('A Benihana Christmas, Pts. 1 & 2', 251),
#  ('A Carta', 70),
#  ('A Castle Full Of Rascals', 63),
#  ('A Copland Celebration, Vol. I', 296),
#  ('A Cor Do Sol', 26),
#  ('A Cor Do Sol', 27),
#  ('A Cura', 142),
#  ('A Day In the Life', 227),
#  ('A Different Kind Of Blue', 176),
#  ('A E O Z', 42),
#  ('A Estrada', 26),
#  ('A Estrada', 27),
#  ('A Festa Do Santo Reis', 223),
#  ('A Kind Of Magic', 36),
#  ('A Luz De Tieta', 21),
#  ('A Man And A Woman', 235),
#  ('A Matter of Life and Death', 94),
#  ('A Measure of Salvation', 227),
#  ('A Melhor Forma', 224),
#  ('A Menina Dança', 145),
#  ("A Midsummer Night's Dream, Op.61 Incidental Music: No.7 Notturno", 326),
#  ('A Moça e a Chuva', 161),
#  ('A New Flame', 141),
#  ('A Noite Do Meu Bem', 158),
#  ('A Novidade', 73),
#  ('A Novidade (Live)', 86),
#  ('A Paz', 33),
#  ('A Paz', 73),
#  ('A Real Dead One', 95),
#  ('A Real Live One', 96),
#  ('A Room At The Heartbreak Hotel', 234),
#  ('A Rua', 47),
#  ('A Small Victory', 75),
#  ('A Sombra Da Maldade', 26),
#  ('A Sombra Da Maldade', 27),
#  ('A Soprano Inspired', 285),
#  ('A Statistic', 18),
#  ('A Sua', 191),
#  ('A Tale of Two Cities', 229),
#  ('A Tarde', 123),
#  ('A TempestadeTempestade Ou O Livro Dos Dias', 139),
#  ('A Touch Away', 63),
#  ('A Twist In The Tail', 66),
#  ('A Via Láctea', 139),
#  ('A Volta Da Asa Branca', 85),
#  ('A World Without Heroes', 126),
#  ('A Última Guerra', 199),
#  ('A-Sides', 203),
#  ('A.N.D.R.O.T.A.Z.', 14),
#  ('Abandoned', 231),
#  ('Abraham, Martin And John', 146),
#  ('Abrir A Porta', 34),
#  ('Absolute Zero', 76),
#  ('Acacia Avenue', 102),
#  ('Ace Of Spades', 160),
#  ('Acelerou', 69),
#  ('Acelerou', 70),
#  ('Aces High', 102),
#  ('Aces High', 107),
#  ('Achilles Last Stand', 136),
#  ('Achtung Baby', 232),
#  ('Acrobat', 232),
#  ('Act IV, Symphony', 331),
#  ('Action', 67),
#  ('Acústico', 224),
#  ('Acústico MTV', 167),
#  ('Acústico MTV [Live]', 26),
#  ('Adagio for Strings from the String Quartet, Op. 11', 294),
#  ('Adams, John: The Chairman Dances', 307),
#  ('Adeus', 247),
#  ('Adios nonino', 329),
#  ('Admirável Gado Novo', 57),
#  ('Adoled (Ocean)', 184),
#  ('Adorate Deum: Gregorian Chant from the Proper of the Mass', 272),
#  ('Adrift', 231),
#  ('Advance Romance', 31),
#  ('Aeroplane Flies High', 201),
#  ('Afraid', 162),
#  ('Afraid To Shoot Strangers', 96),
#  ('Afraid To Shoot Strangers', 99),
#  ('Afraid To Shoot Strangers', 103),
#  ('Africa Bamba', 46),
#  ('Afrociberdelia', 24),
#  ('After Midnight', 72),
#  ('Aftermath', 220),
#  ('Again', 141),
#  ('Age Of Innocence', 98),
#  ('Agora Que O Dia Acordou', 47),
#  ('Aguia De Ouro 2001', 32),
#  ("Ain't My Bitch", 151),
#  ("Ain't Talkin' 'Bout Love", 244),
#  ("Ain't Talkin' 'bout Love", 243),
#  ('Ainda Lembro', 145),
#  ('Ainda É Cedo', 140),
#  ('Alabama Song', 214),
#  ('Alagados', 169),
#  ('Alarum', 220),
#  ('Alberta', 73),
#  ('Album Of The Year', 74),
#  ('Alcohol', 122),
#  ('Alcohol Fueled Brewtality Live! [Disc 1]', 14),
#  ('Alcohol Fueled Brewtality Live! [Disc 2]', 15),
#  ('Alegria, Alegria', 23),
#  ('Alexander the Great', 111),
#  ('Ali', 199),
#  ('Alice', 34),
#  ('Alive', 181),
#  ('All Along The Watchtower', 237),
#  ('All Because Of You', 235),
#  ('All Dead, All Dead', 186),
#  ('All For You', 14),
#  ('All I Really Want', 6),
#  ('All I Want Is You', 237),
#  ('All I Want Is You', 238),
#  ('All My Life', 81),
#  ('All My Love', 130),
#  ('All My Love', 258),
#  ('All Night Thing', 269),
#  ('All Star', 33),
#  ("All That You Can't Leave Behind", 233),
#  ('All Within My Hands', 155),
#  ('All or None', 180),
#  ('All the Best Cowboys Have Daddy Issues', 230),
#  ('Allegri: Miserere', 273),
#  ('Aloha', 139),
#  ('Always Be All Right', 123),
#  ('Always Forever Now', 176),
#  ('Always On The Run', 141),
#  ('Always With Me, Always With You', 121),
#  ('Alô Alô Marciano', 34),
#  ('Alô, Alô, Marciano', 71),
#  ('Am I Evil?', 149),
#  ('Amanda', 262),
#  ('Amanhã Não Se Sabe', 225),
#  ('Amar É Tudo', 70),
#  ('Amazing', 5),
#  ('American Gothic', 212),
#  ('American Idiot', 89),
#  ('American Woman', 141),
#  ('Amor De Muito', 24),
#  ('Amor Demais', 28),
#  ('Amy Amy Amy (Outro)', 322),
#  ('And the Cradle Will Rock...', 243),
#  ('Ando Meio Desligado', 33),
#  ('Ando Meio Desligado', 42),
#  ('Aneurysm', 163),
#  ('Angel', 5),
#  ('Angel', 141),
#  ('Angel Dust', 75),
#  ('Angel Of Harlem', 237),
#  ('Angel Of Harlem', 238),
#  ('Angela', 8),
#  ('Animal', 67),
#  ('Animal', 182),
#  ('Another Life', 101),
#  ('Another One Bites The Dust', 185),
#  ('Another Round', 80),
#  ('Antene Se', 25),
#  ('Antes Das Seis', 140),
#  ('Anthem', 196),
#  ('Any Colour You Like', 183),
#  ('Anya', 66),
#  ("Anyone's Daughter", 60),
#  ('Anything Goes', 90),
#  ('Anyway, Anyhow, Anywhere', 221),
#  ('Ao Meu Redor', 145),
#  ('Ao Vivo [IMPORT]', 248),
#  ('Aonde Quer Que Eu Va', 168),
#  ('Aos Leões', 161),
#  ('Apache Rose Peacock', 193),
#  ('Apesar De Você', 23),
#  ('Appetite for Destruction', 90),
#  ('Aprendendo A Jogar', 71),
#  ('Aquaman', 254),
#  ('Aquarela (Toquinho)', 53),
#  ('Aquele Abraço', 73),
#  ('Aquilo', 143),
#  ('Arc', 180),
#  ('Are We The Waiting', 89),
#  ('Are You Experienced?', 120),
#  ('Are You Gonna Be My Girl', 119),
#  ('Are You Gonna Go My Way', 141),
#  ('Aria Mit 30 Veränderungen, BWV 988 "Goldberg Variations": Aria', 277),
#  ('Armada: Music from the Courts of England and Spain', 319),
#  ('Armadura', 259),
#  ('Armageddon It', 67),
#  ('Arms Around Your Love', 270),
#  ('Army Ants', 220),
#  ('Army Reserve', 179),
#  ('Around The World', 195),
#  ('Arquivo II', 168),
#  ('Arquivo Os Paralamas Do Sucesso', 169),
#  ('Arrepio', 145),
#  ('As Aparências Enganam', 71),
#  ('As Canções de Eu Tu Eles', 85),
#  ('As Dores do Mundo', 123),
#  ('As Pegadas Do Amor', 85),
#  ('As Profecias', 192),
#  ('As Rosas Não Falam (Beth Carvalho)', 53),
#  ('As Tears Go By', 216),
#  ('As The Years Go by', 197),
#  ('As We Sleep', 38),
#  ('Asa Branca', 85),
#  ('Asas', 78),
#  ('Ashes And Ghosts', 212),
#  ('Ashes To Ashes', 74),
#  ('Assaltaram A Gramática', 143),
#  ('Assim Caminha A Humanidade', 142),
#  ('Assum Preto', 85),
#  ('Astronomy', 35),
#  ('Atomic Punk', 244),
#  ('Atras Da Porta', 23),
#  ('Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', 21),
#  ('Atrás Do Trio Elétrico', 142),
#  ('Atrás da Porta', 71),
#  ('Attitude', 153),
#  ('Até Que Enfim Encontrei Você', 222),
#  ('Audioslave', 10),
#  ('Ava Adore', 202),
#  ('Ave Maria', 285),
#  ('Avisa', 78),
#  ('Aviso Aos Navegantes', 143),
#  ('Axé Bahia 2001', 29),
#  ('Azul', 70),
#  ('Azul Da Cor Do Mar', 222),
#  ('Açai', 70),
#  ('B-Sides 1980-1990', 234),
#  ('B.Y.O.B.', 207),
#  ('BBC Sessions [Disc 1] [Live]', 30),
#  ('BBC Sessions [Disc 2] [Live]', 127),
#  ("Baba O'Riley", 221),
#  ("Babe I'm Gonna Leave You", 132),
#  ('Baby', 42),
#  ('Baby Break It Down', 218),
#  ('Babyface', 240),
#  ('Babylon', 219),
#  ('Babylon', 220),
#  ('Bach: Goldberg Variations', 277),
#  ('Bach: Orchestral Suites Nos. 1 - 4', 327),
#  ('Bach: The Brandenburg Concertos', 300),
#  ('Bach: The Cello Suites', 278),
#  ('Bach: Toccata & Fugue in D Minor', 297),
#  ('Bach: Violin Concertos', 276),
#  ('Back Door Man', 214),
#  ('Back from Vacation', 251),
#  ('Back in the Village', 107),
#  ('Back off Bitch', 91),
#  ('Back to Black', 321),
#  ('BackBeat Soundtrack', 12),
#  ('Bad', 238),
#  ('Bad Apples', 91),
#  ('Bad Attitude', 61),
#  ('Bad Boy', 12),
#  ('Bad Boy Boogie', 4),
#  ('Bad Moon Rising', 54),
#  ('Bad Obsession', 91),
#  ('Bad Seed', 153),
#  ('Bad, Bad Leroy Brown', 83),
#  ('Badge', 72),
#  ('Baixo Rio', 47),
#  ('Baião Ambiental [Instrumental]', 24),
#  ('Baião Da Penha', 85),
#  ('Balada Da Paula', 84),
#  ('Balada Do Amor Inabalável', 199),
#  ('Balada Do Louco', 42),
#  ('Balanço', 223),
#  ('Ballot or the Bullet', 245),
#  ('Balls to the Wall', 2),
#  ("Baltar's Escape", 253),
#  ('Baltimore, DC', 68),
#  ('Band Members Discuss Tracks from "Revelations"', 271),
#  ('Banditismo Por Uma Questa', 25),
#  ('Banho De Lua', 42),
#  ('Bankrobber', 211),
#  ('Bark at the Moon', 170),
#  ('Bark at the Moon (Remastered)', 170),
#  ('Bartok: Violin & Viola Concertos', 325),
#  ('Barulhinho Bom', 145),
#  ('Basket Case', 39),
#  ('Basketball', 249),
#  ('Bass Trap', 234),
#  ('Bastille Day', 196),
#  ('Bat Macumba', 42),
#  ('Batalha Naval', 259),
#  ('Bate Lata', 29),
#  ('Battery', 152),
#  ('Battlestar Galactica (Classic), Season 1', 253),
#  ('Battlestar Galactica, Pt. 1', 253),
#  ('Battlestar Galactica, Pt. 2', 253),
#  ('Battlestar Galactica, Pt. 3', 253),
#  ('Battlestar Galactica, Season 3', 227),
#  ('Battlestar Galactica: The Story So Far', 226),
#  ('Be Aggressive', 75),
#  ('Be Good Johnny', 147),
#  ('Be Mine', 189),
#  ('Be Quick Or Be Dead', 96),
#  ('Be Quick Or Be Dead', 99),
#  ('Be Quick Or Be Dead', 103),
#  ('Be Yourself', 11),
#  ('Beach Games', 251),
#  ('Beach Sequence', 176),
#  ('Beautiful Boy', 255),
#  ('Beautiful Day', 233),
#  ('Because You Are', 201),
#  ('Been A Son', 163),
#  ('Beethoven Piano Sonatas: Moonlight & Pastorale', 304),
#  ('Beethoven: Symhonies Nos. 5 & 6', 284),
#  ("Beethoven: Symphony No. 6 'Pastoral' Etc.", 324),
#  ('Before You Accuse Me', 55),
#  ('Before You Accuse Me', 73),
#  ('Behind The Wall Of Sleep', 16),
#  ('Beija Eu', 145),
#  ('Beija-Flor', 45),
#  ('Beijo Partido', 159),
#  ('Beijo do Olhar', 161),
#  ('Beira Mar', 73),
#  ('Believe', 38),
#  ('Believe', 141),
#  ('Believe', 201),
#  ('Believe in Love', 257),
#  ('Believer', 174),
#  ('Bell Bottom Blues', 72),
#  ('Belong', 187),
#  ('Bem Devagar', 21),
#  ('Bem Leve', 145),
#  ('Ben Franklin', 251),
#  ('Berimbau', 52),
#  ('Berlim', 26),
#  ('Berlioz: Symphonie Fantastique', 312),
#  ('Best Of You', 79),
#  ('Best Thing', 38),
#  ('Beth', 37),
#  ('Beth', 126),
#  ('Better Halves', 228),
#  ('Better Man', 178),
#  ('Better Than You', 153),
#  ('Beyond Good And Evil', 212),
#  ('Bichos Escrotos (Vinheta)', 224),
#  ('Bicycle Race', 185),
#  ('Big Bad Bill (Is Sweet William Now)', 242),
#  ('Big City Nights', 257),
#  ('Big Machine', 246),
#  ('Big Ones', 5),
#  ('Big Wave', 179),
#  ('Billie Jean', 270),
#  ('Binky The Doormat', 189),
#  ('Biruta', 184),
#  ('Bite The Bullet', 160),
#  ('Bitter Pill', 162),
#  ('Bitter Suite: Brief Encounter / Lost Weekend / Blue Angel', 144),
#  ('Bittersweet Me', 189),
#  ('Bizet: Carmen Highlights', 313),
#  ('Black', 178),
#  ('Black', 181),
#  ('Black Album', 148),
#  ('Black Capricorn Day', 117),
#  ('Black Country Woman', 135),
#  ('Black Diamond', 37),
#  ('Black Dog', 127),
#  ('Black Dog', 131),
#  ('Black Hole Sun', 203),
#  ('Black Light Syndrome', 208),
#  ('Black Moon Creeping', 210),
#  ('Black Mountain Side', 132),
#  ('Black Night', 61),
#  ('Black Sabbath', 16),
#  ('Black Sabbath', 256),
#  ('Black Sabbath Vol. 4 (Remaster)', 17),
#  ('Black Satin', 49),
#  ('Black Velveteen', 141),
#  ('Blackened', 156),
#  ('Blanco', 145),
#  ('Bleed The Freak', 7),
#  ('Bleed Together', 203),
#  ('Bleeding Me', 151),
#  ('Blew', 163),
#  ('Blind Curve: Vocal Under A Bloodlight / Passing Strangers / Mylo / Perimeter Walk / Threshold', 144),
#  ('Blind Man', 5),
#  ('Blinded By Rainbows', 218),
#  ('Blissed & Gone', 201),
#  ('Blitzkrieg', 149),
#  ('Blizzard of Ozz', 171),
#  ('Blood', 182),
#  ('Blood Brothers', 97),
#  ('Blood Brothers', 108),
#  ('Blood In The Wall', 15),
#  ("Blood On The World's Hands", 113),
#  ('Blood Sugar Sex Magik', 193),
#  ('Bloodsucker', 59),
#  ('Blow Up The Outside World', 203),
#  ('Blow Your Mind', 116),
#  ('Blue Moods', 93),
#  ('Blue Rythm Fantasy', 51),
#  ('Blue Train', 175),
#  ('Blues Da Piedade', 57),
#  ('Blues For Pablo', 157),
#  ('Blues For Pablo (Alternate Take)', 157),
#  ('Boa Noite', 69),
#  ('Bodies', 191),
#  ('Body Count', 18),
#  ('Body Count Anthem', 18),
#  ("Body Count's In The House", 18),
#  ('Bohemian Rhapsody', 185),
#  ('Bongo Fury', 31),
#  ("Bonzo's Montreux", 128),
#  ('Boogie Blues', 51),
#  ('Boogie With Stu', 135),
#  ('Book Of Thel', 19),
#  ('Book of Hours', 208),
#  ('Booze Cruise', 250),
#  ('Bop Boogie', 51),
#  ('Bora-Bora', 167),
#  ('Bored To Tears', 14),
#  ('Boris The Spider', 221),
#  ('Born On The Bayou', 55),
#  ('Born To Booze', 14),
#  ('Born To Move', 55),
#  ('Born to Run', 230),
#  ('Borogodo', 124),
#  ('Bossa', 184),
#  ('Boulevard Of Broken Dreams', 89),
#  ('Bowels Of The Devil', 18),
#  ('Boys and Girls', 250),
#  ('Brain Damage', 183),
#  ('Brain Stew', 39),
#  ('Branch Closing', 251),
#  ('Brand New Car', 218),
#  ('Brasil', 56),
#  ('Brasil', 158),
#  ('Brasília 5:31', 167),
#  ('Brave New World', 97),
#  ('Brave New World', 108),
#  ('Breadfan', 149),
#  ('Break on Through', 214),
#  ('Breakdown', 92),
#  ('Breakfast In Bed', 64),
#  ('Breakfast In Bed', 241),
#  ('Breaking The Girl', 193),
#  ('Breaking The Law (Live)', 125),
#  ('Breaking The Rules', 1),
#  ('Breakthru', 36),
#  ('Breathe', 212),
#  ('Breed', 163),
#  ('Breed', 164),
#  ('Brejo Da Cruz', 23),
#  ('Brighter Than a Thousand Suns', 94),
#  ('Bring It On Home', 133),
#  ('Bring Me Your Cup', 241),
#  ('Bring Your Daughter... ...To The Slaughter', 105),
#  ('Bring Your Daughter... To The Slaughter', 96),
#  ('Bring Your Daughter... To The Slaughter...', 104),
#  ("Bring'em Back Alive", 10),
#  ("Bringin' On The Heartbreak", 67),
#  ('Broken City', 271),
#  ('Bron-Y-Aur Stomp', 134),
#  ('Bron-Yr-Aur', 135),
#  ('Brumário', 142),
#  ('Buk-In-Hamm Palace', 141),
#  ('Bullet The Blue Sky', 237),
#  ('Bullet With Butterfly Wings', 202),
#  ('Bumbo Da Mangueira', 34),
#  ('Burden In My Hand', 203),
#  ('Burn', 43),
#  ('Burn Away', 81),
#  ('Burning Up', 175),
#  ('Busca Vida', 168),
#  ('Bush Doctor', 141),
#  ('Bushleager', 180),
#  ('Business School', 251),
#  ('Butterfly', 117),
#  ('By The Way', 194),
#  ('By-Tor And The Snow Dog', 196),
#  ('Bye Bye Blackbird', 48),
#  ('Bye, Bye Brasil', 23),
#  ('Bê-a-Bá', 191),
#  ("C'Mon Everybody", 12),
#  ("C'est La Vie", 241),
#  ('C.O.D.', 1),
#  ('Cabeça Dinossauro', 224),
#  ('Cabin Fever', 261),
#  ('Cabron', 194),
#  ('Cada Um Cada Um (A Namoradeira)', 28),
#  ('Cafezinho', 124),
#  ('Caffeine', 75),
#  ('Cajueiro', 191),
#  ('Cake: B-Sides and Rarities', 260),
#  ('Caleidoscópio', 167),
#  ('Caleidoscópio', 169),
#  ('Californication', 195),
#  ('Call Me At Cleo´s', 84),
#  ('Call Me a Dog', 269),
#  ('Call Of The Wild', 61),
#  ('Calling Dr. Love', 37),
#  ('Camarão que Dorme e Onda Leva', 248),
#  ('Camisa Verde 2001', 32),
#  ('Can I Play With Madness', 96),
#  ('Can I Play With Madness', 103),
#  ('Can I Play With Madness', 110),
#  ('Can You See Me', 120),
#  ("Can't Get There From Here", 190),
#  ("Can't Get This Stuff No More", 243),
#  ("Can't Get You Off My Mind", 141),
#  ("Can't Keep", 180),
#  ("Can't Stand Losing You", 215),
#  ("Can't Stop", 194),
#  ("Can't Stop Loving You", 243),
#  ('Candy Store Rock', 136),
#  ('Canned Heat', 117),
#  ('Canon and Gigue in D Major: I. Canon', 274),
#  ('Canta, Canta Mais', 8),
#  ('Canto De Ossanha', 52),
#  ('Canário Do Reino', 223),
#  ('Canção Do Novo Mundo', 158),
#  ('Canção Noturna', 199),
#  ('Caprichosos', 45),
#  ('Caralho Voador', 76),
#  ('Caras Como Eu', 225),
#  ('Carimbo', 259),
#  ('Carmen: Overture', 313),
#  ('Carmina Burana', 295),
#  ('Carmina Burana: O Fortuna', 295),
#  ('Carnaval 2001', 32),
#  ('Carnival Of Sorts', 190),
#  ('Carol', 12),
#  ('Carolina', 21),
#  ('Carolina', 23),
#  ('Carolina Hard-Core Ecstasy', 31),
#  ('Carouselambra', 130),
#  ('Carpe Diem Baby', 153),
#  ('Carried to Dust (Bonus Track Version)', 323),
#  ('Carry On', 270),
#  ('Carta Ao Tom 74', 52),
#  ('Cartao Postal', 166),
#  ('Casa', 142),
#  ('Casa no Campo', 71),
#  ("Cascades : I'm Not Your Lover", 63),
#  ('Casinha Feliz', 85),
#  ('Casino Night - Season Finale', 250),
#  ('Caso Você Queira Saber', 159),
#  ('Catch-22', 229),
#  ('Cathedral', 242),
#  ('Catimbo', 259),
#  ('Caught Somewhere in Time', 111),
#  ('Cavalleria Rusticana \\ Act \\ Intermezzo Sinfonico', 302),
#  ('Caxangá', 158),
#  ('Caçador de Mim (Sá & Guarabyra)', 53),
#  ('Celebration Day', 134),
#  ('Celebration Day', 137),
#  ('Cesta Básica', 191),
#  ('Chains Of Misery', 99),
#  ('Changes', 17),
#  ('Changes', 88),
#  ('Chaos-Control', 208),
#  ('Chapa o Coco', 259),
#  ('Charles Anjo 45', 122),
#  ('Charpentier: Divertissements, Airs & Concerts', 328),
#  ('Chega no Suingue', 259),
#  ('Chemical Wedding', 19),
#  ('Cherub Rock', 202),
#  ('Chico Não Vai na Corimba', 248),
#  ('Child In Time', 59),
#  ('Child In Time (Son Of Aleric - Instrumental)', 61),
#  ("Childhood's End", 99),
#  ('Childhoods End?', 144),
#  ('Children Of The Damned', 102),
#  ('Children Of The Grave', 174),
#  ('Children of the Damned', 112),
#  ('Chill: Brazil (Disc 1)', 33),
#  ('Chill: Brazil (Disc 2)', 34),
#  ('Chocolate', 222),
#  ('Chopin: Piano Concertos Nos. 1 & 2', 301),
#  ('Choramingando', 124),
#  ('Christmas Party', 250),
#  ('Chronicle, Vol. 1', 54),
#  ('Chronicle, Vol. 2', 55),
#  ('Chuva No Brejo', 145),
#  ('Chão De Estrelas', 42),
#  ('Chão de Giz (Elba Ramalho)', 53),
#  ('Cidade', 25),
#  ('Cidade Negra - Hits', 27),
#  ('Cigano', 69),
#  ('Cigaro', 207),
#  ('Cinema Mudo', 169),
#  ('Circles', 121),
#  ('City Of Blinding Lights', 235),
#  ('Civil War', 92),
#  ('Clash City Rockers', 211),
#  ('Closer To The Heart', 196),
#  ('Cocaine', 72),
#  ('Cochise', 10),
#  ('Cocktails', 251),
#  ('Coda', 128),
#  ('Cold Day In The Sun', 80),
#  ('Cold Gin', 37),
#  ('Cold Hard Bitch', 119),
#  ('Cold Sweat', 115),
#  ('Cold Turkey', 255),
#  ('Colibri', 93),
#  ('Collaborators', 227),
#  ('Collision', 74),
#  ('Collision', 228),
#  ('Collision', 231),
#  ('Com A Perna No Mundo', 41),
#  ('Com Açúcar E Com Afeto', 23),
#  ('Coma', 91),
#  ('Comatose', 179),
#  ('Come And Get Some Of This', 258),
#  ('Come Around Again', 119),
#  ('Come As You Are', 164),
#  ('Come Back', 81),
#  ('Come Back', 179),
#  ('Come Fly With Me', 83),
#  ('Come Taste The Band', 58),
#  ('Começaria Tudo Outra Vez', 41),
#  ('Começaria Tudo Outra Vez (Maria Creuza)', 53),
#  ('Comida', 224),
#  ("Comin' Home", 58),
#  ("Comin' Home", 126),
#  ('Coming In Hot', 141),
#  ('Commercial 1', 258),
#  ('Commercial 2', 258),
#  ('Commotion', 54),
#  ('Communication Breakdown', 30),
#  ('Communication Breakdown', 132),
#  ('Communication Breakdown(2)', 30),
#  ('Communication Breakdown(3)', 30),
#  ('Como Estais Amigos', 114),
#  ('Como É Duro Trabalhar', 52),
#  ('Compadre', 222),
#  ('Company Man', 228),
#  ('Complete Control', 211),
#  ('Comportamento Geral', 41),
#  ('Compositores', 165),
#  ('Compulsion', 48),
#  ('Computadores Fazem Arte', 25),
#  ('Concert pour 4 Parties de V**les, H. 545: I. Prelude', 328),
#  ('Concerto No. 1 in E Major, RV 269 "Spring": I. Allegro', 275),
#  ('Concerto No.2 in F Major, BWV1047, I. Allegro', 300),
#  ('Concerto for 2 Violins in D Minor, BWV 1043: I. Vivace', 276),
#  ('Concerto for Cello and Orchestra in E minor, Op. 85: I. Adagio - Moderato', 306),
#  ('Concerto for Clarinet in A Major, K. 622: II. Adagio', 282),
#  ('Concerto for Piano No. 2 in F Minor, Op. 21: II. Larghetto', 301),
#  ('Concerto for Violin, Strings and Continuo in G Major, Op. 3, No. 9: I. Allegro', 342),
#  ('Conciliação', 26),
#  ('Condição', 142),
#  ('Confidence Man', 230),
#  ('Confidência', 78),
#  ('Confirmed Dead', 261),
#  ('Conflict Resolution', 250),
#  ('Confusion', 7),
#  ('Construção / Deus Lhe Pague', 23),
#  ('Contraband', 246),
#  ('Copacabana (Live)', 86),
#  ('Corazon Espinado', 46),
#  ('Coração De Estudante', 158),
#  ('Coração Em Desalinho', 248),
#  ('Coração do Agreste (Fafá de Belém)', 53),
#  ('Corcovado (Quiet Nights Of Quiet Stars)', 8),
#  ('Corduroy', 178),
#  ('Core', 206),
#  ('Corinna', 217),
#  ('Cornucopia', 17),
#  ('Coronation Drop', 51),
#  ('Coroné Antonio Bento', 56),
#  ('Coroné Antonio Bento', 222),
#  ('Corpo De Lama', 24),
#  ('Corpse (These Chains Are Way Too Long)', 176),
#  ('Cosmic Fiend', 209),
#  ('Cotidiano N 2', 247),
#  ('Cotton Fields', 55),
#  ('Country Feedback', 187),
#  ('Crack Hitler', 75),
#  ('Crackerman', 206),
#  ('Crash Course In Brain Surgery', 149),
#  ('Crazy', 5),
#  ('Crazy Little Thing Called Love', 185),
#  ('Crazy Train', 171),
#  ('Crazy Train', 174),
#  ('Creep', 206),
#  ('Creeping Death', 9),
#  ('Creeping Death', 154),
#  ('Criança De Domingo', 24),
#  ('Cristina Nº 2', 222),
#  ('Cropduster', 180),
#  ('Crossfire', 205),
#  ('Crossroads', 72),
#  ('Crossroads, Pt. 1', 227),
#  ('Crossroads, Pt. 2', 227),
#  ('Crumbs From Your Table', 235),
#  ('Crushing Day', 121),
#  ('Cry For Love', 40),
#  ("Cryin'", 5),
#  ('Crying In The Rain', 141),
#  ('Crystal Ball', 141),
#  ('Cuando A Noite Vai Chegando', 124),
#  ('Cuando Eu For Pro Ceu', 124),
#  ('Cucamonga', 31),
#  ('Cuckoo For Caca', 76),
#  ('Cuitelinho', 158),
#  ('Cure', 151),
#  ('Cursed Diamonds', 209),
#  ('Custard Pie', 44),
#  ('Cuyahoga', 190),
#  ('Cássia Eller - Coleção Sem Limite [Disc 2]', 56),
#  ('Cássia Eller - Sem Limite [Disc 1]', 57),
#  ('Cérebro Eletrônico', 145),
#  ('Cérebro Eletrônico (Live)', 86),
#  ('D Note', 18),
#  ("D'Yer Mak'er", 129),
#  ('D.O.C.', 229),
#  ('DOA', 79),
#  ('Da Lama Ao Caos', 25),
#  ("Daddy's Gonna Pay For Your Crashed Car", 240),
#  ('Damage Case', 149),
#  ('Damage Inc.', 152),
#  ('Dance', 160),
#  ('Dance Enquanto é Tempo', 123),
#  ('Dance Of Death', 98),
#  ('Dance the Night Away', 243),
#  ('Dancing Barefoot', 234),
#  ('Dancing Days', 129),
#  ('Dancing In The Street', 242),
#  ('Dancin´Days', 143),
#  ('Dandelion', 11),
#  ('Daniela', 29),
#  ('Danny Boy, Danny Boy', 258),
#  ('Dança Da Solidão', 145),
#  ('Dark Corners', 208),
#  ('Dark Side Of The Cog', 93),
#  ('Dark Side Of The Moon', 183),
#  ('Darlene', 128),
#  ('Das Lied Von Der Erde, Von Der Jugend', 305),
#  ('Daughter', 178),
#  ('Daughter', 182),
#  ('Dave', 231),
#  ('Dazed And Confused', 127),
#  ('Dazed And Confused', 137),
#  ('Dazed and Confused', 30),
#  ('Dazed and Confused', 132),
#  ('De Do Do Do, De Da Da Da', 215),
#  ('De Ja Vu', 111),
#  ('De La Luz', 38),
#  ('De Noite Na Cama', 145),
#  ('De Ouro E Marfim (Live)', 86),
#  ('Dead And Bloated', 206),
#  ('Dead And Broken', 88),
#  ('Dead Horse', 91),
#  ('Dealer', 58),
#  ('Debra Kadabra', 31),
#  ('Dee', 174),
#  ('Deep', 181),
#  ('Deep Purple In Rock', 59),
#  ('Deep Waters', 93),
#  ('Deeper Underground', 117),
#  ('Deixa', 52),
#  ('Deixa Entrar', 78),
#  ('Demorou!', 161),
#  ('Demorou...', 161),
#  ('Denúncia', 166),
#  ('Departure', 189),
#  ('Desafinado', 8),
#  ('Desaforo', 78),
#  ('Desculpe Babe', 42),
#  ('Desire', 237),
#  ('Desire', 238),
#  ('Desordem', 225),
#  ('Despertar', 262),
#  ('Destitute Illusions', 117),
#  ('Detroit Rock City', 37),
#  ('Deuce', 37),
#  ('Deuces Are Wild', 5),
#  ('Deus', 165),
#  ('Deus Ex Machina', 230),
#  ("Devil's Dance", 153),
#  ('Dezesseis', 139),
#  ('Dezesseis', 140),
#  ('Diamante De Mendigo', 192),
#  ('Diamonds And Rust (Live)', 125),
#  ('Diary of a Madman (Remastered)', 172),
#  ("Didgin' Out", 116),
#  ('Die Die My Darling', 35),
#  ('Die Walküre: The Ride of the Valkyries', 287),
#  ('Die With Your Boots On', 102),
#  ('Die With Your Boots On', 106),
#  ('Die Zauberflöte, K.620: "Der Hölle Rache Kocht in Meinem Herze"', 317),
#  ('Different World', 94),
#  ('Dig-Dig, Lambe-Lambe (Ao Vivo)', 29),
#  ('Diga Lá, Coração', 41),
#  ('Digging The Grave', 76),
#  ('Din Din Wo (Little Child)', 263),
#  ('Dindi (Dindi)', 8),
#  ('Dirty Day', 240),
#  ('Dirty Hands', 227),
#  ('Dirty Little Thing', 246),
#  ('Dirty Love', 160),
#  ('Dirty Water Dog', 245),
#  ('Dirty Window', 155),
#  ('Disappearing Act', 270),
#  ('Disarm', 202),
#  ('Disc Jockey Jump', 51),
#  ('Discotheque', 236),
#  ('Disenchanted Lullaby', 81),
#  ('Disposable Heroes', 152),
#  ('Dissident', 182),
#  ('Distance', 264),
#  ('Distractions', 228),
#  ('Diver Down', 242),
#  ('Diversity Day', 249),
#  ('Diversão', 224),
#  ('Divirta-Se (Saindo Da Sua)', 84),
#  ('Diwali', 251),
#  ('Djavan Ao Vivo - Vol. 02', 69),
#  ('Djavan Ao Vivo - Vol. 1', 70),
#  ('Do It For The Kids', 246),
#  ('Do No Harm', 230),
#  ('Do Nosso Amor', 124),
#  ('Do The Evolution', 178),
#  ('Do You Feel Loved', 236),
#  ('Do You Have Other Loves?', 47),
#  ('Do You Like The Way', 46),
#  ('Do You Love Me', 37),
#  ('Do You Love Me', 126),
#  ('Do what cha wanna', 13),
#  ('Doce De Carnaval (Candy All)', 87),
#  ("Doesn't Remind Me", 11),
#  ('Dog Eat Dog', 4),
#  ('Dois Pra Lá, Dois Pra Cá', 71),
#  ('Dois Índios', 161),
#  ('Doll', 82),
#  ('Domingo', 225),
#  ('Domino', 126),
#  ("Don't Cry", 92),
#  ("Don't Cry (Original)", 91),
#  ("Don't Damn Me", 91),
#  ("Don't Forget Me", 194),
#  ("Don't Go Away Mad (Just Go Away)", 162),
#  ("Don't Go Back To Rockville", 190),
#  ("Don't Lie To Me", 40),
#  ("Don't Look Back", 141),
#  ("Don't Look Back", 228),
#  ("Don't Look Now", 55),
#  ("Don't Look To The Eyes Of A Stranger", 114),
#  ("Don't Stand So Close to Me '86", 215),
#  ("Don't Stand so Close to Me", 215),
#  ("Don't Stop Me Now", 185),
#  ("Don't Take Your Love From Me", 51),
#  ("Don't Tread On Me", 148),
#  ("Don't You Cry", 40),
#  ('Dona (Roupa Nova)', 53),
#  ('Dosed', 194),
#  ("Double Talkin' Jive", 91),
#  ('Doutor', 27),
#  ('Down By The Seaside', 135),
#  ('Down On The Corner', 54),
#  ('Down Under', 147),
#  ('Down by the Sea', 147),
#  ('Downtown', 27),
#  ('Dr. Feelgood', 162),
#  ('Dr. Heckyll & Mr. Jive', 147),
#  ('Drain You', 163),
#  ('Drain You', 164),
#  ('Dream Of Mirrors', 97),
#  ('Dream Of Mirrors', 109),
#  ('Dreams', 243),
#  ('Drifter', 58),
#  ('Drifter', 101),
#  ('Driver 8', 190),
#  ('Drown', 202),
#  ('Drown Me Slowly', 11),
#  ('Drowning Man', 239),
#  ('Drug Testing', 250),
#  ('Drum Boogie', 51),
#  ('Drão', 21),
#  ('Drão', 73),
#  ('Dude (Looks Like A Lady)', 5),
#  ('Duelists', 107),
#  ('Duende', 208),
#  ('Dujji', 84),
#  ('Duos II', 266),
#  ("Dust N' Bones", 91),
#  ("Dwight's Speech", 250),
#  ('Dyers Eve', 156),
#  ('E Vamos À Luta', 41),
#  ('E-Bow The Letter', 189),
#  ('E.C.T.', 57),
#  ('E.S.P.', 49),
#  ('Earth Mofo', 213),
#  ('Easily', 195),
#  ('Easy', 75),
#  ('Eat The Rich', 5),
#  ('Echo', 121),
#  ('Eclipse', 183),
#  ('Eclipse Oculto', 21),
#  ('Edge Of The World', 77),
#  ('Edie (Ciao Baby)', 213),
#  ('Eduardo E Mônica', 140),
#  ('Eggtown', 261),
#  ('Ego Tripping Out', 146),
#  ('El Corazon Manda', 197),
#  ('El Farol', 46),
#  ('Ela Desapareceu', 199),
#  ('Ela Disse Adeus', 168),
#  ('Elderly Woman Behind The Counter In A Small Town', 178),
#  ('Elderly Woman Behind The Counter In A Small Town', 182),
#  ('Eleanor Rigby', 57),
#  ('Electric Eye', 125),
#  ('Electrolite', 189),
#  ('Elevation', 233),
#  ('Elgar: Cello Concerto & Vaughan Williams: Fantasias', 306),
#  ('Elis Regina-Minha História', 71),
#  ('Elvis Ate America', 176),
#  ('Elza', 165),
#  ('Email Surveillance', 250),
#  ('Emerald', 220),
#  ('Emergency', 160),
#  ('Emergency On Planet Earth', 116),
#  ('Emit Remmus', 195),
#  ('Encontrar Alguém', 123),
#  ('End Of Romanticism', 204),
#  ('End Of The Night', 214),
#  ('End Over End', 79),
#  ('Endgame', 187),
#  ('Endless Deep', 234),
#  ('Engenho De Dentro', 122),
#  ('English Civil War', 211),
#  ('English Renaissance', 314),
#  ('Enough Space', 82),
#  ('Enquanto O Dia Não Vem', 124),
#  ('Enquanto O Mundo Explode', 24),
#  ('Enslaved', 162),
#  ('Enter 77', 229),
#  ('Enter Sandman', 9),
#  ('Enter Sandman', 148),
#  ('Entrando Na Sua (Intro)', 84),
#  ('Entre E Ouça', 47),
#  ('Epic', 77),
#  ('Equal Rights Downpresser Man', 141),
#  ('Equinocio', 124),
#  ('Era Uma Vez', 225),
#  ('Erlkonig, D.328', 341),
#  ('Eruption', 243),
#  ('Eruption', 244),
#  ('Escape', 154),
#  ('Esotérico', 73),
#  ...]

# %% [markdown]
# ### Exercise 2
#
# In some cases, artists will create eponymous albums, i.e. albums with the same name as the artist. Write a query that will highlight all eponymous albums as well as non-eponymous albums.
#
#
# **NOTE**: At the moment, SQLite does not support the `FULL OUTER JOIN` statement. Emulate it using a `LEFT JOIN` and a `UNION` operator.

# %%
# %%sql
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     artists ar
# LEFT JOIN
#     albums AS a
#     ON ar.Name = a.Title
#
# UNION ALL
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     albums AS a
# LEFT JOIN
#     artists AS ar
#     ON ar.Name = a.Title
# Out:
#  * sqlite:///chinook.db
# Done.
# [('AC/DC', None),
#  ('Accept', None),
#  ('Aerosmith', None),
#  ('Alanis Morissette', None),
#  ('Alice In Chains', None),
#  ('Antônio Carlos Jobim', None),
#  ('Apocalyptica', None),
#  ('Audioslave', 'Audioslave'),
#  ('BackBeat', None),
#  ('Billy Cobham', None),
#  ('Black Label Society', None),
#  ('Black Sabbath', 'Black Sabbath'),
#  ('Body Count', 'Body Count'),
#  ('Bruce Dickinson', None),
#  ('Buddy Guy', None),
#  ('Caetano Veloso', None),
#  ('Chico Buarque', None),
#  ('Chico Science & Nação Zumbi', None),
#  ('Cidade Negra', None),
#  ('Cláudio Zoli', None),
#  ('Various Artists', None),
#  ('Led Zeppelin', None),
#  ('Frank Zappa & Captain Beefheart', None),
#  ('Marcos Valle', None),
#  ('Milton Nascimento & Bebeto', None),
#  ('Azymuth', None),
#  ('Gilberto Gil', None),
#  ('João Gilberto', None),
#  ('Bebel Gilberto', None),
#  ('Jorge Vercilo', None),
#  ('Baby Consuelo', None),
#  ('Ney Matogrosso', None),
#  ('Luiz Melodia', None),
#  ('Nando Reis', None),
#  ('Pedro Luís & A Parede', None),
#  ('O Rappa', None),
#  ('Ed Motta', None),
#  ('Banda Black Rio', None),
#  ('Fernanda Porto', None),
#  ('Os Cariocas', None),
#  ('Elis Regina', None),
#  ('Milton Nascimento', None),
#  ('A Cor Do Som', None),
#  ('Kid Abelha', None),
#  ('Sandra De Sá', None),
#  ('Jorge Ben', None),
#  ('Hermeto Pascoal', None),
#  ('Barão Vermelho', None),
#  ('Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', None),
#  ('Metallica', None),
#  ('Queen', None),
#  ('Kiss', None),
#  ('Spyro Gyra', None),
#  ('Green Day', None),
#  ('David Coverdale', None),
#  ('Gonzaguinha', None),
#  ('Os Mutantes', None),
#  ('Deep Purple', None),
#  ('Santana', None),
#  ('Santana Feat. Dave Matthews', None),
#  ('Santana Feat. Everlast', None),
#  ('Santana Feat. Rob Thomas', None),
#  ('Santana Feat. Lauryn Hill & Cee-Lo', None),
#  ('Santana Feat. The Project G&B', None),
#  ('Santana Feat. Maná', None),
#  ('Santana Feat. Eagle-Eye Cherry', None),
#  ('Santana Feat. Eric Clapton', None),
#  ('Miles Davis', None),
#  ('Gene Krupa', None),
#  ('Toquinho & Vinícius', None),
#  ('Vinícius De Moraes & Baden Powell', None),
#  ('Vinícius De Moraes', None),
#  ('Vinícius E Qurteto Em Cy', None),
#  ('Vinícius E Odette Lara', None),
#  ('Vinicius, Toquinho & Quarteto Em Cy', None),
#  ('Creedence Clearwater Revival', None),
#  ('Cássia Eller', None),
#  ('Def Leppard', None),
#  ('Dennis Chambers', None),
#  ('Djavan', None),
#  ('Eric Clapton', None),
#  ('Faith No More', None),
#  ('Falamansa', None),
#  ('Foo Fighters', None),
#  ('Frank Sinatra', None),
#  ('Funk Como Le Gusta', None),
#  ('Godsmack', None),
#  ("Guns N' Roses", None),
#  ('Incognito', None),
#  ('Iron Maiden', 'Iron Maiden'),
#  ('James Brown', None),
#  ('Jamiroquai', None),
#  ('JET', None),
#  ('Jimi Hendrix', None),
#  ('Joe Satriani', None),
#  ('Jota Quest', None),
#  ('João Suplicy', None),
#  ('Judas Priest', None),
#  ('Legião Urbana', None),
#  ('Lenny Kravitz', None),
#  ('Lulu Santos', None),
#  ('Marillion', None),
#  ('Marisa Monte', None),
#  ('Marvin Gaye', None),
#  ('Men At Work', None),
#  ('Motörhead', None),
#  ('Motörhead & Girlschool', None),
#  ('Mônica Marianno', None),
#  ('Mötley Crüe', None),
#  ('Nirvana', None),
#  ('O Terço', None),
#  ('Olodum', 'Olodum'),
#  ('Os Paralamas Do Sucesso', None),
#  ('Ozzy Osbourne', None),
#  ('Page & Plant', None),
#  ('Passengers', None),
#  ("Paul D'Ianno", None),
#  ('Pearl Jam', 'Pearl Jam'),
#  ('Peter Tosh', None),
#  ('Pink Floyd', None),
#  ('Planet Hemp', None),
#  ('R.E.M. Feat. Kate Pearson', None),
#  ('R.E.M. Feat. KRS-One', None),
#  ('R.E.M.', None),
#  ('Raimundos', None),
#  ('Raul Seixas', 'Raul Seixas'),
#  ('Red Hot Chili Peppers', None),
#  ('Rush', None),
#  ('Simply Red', None),
#  ('Skank', None),
#  ('Smashing Pumpkins', None),
#  ('Soundgarden', None),
#  ('Stevie Ray Vaughan & Double Trouble', None),
#  ('Stone Temple Pilots', None),
#  ('System Of A Down', None),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', None),
#  ('The Black Crowes', None),
#  ('The Clash', None),
#  ('The Cult', None),
#  ('The Doors', 'The Doors'),
#  ('The Police', None),
#  ('The Rolling Stones', None),
#  ('The Tea Party', None),
#  ('The Who', None),
#  ('Tim Maia', None),
#  ('Titãs', None),
#  ('Battlestar Galactica', None),
#  ('Heroes', None),
#  ('Lost', None),
#  ('U2', None),
#  ('UB40', None),
#  ('Van Halen', 'Van Halen'),
#  ('Velvet Revolver', None),
#  ('Whitesnake', None),
#  ('Zeca Pagodinho', None),
#  ('The Office', None),
#  ('Dread Zeppelin', None),
#  ('Battlestar Galactica (Classic)', None),
#  ('Aquaman', 'Aquaman'),
#  ('Christina Aguilera featuring BigElf', None),
#  ("Aerosmith & Sierra Leone's Refugee Allstars", None),
#  ('Los Lonely Boys', None),
#  ('Corinne Bailey Rae', None),
#  ('Dhani Harrison & Jakob Dylan', None),
#  ('Jackson Browne', None),
#  ('Avril Lavigne', None),
#  ('Big & Rich', None),
#  ("Youssou N'Dour", None),
#  ('Black Eyed Peas', None),
#  ('Jack Johnson', None),
#  ('Ben Harper', None),
#  ('Snow Patrol', None),
#  ('Matisyahu', None),
#  ('The Postal Service', None),
#  ('Jaguares', None),
#  ('The Flaming Lips', None),
#  ("Jack's Mannequin & Mick Fleetwood", None),
#  ('Regina Spektor', None),
#  ('Scorpions', None),
#  ('House Of Pain', None),
#  ('Xis', None),
#  ('Nega Gizza', None),
#  ('Gustavo & Andres Veiga & Salazar', None),
#  ('Rodox', None),
#  ('Charlie Brown Jr.', None),
#  ('Pedro Luís E A Parede', None),
#  ('Los Hermanos', None),
#  ('Mundo Livre S/A', None),
#  ('Otto', None),
#  ('Instituto', None),
#  ('Nação Zumbi', None),
#  ('DJ Dolores & Orchestra Santa Massa', None),
#  ('Seu Jorge', None),
#  ('Sabotage E Instituto', None),
#  ('Stereo Maracana', None),
#  ('Cake', None),
#  ('Aisha Duo', None),
#  ('Habib Koité and Bamada', None),
#  ('Karsh Kale', None),
#  ('The Posies', None),
#  ('Luciana Souza/Romero Lubambo', None),
#  ('Aaron Goldberg', None),
#  ('Nicolaus Esterhazy Sinfonia', None),
#  ('Temple of the Dog', 'Temple of the Dog'),
#  ('Chris Cornell', None),
#  ('Alberto Turco & Nova Schola Gregoriana', None),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', None),
#  ('English Concert & Trevor Pinnock', None),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', None),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', None),
#  ('Wilhelm Kempff', None),
#  ('Yo-Yo Ma', None),
#  ('Scholars Baroque Ensemble', None),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', None),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', None),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', None),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', None),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', None),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', None),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', None),
#  ('Sir Georg Solti & Wiener Philharmoniker', None),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', None),
#  ('London Symphony Orchestra & Sir Charles Mackerras', None),
#  ('Barry Wordsworth & BBC Concert Orchestra', None),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', None),
#  ('Eugene Ormandy', None),
#  ('Luciano Pavarotti', None),
#  ('Leonard Bernstein & New York Philharmonic', None),
#  ('Boston Symphony Orchestra & Seiji Ozawa', None),
#  ('Aaron Copland & London Symphony Orchestra', None),
#  ('Ton Koopman', None),
#  ('Sergei Prokofiev & Yuri Temirkanov', None),
#  ('Chicago Symphony Orchestra & Fritz Reiner', None),
#  ('Orchestra of The Age of Enlightenment', None),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', None),
#  ('James Levine', None),
#  ('Berliner Philharmoniker & Hans Rosbaud', None),
#  ('Maurizio Pollini', None),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', None),
#  ('Gustav Mahler', None),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', None),
#  ('Edo de Waart & San Francisco Symphony', None),
#  ('Antal Doráti & London Symphony Orchestra', None),
#  ('Choir Of Westminster Abbey & Simon Preston', None),
#  ('Michael Tilson Thomas & San Francisco Symphony', None),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', None),
#  ("The King's Singers", None),
#  ('Berliner Philharmoniker & Herbert Von Karajan', None),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', None),
#  ("Christopher O'Riley", None),
#  ('Fretwork', None),
#  ('Amy Winehouse', None),
#  ('Calexico', None),
#  ('Otto Klemperer & Philharmonia Orchestra', None),
#  ('Yehudi Menuhin', None),
#  ('Philharmonia Orchestra & Sir Neville Marriner', None),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', None),
#  ('Les Arts Florissants & William Christie', None),
#  ('The 12 Cellists of The Berlin Philharmonic', None),
#  ('Adrian Leaper & Doreen de Feis', None),
#  ('Roger Norrington, London Classical Players', None),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", None),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', None),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", None),
#  ('Julian Bream', None),
#  ('Martin Roscoe', None),
#  ('Göteborgs Symfoniker & Neeme Järvi', None),
#  ('Itzhak Perlman', None),
#  ('Michele Campanella', None),
#  ('Gerald Moore', None),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', None),
#  ('Emerson String Quartet', None),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', None),
#  ('Nash Ensemble', None),
#  ('Philip Glass Ensemble', None),
#  (None, 'For Those About To Rock We Salute You'),
#  (None, 'Balls to the Wall'),
#  (None, 'Restless and Wild'),
#  (None, 'Let There Be Rock'),
#  (None, 'Big Ones'),
#  (None, 'Jagged Little Pill'),
#  (None, 'Facelift'),
#  (None, 'Warner 25 Anos'),
#  (None, 'Plays Metallica By Four Cellos'),
#  ('Audioslave', 'Audioslave'),
#  (None, 'Out Of Exile'),
#  (None, 'BackBeat Soundtrack'),
#  (None, 'The Best Of Billy Cobham'),
#  (None, 'Alcohol Fueled Brewtality Live! [Disc 1]'),
#  (None, 'Alcohol Fueled Brewtality Live! [Disc 2]'),
#  ('Black Sabbath', 'Black Sabbath'),
#  (None, 'Black Sabbath Vol. 4 (Remaster)'),
#  ('Body Count', 'Body Count'),
#  (None, 'Chemical Wedding'),
#  (None, 'The Best Of Buddy Guy - The Millenium Collection'),
#  (None, 'Prenda Minha'),
#  (None, 'Sozinho Remix Ao Vivo'),
#  (None, 'Minha Historia'),
#  (None, 'Afrociberdelia'),
#  (None, 'Da Lama Ao Caos'),
#  (None, 'Acústico MTV [Live]'),
#  (None, 'Cidade Negra - Hits'),
#  (None, 'Na Pista'),
#  (None, 'Axé Bahia 2001'),
#  (None, 'BBC Sessions [Disc 1] [Live]'),
#  (None, 'Bongo Fury'),
#  (None, 'Carnaval 2001'),
#  (None, 'Chill: Brazil (Disc 1)'),
#  (None, 'Chill: Brazil (Disc 2)'),
#  (None, 'Garage Inc. (Disc 1)'),
#  (None, 'Greatest Hits II'),
#  (None, 'Greatest Kiss'),
#  (None, 'Heart of the Night'),
#  (None, 'International Superhits'),
#  (None, 'Into The Light'),
#  (None, 'Meus Momentos'),
#  (None, 'Minha História'),
#  (None, 'MK III The Final Concerts [Disc 1]'),
#  (None, 'Physical Graffiti [Disc 1]'),
#  (None, 'Sambas De Enredo 2001'),
#  (None, 'Supernatural'),
#  (None, 'The Best of Ed Motta'),
#  (None, 'The Essential Miles Davis [Disc 1]'),
#  (None, 'The Essential Miles Davis [Disc 2]'),
#  (None, 'The Final Concerts (Disc 2)'),
#  (None, "Up An' Atom"),
#  (None, 'Vinícius De Moraes - Sem Limite'),
#  (None, 'Vozes do MPB'),
#  (None, 'Chronicle, Vol. 1'),
#  (None, 'Chronicle, Vol. 2'),
#  (None, 'Cássia Eller - Coleção Sem Limite [Disc 2]'),
#  (None, 'Cássia Eller - Sem Limite [Disc 1]'),
#  (None, 'Come Taste The Band'),
#  (None, 'Deep Purple In Rock'),
#  (None, 'Fireball'),
#  (None, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's"),
#  (None, 'Machine Head'),
#  (None, 'Purpendicular'),
#  (None, 'Slaves And Masters'),
#  (None, 'Stormbringer'),
#  (None, 'The Battle Rages On'),
#  (None, "Vault: Def Leppard's Greatest Hits"),
#  (None, 'Outbreak'),
#  (None, 'Djavan Ao Vivo - Vol. 02'),
#  (None, 'Djavan Ao Vivo - Vol. 1'),
#  (None, 'Elis Regina-Minha História'),
#  (None, 'The Cream Of Clapton'),
#  (None, 'Unplugged'),
#  (None, 'Album Of The Year'),
#  (None, 'Angel Dust'),
#  (None, 'King For A Day Fool For A Lifetime'),
#  (None, 'The Real Thing'),
#  (None, 'Deixa Entrar'),
#  (None, 'In Your Honor [Disc 1]'),
#  (None, 'In Your Honor [Disc 2]'),
#  (None, 'One By One'),
#  (None, 'The Colour And The Shape'),
#  (None, 'My Way: The Best Of Frank Sinatra [Disc 1]'),
#  (None, 'Roda De Funk'),
#  (None, 'As Canções de Eu Tu Eles'),
#  (None, 'Quanta Gente Veio Ver (Live)'),
#  (None, 'Quanta Gente Veio ver--Bônus De Carnaval'),
#  (None, 'Faceless'),
#  (None, 'American Idiot'),
#  (None, 'Appetite for Destruction'),
#  (None, 'Use Your Illusion I'),
#  (None, 'Use Your Illusion II'),
#  (None, 'Blue Moods'),
#  (None, 'A Matter of Life and Death'),
#  (None, 'A Real Dead One'),
#  (None, 'A Real Live One'),
#  (None, 'Brave New World'),
#  (None, 'Dance Of Death'),
#  (None, 'Fear Of The Dark'),
#  ('Iron Maiden', 'Iron Maiden'),
#  (None, 'Killers'),
#  (None, 'Live After Death'),
#  (None, 'Live At Donington 1992 (Disc 1)'),
#  (None, 'Live At Donington 1992 (Disc 2)'),
#  (None, 'No Prayer For The Dying'),
#  (None, 'Piece Of Mind'),
#  (None, 'Powerslave'),
#  (None, 'Rock In Rio [CD1]'),
#  (None, 'Rock In Rio [CD2]'),
#  (None, 'Seventh Son of a Seventh Son'),
#  (None, 'Somewhere in Time'),
#  (None, 'The Number of The Beast'),
#  (None, 'The X Factor'),
#  (None, 'Virtual XI'),
#  (None, 'Sex Machine'),
#  (None, 'Emergency On Planet Earth'),
#  (None, 'Synkronized'),
#  (None, 'The Return Of The Space Cowboy'),
#  (None, 'Get Born'),
#  (None, 'Are You Experienced?'),
#  (None, 'Surfing with the Alien (Remastered)'),
#  (None, 'Jorge Ben Jor 25 Anos'),
#  (None, 'Jota Quest-1995'),
#  (None, 'Cafezinho'),
#  (None, 'Living After Midnight'),
#  (None, 'Unplugged [Live]'),
#  (None, 'BBC Sessions [Disc 2] [Live]'),
#  (None, 'Coda'),
#  (None, 'Houses Of The Holy'),
#  (None, 'In Through The Out Door'),
#  (None, 'IV'),
#  (None, 'Led Zeppelin I'),
#  (None, 'Led Zeppelin II'),
#  (None, 'Led Zeppelin III'),
#  (None, 'Physical Graffiti [Disc 2]'),
#  (None, 'Presence'),
#  (None, 'The Song Remains The Same (Disc 1)'),
#  (None, 'The Song Remains The Same (Disc 2)'),
#  (None, 'A TempestadeTempestade Ou O Livro Dos Dias'),
#  (None, 'Mais Do Mesmo'),
#  (None, 'Greatest Hits'),
#  (None, 'Lulu Santos - RCA 100 Anos De Música - Álbum 01'),
#  (None, 'Lulu Santos - RCA 100 Anos De Música - Álbum 02'),
#  (None, 'Misplaced Childhood'),
#  (None, 'Barulhinho Bom'),
#  (None, 'Seek And Shall Find: More Of The Best (1963-1981)'),
#  (None, 'The Best Of Men At Work'),
#  (None, 'Black Album'),
#  (None, 'Garage Inc. (Disc 2)'),
#  (None, "Kill 'Em All"),
#  (None, 'Load'),
#  (None, 'Master Of Puppets'),
#  (None, 'ReLoad'),
#  (None, 'Ride The Lightning'),
#  (None, 'St. Anger'),
#  (None, '...And Justice For All'),
#  (None, 'Miles Ahead'),
#  (None, 'Milton Nascimento Ao Vivo'),
#  (None, 'Minas'),
#  (None, 'Ace Of Spades'),
#  (None, 'Demorou...'),
#  (None, 'Motley Crue Greatest Hits'),
#  (None, 'From The Muddy Banks Of The Wishkah [Live]'),
#  (None, 'Nevermind'),
#  (None, 'Compositores'),
#  ('Olodum', 'Olodum'),
#  (None, 'Acústico MTV'),
#  (None, 'Arquivo II'),
#  (None, 'Arquivo Os Paralamas Do Sucesso'),
#  (None, 'Bark at the Moon (Remastered)'),
#  (None, 'Blizzard of Ozz'),
#  (None, 'Diary of a Madman (Remastered)'),
#  (None, 'No More Tears (Remastered)'),
#  (None, 'Tribute'),
#  (None, 'Walking Into Clarksdale'),
#  (None, 'Original Soundtracks 1'),
#  (None, 'The Beast Live'),
#  (None, 'Live On Two Legs [Live]'),
#  ('Pearl Jam', 'Pearl Jam'),
#  (None, 'Riot Act'),
#  (None, 'Ten'),
#  (None, 'Vs.'),
#  (None, 'Dark Side Of The Moon'),
#  (None, 'Os Cães Ladram Mas A Caravana Não Pára'),
#  (None, 'Greatest Hits I'),
#  (None, 'News Of The World'),
#  (None, 'Out Of Time'),
#  (None, 'Green'),
#  (None, 'New Adventures In Hi-Fi'),
#  (None, 'The Best Of R.E.M.: The IRS Years'),
#  (None, 'Cesta Básica'),
#  ('Raul Seixas', 'Raul Seixas'),
#  (None, 'Blood Sugar Sex Magik'),
#  (None, 'By The Way'),
#  (None, 'Californication'),
#  (None, 'Retrospective I (1974-1980)'),
#  (None, 'Santana - As Years Go By'),
#  (None, 'Santana Live'),
#  (None, 'Maquinarama'),
#  (None, 'O Samba Poconé'),
#  (None, 'Judas 0: B-Sides and Rarities'),
#  (None, 'Rotten Apples: Greatest Hits'),
#  (None, 'A-Sides'),
#  (None, 'Morning Dance'),
#  (None, 'In Step'),
#  (None, 'Core'),
#  (None, 'Mezmerize'),
#  (None, '[1997] Black Light Syndrome'),
#  (None, 'Live [Disc 1]'),
#  (None, 'Live [Disc 2]'),
#  (None, 'The Singles'),
#  (None, 'Beyond Good And Evil'),
#  (None, 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]'),
#  ('The Doors', 'The Doors'),
#  (None, 'The Police Greatest Hits'),
#  (None, 'Hot Rocks, 1964-1971 (Disc 1)'),
#  (None, 'No Security'),
#  (None, 'Voodoo Lounge'),
#  (None, 'Tangents'),
#  (None, 'Transmission'),
#  (None, 'My Generation - The Very Best Of The Who'),
#  (None, 'Serie Sem Limite (Disc 1)'),
#  (None, 'Serie Sem Limite (Disc 2)'),
#  (None, 'Acústico'),
#  (None, 'Volume Dois'),
#  (None, 'Battlestar Galactica: The Story So Far'),
#  (None, 'Battlestar Galactica, Season 3'),
#  (None, 'Heroes, Season 1'),
#  (None, 'Lost, Season 3'),
#  (None, 'Lost, Season 1'),
#  (None, 'Lost, Season 2'),
#  (None, 'Achtung Baby'),
#  (None, "All That You Can't Leave Behind"),
#  (None, 'B-Sides 1980-1990'),
#  (None, 'How To Dismantle An Atomic Bomb'),
#  (None, 'Pop'),
#  (None, 'Rattle And Hum'),
#  (None, 'The Best Of 1980-1990'),
#  (None, 'War'),
#  (None, 'Zooropa'),
#  (None, 'UB40 The Best Of - Volume Two [UK]'),
#  (None, 'Diver Down'),
#  (None, 'The Best Of Van Halen, Vol. I'),
#  ('Van Halen', 'Van Halen'),
#  (None, 'Van Halen III'),
#  (None, 'Contraband'),
#  (None, 'Vinicius De Moraes'),
#  (None, 'Ao Vivo [IMPORT]'),
#  (None, 'The Office, Season 1'),
#  (None, 'The Office, Season 2'),
#  (None, 'The Office, Season 3'),
#  (None, 'Un-Led-Ed'),
#  (None, 'Battlestar Galactica (Classic), Season 1'),
#  ('Aquaman', 'Aquaman'),
#  (None, 'Instant Karma: The Amnesty International Campaign to Save Darfur'),
#  (None, 'Speak of the Devil'),
#  (None, '20th Century Masters - The Millennium Collection: The Best of Scorpions'),
#  (None, 'House of Pain'),
#  (None, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro'),
#  (None, 'Cake: B-Sides and Rarities'),
#  (None, 'LOST, Season 4'),
#  (None, 'Quiet Songs'),
#  (None, 'Muso Ko'),
#  (None, 'Realize'),
#  (None, 'Every Kind of Light'),
#  (None, 'Duos II'),
#  (None, 'Worlds'),
#  (None, 'The Best of Beethoven'),
#  ('Temple of the Dog', 'Temple of the Dog'),
#  (None, 'Carry On'),
#  (None, 'Revelations'),
#  (None, 'Adorate Deum: Gregorian Chant from the Proper of the Mass'),
#  (None, 'Allegri: Miserere'),
#  (None, 'Pachelbel: Canon & Gigue'),
#  (None, 'Vivaldi: The Four Seasons'),
#  (None, 'Bach: Violin Concertos'),
#  (None, 'Bach: Goldberg Variations'),
#  (None, 'Bach: The Cello Suites'),
#  (None, 'Handel: The Messiah (Highlights)'),
#  (None, 'The World of Classical Favourites'),
#  (None, 'Sir Neville Marriner: A Celebration'),
#  (None, 'Mozart: Wind Concertos'),
#  (None, 'Haydn: Symphonies 99 - 104'),
#  (None, 'Beethoven: Symhonies Nos. 5 & 6'),
#  (None, 'A Soprano Inspired'),
#  (None, 'Great Opera Choruses'),
#  (None, 'Wagner: Favourite Overtures'),
#  (None, 'Fauré: Requiem, Ravel: Pavane & Others'),
#  (None, 'Tchaikovsky: The Nutcracker'),
#  (None, 'The Last Night of the Proms'),
#  (None, 'Puccini: Madama Butterfly - Highlights'),
#  (None, 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies'),
#  (None, "Pavarotti's Opera Made Easy"),
#  (None, "Great Performances - Barber's Adagio and Other Romantic Favorites for Strings"),
#  (None, 'Carmina Burana'),
#  (None, 'A Copland Celebration, Vol. I'),
#  (None, 'Bach: Toccata & Fugue in D Minor'),
#  (None, 'Prokofiev: Symphony No.1'),
#  (None, 'Scheherazade'),
#  (None, 'Bach: The Brandenburg Concertos'),
#  (None, 'Chopin: Piano Concertos Nos. 1 & 2'),
#  (None, 'Mascagni: Cavalleria Rusticana'),
#  (None, 'Sibelius: Finlandia'),
#  (None, 'Beethoven Piano Sonatas: Moonlight & Pastorale'),
#  (None, 'Great Recordings of the Century - Mahler: Das Lied von der Erde'),
#  (None, 'Elgar: Cello Concerto & Vaughan Williams: Fantasias'),
#  (None, 'Adams, John: The Chairman Dances'),
#  (None, "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory"),
#  (None, 'Palestrina: Missa Papae Marcelli & Allegri: Miserere'),
#  (None, 'Prokofiev: Romeo & Juliet'),
#  (None, 'Strauss: Waltzes'),
#  (None, 'Berlioz: Symphonie Fantastique'),
#  (None, 'Bizet: Carmen Highlights'),
#  (None, 'English Renaissance'),
#  (None, 'Handel: Music for the Royal Fireworks (Original Version 1749)'),
#  (None, 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande'),
#  (None, 'Mozart Gala: Famous Arias'),
#  (None, 'SCRIABIN: Vers la flamme'),
#  (None, 'Armada: Music from the Courts of England and Spain'),
#  (None, 'Mozart: Symphonies Nos. 40 & 41'),
#  (None, 'Back to Black'),
#  (None, 'Frank'),
#  (None, 'Carried to Dust (Bonus Track Version)'),
#  (None, "Beethoven: Symphony No. 6 'Pastoral' Etc."),
#  (None, 'Bartok: Violin & Viola Concertos'),
#  (None, "Mendelssohn: A Midsummer Night's Dream"),
#  (None, 'Bach: Orchestral Suites Nos. 1 - 4'),
#  (None, 'Charpentier: Divertissements, Airs & Concerts'),
#  (None, 'South American Getaway'),
#  (None, 'Górecki: Symphony No. 3'),
#  (None, 'Purcell: The Fairy Queen'),
#  (None, 'The Ultimate Relexation Album'),
#  (None, 'Purcell: Music for the Queen Mary'),
#  (None, 'Weill: The Seven Deadly Sins'),
#  (None, 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro'),
#  (None, 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps'),
#  (None, 'Szymanowski: Piano Works, Vol. 1'),
#  (None, 'Nielsen: The Six Symphonies'),
#  (None, "Great Recordings of the Century: Paganini's 24 Caprices"),
#  (None, "Liszt - 12 Études D'Execution Transcendante"),
#  (None, 'Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder'),
#  (None, 'Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3'),
#  (None, 'Respighi:Pines of Rome'),
#  (None, "Schubert: The Late String Quartets & String Quintet (3 CD's)"),
#  (None, "Monteverdi: L'Orfeo"),
#  (None, 'Mozart: Chamber Music'),
#  (None, 'Koyaanisqatsi (Soundtrack from the Motion Picture)')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1
#
# The SQL query uses the `UNION` operator to merge data from two tables, `tracks` and `albums`, into a single list. It selects the `AlbumId` and `Name` columns from the `tracks` table with a "Category" label of "Artist" and combines it with the `AlbumId` and `Title` columns from the `albums` table with a "Category" label of "Album". The `LIMIT 10` clause is used to restrict the output to the first 10 results.

# %%
# %%sql
#
# SELECT t.AlbumId, t.Name, "Artist" AS "Category"
# FROM tracks AS t
#
# UNION
#
# SELECT a.AlbumId, a.Title, "Album" AS "Category"
# FROM albums AS a
#
# LIMIT 10;  -- Remove this line to see the full query output
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Breaking The Rules', 'Artist'),
#  (1, 'C.O.D.', 'Artist'),
#  (1, 'Evil Walks', 'Artist'),
#  (1, 'For Those About To Rock (We Salute You)', 'Artist'),
#  (1, 'For Those About To Rock We Salute You', 'Album'),
#  (1, 'Inject The Venom', 'Artist'),
#  (1, "Let's Get It Up", 'Artist'),
#  (1, 'Night Of The Long Knives', 'Artist'),
#  (1, 'Put The Finger On You', 'Artist'),
#  (1, 'Snowballed', 'Artist')]

# %% [markdown]
# ### Exercise 2
#
# The SQL query retrieves a list of artist names and album titles, highlighting both eponymous albums (albums with the same name as the artist) and non-eponymous albums. It achieves this by using a combination of `LEFT JOIN` and `UNION ALL` to combine the results of two separate queries. The first query joins the `artists` and `albums` tables by matching the artist's name with the album title, while the second query joins the `albums` and `artists` tables with the same condition. This approach effectively emulates a `FULL OUTER JOIN`, ensuring that all eponymous and non-eponymous albums are included in the final result.

# %%
# %%sql
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     artists ar
# LEFT JOIN
#     albums AS a
#     ON ar.Name = a.Title
#
# UNION ALL
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     albums AS a
# LEFT JOIN
#     artists AS ar
#     ON ar.Name = a.Title
#
# LIMIT 10;  -- Remove this line to see the full query output

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
